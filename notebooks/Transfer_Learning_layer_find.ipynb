# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ## Load Libraries

# %%
import importlib
import sys
import os
import numpy as np
import time
from pathlib import Path
import matplotlib.pyplot as plt

import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, TensorDataset, DataLoader

from torch.utils import data
from torchvision import transforms

sys.path.append(os.path.join(os.getcwd(), ".."))

from distiller import apputils
import ai8x

from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

kws20 = importlib.import_module("datasets.kws20-horsecough")

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_recall_fscore_support, roc_auc_score, roc_curve


import librosa
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# FIX SEED FOR REPRODUCIBILITY
seed = 69
torch.manual_seed(seed)

# %% [markdown]
# ## Function Declarations

# %%
def rescale(audio, min_val=-1,max_val=1):
    sig = audio
    mean = np.average(sig)

    sig = sig-mean # REMOVE DC COMPONENT

    sig_max = np.max(sig)
    sig_min = np.min(sig)

    if sig_max >= np.abs(sig_min):
        sig_scaled = sig/sig_max
    else:
        sig_scaled = sig/np.abs(sig_min)

    return sig_scaled

def rescale2(audio, min_val=-1,max_val=1):
    scaler = MinMaxScaler(feature_range=(min_val,max_val))
    audio = audio.reshape(-1,1)
    scaler.fit(audio)
    scaled = np.array(scaler.transform(audio))
    
    return scaled[:,0]


def plot_confusion(y_true, y_pred, classes):
    cf_matrix = confusion_matrix(y_true = y_true, y_pred = y_pred, labels =list(range(len(classes))))
    print(cf_matrix)

def plot_roc_curve(true_y, y_prob):
    fpr, tpr, thresholds = roc_curve(true_y, y_prob)
    plt.plot(fpr, tpr)
    plt.plot([0,1], [0,1], 'r--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

def custom_dataloader(data, train_idx, val_idx, test_idx, batch_size = 2048):
    data_file = data
    x = np.asarray(data_file[0][test_idx])
    y = np.squeeze(np.asarray(data_file[1][test_idx]))
    test_set = TensorDataset(torch.Tensor(x),torch.Tensor(y).to(dtype =torch.int64))
    test_loader = DataLoader(test_set,batch_size=batch_size, num_workers=4, pin_memory=True)

    x = np.asarray(data_file[0][val_idx])
    y = np.squeeze(np.asarray(data_file[1][val_idx]))
    val_set = TensorDataset(torch.Tensor(x),torch.Tensor(y).to(dtype =torch.int64))
    val_loader = DataLoader(val_set,batch_size=batch_size, num_workers=4, pin_memory=True)

    x = np.asarray(data_file[0][train_idx])
    y = np.squeeze(np.asarray(data_file[1][train_idx]))
    train_set = TensorDataset(torch.Tensor(x),torch.Tensor(y).to(dtype =torch.int64))
    train_loader = DataLoader(train_set,batch_size=batch_size, num_workers=4, pin_memory=True)

    return train_loader,val_loader,test_loader

def count_params(model):
    model_parameters = filter(lambda p: p.requires_grad, model.parameters())
    params = sum([np.prod(p.size()) for p in model_parameters])
    print(params)
    return params

def freeze_layer(layer):
    for p in layer.parameters():
        p.requires_grad = False

# %% [markdown]
# ## Prepare Checkpoint, Plot, and Dataset Folders

# %%
model_name = 'human_others'
classes = ["combined",'cough']
checkpoint_dir = './checkpoints/'+model_name+'/'

indexer = 0
while os.path.exists(checkpoint_dir):
    model_name = 'human_others'
    model_name = model_name + '_' + str(indexer)
    checkpoint_dir = './checkpoints/'+model_name+'/'
    indexer += 1

if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

print('Model Name: ', model_name)
print('Classes: ', classes)
print('Checkpoint Dir: ', checkpoint_dir)
# Out:
# Model Name:  human_others_13
# Classes:  ['combined', 'cough']
# Checkpoint Dir:  ./checkpoints/human_others_13/

# %% [markdown]
# ## Calculate weights

# %%
raw_data_path = Path("../data/KWS_EQUINE/raw/")
class_file_count = {}

class_dirs = [d for d in raw_data_path.iterdir() if d.is_dir() and (d.stem != "__combinedkws") and (d.stem != "__combined_others") and (d.stem != "__human_cough")and (d.stem != "__human_cough_v2")]

for d in class_dirs:
    print(d)
    class_file_count[d] = len(list(d.iterdir()))

min_file_count = float(min(class_file_count.values()))

# Calculate weights
class_weights = []
for d in class_dirs:
    class_file_count[d] = min_file_count / class_file_count[d]
    print(f"{d.stem}: {round(class_file_count[d], 7)}")
    class_weights.append(round(class_file_count[d], 7))
print('Weights: ',class_weights)
# Out:
# ..\data\KWS_EQUINE\raw\combined_others
# ..\data\KWS_EQUINE\raw\human_cough_v2
# combined_others: 1.0
# human_cough_v2: 0.98327
# Weights:  [1.0, 0.98327]

# %% [markdown]
# ## Generate Processed Datafile

# %%
train_batch_size = 4096

processed_data_path = Path("../data/KWS_EQUINE/processed/")
fname = model_name+'.pt'
_, _, _, _ = apputils.get_data_loaders(kws20.KWS_HORSE_TF_get_datasets,("../data", True), 
                                       train_batch_size, 4, validation_split=0.1)
# Out:
# No key `noise_var` in input augmentation dictionary!  Using defaults: [Min: 0., Max: 1.]
# No key `shift` in input augmentation dictionary! Using defaults: [Min:-0.1, Max: 0.1]
# No key `strech` in input augmentation dictionary! Using defaults: [Min: 0.8, Max: 1.3]
# Generating dataset from raw data samples for the first time.
# This process will take significant time (~60 minutes)...
# data_len: 16384
# ------------- Label Size ---------------
# combined_others:  	5172
# human_cough_v2:  	5260
# ------------------------------------------
# Processing the label: combined_others. 1 of 2
# 	1 of 5172
# 	1001 of 5172
# 	2001 of 5172
# 	3001 of 5172
# 	4001 of 5172
# 	5001 of 5172
# Finished in 106.081 seconds.
# (15516, 128, 128)
# Data concatenation finished in 0.026 seconds.
# Processing the label: human_cough_v2. 2 of 2
# 	1 of 5260
# 	1001 of 5260
# 	2001 of 5260
# 	3001 of 5260
# 	4001 of 5260
# 	5001 of 5260
# Finished in 105.289 seconds.
# (15780, 128, 128)
# Data concatenation finished in 0.064 seconds.
# Dataset created.
# Training+Validation: 4745,  Test: 515
#
# Processing train...
# Class combined not found in data
#
# Processing test...
# Class combined not found in data

# %% [markdown]
# ## Read Processed Dataset

# %%
if torch.cuda.is_available():
    device = torch.device('cuda:0')
    cpu = False
else:
     device = torch.device('cpu')
     cpu = True

print('Running on device: {}'.format(torch.cuda.get_device_name()))

processed_dir = "../data/KWS_EQUINE/processed/"

test_ratio = 0.1
val_ratio = 0.1

if os.path.exists(processed_dir+fname):
     data_file = torch.load(processed_dir+fname) # (data, class, type)
     len_dataset = len(data_file[0])

     train_indices, test_indices = train_test_split(np.arange(len_dataset),test_size=test_ratio, train_size=1-test_ratio)
     train_indices, val_indices = train_test_split(train_indices,test_size=val_ratio/(1-test_ratio), train_size=1-(val_ratio/(1-test_ratio)))

     train_loader,val_loader,test_loader = custom_dataloader(data=data_file, train_idx = train_indices,
     val_idx = val_indices, test_idx = test_indices, batch_size = train_batch_size)

     # x = np.asarray(data_file[0][test_indices])
     # y = np.squeeze(np.asarray(data_file[1][test_indices]))

     # test_set = TensorDataset(torch.Tensor(x),torch.Tensor(y).to(dtype =torch.int64))
     # test_loader = DataLoader(test_set,batch_size=train_batch_size, num_workers=4, pin_memory=True)

     # x = np.asarray(data_file[0][val_indices])
     # y = np.squeeze(np.asarray(data_file[1][val_indices]))

     # val_set = TensorDataset(torch.Tensor(x),torch.Tensor(y).to(dtype =torch.int64))
     # val_loader = DataLoader(val_set,batch_size=train_batch_size, num_workers=4, pin_memory=True)
     
     # x = np.asarray(data_file[0][train_indices])
     # y = np.squeeze(np.asarray(data_file[1][train_indices]))

     # train_set = TensorDataset(torch.Tensor(x),torch.Tensor(y).to(dtype =torch.int64))
     # train_loader = DataLoader(train_set,batch_size=train_batch_size, num_workers=4, pin_memory=True)
     
     print('Dataloaders Created')
     print('Train Loader Size: ',len(train_loader.dataset))
     print('Validation Loader Size: ',len(val_loader.dataset))
     print('Test Loader Size: ',len(test_loader.dataset))
else:
     print('Dataset does not Exist')
# Out:
# Running on device: NVIDIA GeForce RTX 2070 SUPER
# Dataloaders Created
# Train Loader Size:  25036
# Validation Loader Size:  3130
# Test Loader Size:  3130

# %% [markdown]
# ## LOOP AT EVERY CHANGE OF FROZEN LAYER TO FIND BEST PERFORMING MODEL

# %%
num_epochs = 1500

criterion = torch.nn.CrossEntropyLoss(weight=torch.FloatTensor(class_weights))
print(criterion.type)
criterion.to(device)

qat_policy = {
    'start_epoch': 100,
    'weight_bits': 8
    }
print('Epochs: ', num_epochs)
# print('Optimizer: \n',optimizer)
print('Loss Function: \n',criterion)
print('QAT: \n',qat_policy)

ai8x.set_device(device=85, simulate=False, round_avg=False)

mod = importlib.import_module("models.ai85net-kws20-v3")

for fl in range (0,8):
    model = mod.AI85KWS20Netv3(num_classes=21, num_channels=128, dimensions=(128, 1), bias=False)
    print(f'Number of Model Params: {count_params(model)}')

    # WEIGHTS OF REFERENCE MODEL
    model, compression_scheduler, optimizer, start_epoch = apputils.load_checkpoint(
                model, "../logs/kws20_original/qat_best.pth.tar")

    # FREEZE SOME LAYERS
    if fl >= 0: freeze_layer(model.voice_conv1)
    if fl >= 1: freeze_layer(model.voice_conv2)
    if fl >= 2: freeze_layer(model.voice_conv3)
    if fl >= 3: freeze_layer(model.voice_conv4)
    if fl >= 4: freeze_layer(model.kws_conv1)
    if fl >= 5: freeze_layer(model.kws_conv2)
    if fl >= 6: freeze_layer(model.kws_conv3)
    if fl >= 7: freeze_layer(model.kws_conv4)
    model.fc = ai8x.Linear(256, len(classes), bias=False, wide=True)

    model = model.to(device)
    
    optimizer = optim.Adam(model.parameters(), lr=0.0001)
    ms_lr_scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[500, 1000], gamma=0.2)

    best_acc = 0
    best_qat_acc = 0
    best_loss = 0
    best_epoch = 0

    train_acc = []
    train_loss = []
    val_acc = []
    val_loss =[]
    running_class_acc = []

    

    continue_train = True
    epoch = 0
    while(epoch < num_epochs):
        train_start = time.time()
        if epoch > 0 and epoch == qat_policy['start_epoch']:
            print('QAT is starting!')
            # Fuse the BN parameters into conv layers before Quantization Aware Training (QAT)
            ai8x.fuse_bn_layers(model)
            # Switch model from unquantized to quantized for QAT
            ai8x.initiate_qat(model, qat_policy)
            # Model is re-transferred to GPU in case parameters were added
            model.to(device)

        average_acc = 0
        ############ TRAIN SECTION ############
        running_loss = []
        y_pred_train = []
        y_true_train = []
        acc_b = []
        model.train()
        for idx, (inputs, target) in enumerate(train_loader):
            inputs = inputs.to(device)
            target = target.type(torch.int64)
            target = target.to(device)
            optimizer.zero_grad()
            
            model_out = model(inputs)
            target_out = torch.argmax(model_out, dim=1)
            
            y_pred_train.extend(target_out.cpu().numpy())
            y_true_train.extend(target.cpu().numpy())
            
            tp = torch.sum(target_out == target)
            acc_b.extend([(tp / target_out.numel()).detach().item()])

            loss = criterion(model_out, target)     
            loss.backward()
            optimizer.step()
            
            running_loss.append(loss.cpu().detach().numpy())
        
        total_acc = np.mean(acc_b)*100
        mean_loss = np.mean(running_loss)

        # TRAIN ACCURACY / TRAIN LOSS
        train_acc.append(total_acc)
        train_loss.append(mean_loss)
        average_acc += total_acc*0.5

        ############ VALIDATION SECTION ############
        acc_b = []
        y_pred_val = []
        y_true_val = []
        running_v_loss = []
        
        model.eval()
        with torch.no_grad():
            for inputs, target in val_loader:
                inputs = inputs.to(device)
                target = target.to(device)
                model_out = model(inputs)
                target_out = torch.argmax(model_out, dim=1)
                
                y_pred_val.extend(target_out.cpu().numpy())
                y_true_val.extend(target.cpu().numpy())
                
                tp = torch.sum(target_out == target)
                acc_b.extend([(tp / target_out.numel()).detach().item()])

                v_loss = criterion(model_out, target)
                running_v_loss.append(loss.cpu().detach().numpy())

            total_acc = np.mean(acc_b)*100
            mean_loss = np.mean(running_v_loss)

            if epoch == qat_policy['start_epoch']: best_acc = 0
            
            # VALIDATION ACCURACY / VALIDATION LOSS
            val_acc.append(total_acc)
            val_loss.append(mean_loss)
            average_acc += total_acc*0.5
        
        ############ CLASS ACCURACY ############
        class_acc = np.zeros(len(classes))
        for class_num,class_type in enumerate(classes):
            class_count_train = y_true_train.count(class_num)
            class_count_val = y_true_val.count(class_num)

            for t_idx, targ_val in enumerate(y_true_train):
                if targ_val == y_pred_train[t_idx] and targ_val == class_num:
                    class_acc[class_num] += 1/class_count_train*10

            for t_idx, targ_val in enumerate(y_true_val):
                if targ_val == y_pred_val[t_idx] and targ_val == class_num:
                    class_acc[class_num] += 1/class_count_val*90
            
        running_class_acc.append(class_acc)
        
        train_end = time.time()
        print('---------------------------------------------')
        print("\n\n Epoch: {}/{} \tLR: {} \tDur: {:.2f} sec".format(epoch+1, num_epochs, ms_lr_scheduler.get_lr() , (train_end-train_start)))

        ############ CONFUSION MATRIX ############   
        print("\n Training - Confusion Matrix: ")
        plot_confusion(y_true_train, y_pred_train, classes)
        print("\n Validation - Confusion Matrix: ")
        plot_confusion(y_true_val, y_pred_val, classes)
        
        ############ ACC and LOSS ############  
        print('\nTrain Acc : ', train_acc[-1])
        print('Train Loss : ', train_loss[-1])
        print('Val Acc : ', val_acc[-1])
        print('Val Loss : ', val_loss[-1])

        ############ PLOTS ############
        if (epoch%10 == 0 or epoch==num_epochs-1) and epoch > 0:
            best_epoch = checkpoint_extras['best_epoch']
            
            plt.figure(figsize=(20,10),dpi=1000)
            plt.title(model_name)
            plt.subplot(1,2,1)
            plt.plot(np.asarray(running_class_acc)[:,0],color='orange')
            plt.plot(np.asarray(running_class_acc)[:,1],color='yellow')
            plt.plot(val_acc, color ='green')
            plt.plot(train_acc, color = 'red')
            plt.stem(best_epoch,train_acc[best_epoch])
            plt.legend([classes[0],classes[1],'Validation','Train','Checkpoint'])
            plt.title('Train Acc: {:.2f}   Val Acc: {:.2f}'.format(train_acc[best_epoch],val_acc[best_epoch]))
            plt.xlabel('Epochs')
            plt.ylabel('Value')

            plt.subplot(1,2,2)
            plt.plot(val_loss,color='green')
            plt.plot(train_loss,color='red')
            plt.stem(best_epoch,train_loss[best_epoch])
            plt.legend(['Validation','Train','Checkpoint'])
            plt.title('Train Loss: {:.2f}   Train Loss: {:.2f}'.format(train_loss[best_epoch],val_loss[best_epoch]))
            plt.xlabel('Epochs')
            plt.ylabel('Value')

            plt.savefig(checkpoint_dir+model_name+'_'+str(fl)+'.png')
            
            plt.clf()
            plt.cla()
            plt.close()
        
        ############ CHECKPOINT CRITERION ############   
        if average_acc > best_acc:
            best_acc = average_acc

            # SAVE CHECKPOINT
            checkpoint_extras = {'best_ave_acc': best_acc,'best_epoch': epoch}
            # model_prefix = f'{model_name}' if epoch < qat_policy['start_epoch'] else (f'qat_{model_name}')
            # apputils.save_checkpoint(epoch, model_name, model, optimizer=optimizer,
            #                             scheduler=None, extras=checkpoint_extras,
            #                             is_best=True, name=model_prefix,
            #                             dir=checkpoint_dir)

            # PLOT CONFUSION MATRIX AND STAT MEASURES ON TRAIN
            conf_mat_train = confusion_matrix(y_true_train, y_pred_train)
            cm_display_train = ConfusionMatrixDisplay(confusion_matrix = conf_mat_train, display_labels = classes)
            p_train,r_train,f1_train,_= precision_recall_fscore_support(y_true_train, y_pred_train, average=None)
            cm_display_train.plot(cmap= 'Blues',colorbar=False, values_format = 'd')
            plt.title('Preicison: ({:.2f} {:.2f})   Recall: ({:.2f} {:.2f})   F1-Score: ({:.2f} {:.2f})'.format(p_train[0],p_train[1],r_train[0],r_train[1],f1_train[0],f1_train[1]))
            plt.savefig(checkpoint_dir+model_name+'_'+str(fl)+'_cm_train.png')
            plt.clf()
            plt.cla()
            plt.close()

            # PLOT CONFUSION MATRIX AND STAT MEASURES ON VALIDATION
            conf_mat_val = confusion_matrix(y_true_val, y_pred_val)
            cm_display_val = ConfusionMatrixDisplay(confusion_matrix = conf_mat_val, display_labels = classes)
            p_val,r_val,f1_val,_= precision_recall_fscore_support(y_true_val, y_pred_val, average=None)
            cm_display_val.plot(cmap= 'Blues',colorbar=False, values_format = 'd')
            plt.title('Preicison: ({:.2f} {:.2f})   Recall: ({:.2f} {:.2f})   F1-Score: ({:.2f} {:.2f})'.format(p_val[0],p_val[1],r_val[0],r_val[1],f1_val[0],f1_val[1]))
            plt.savefig(checkpoint_dir+model_name+'_'+str(fl)+'_cm_Val.png')
            plt.clf()
            plt.cla()
            plt.close()

            # PLOT ROC ON VAL
            plot_roc_curve(y_true_val, y_pred_val)
            plt.title('AUC: {:.2f}'.format(roc_auc_score(y_true_val, y_pred_val)))
            plt.savefig(checkpoint_dir+model_name+'_'+str(fl)+'_roc_val.png')
            plt.clf()
            plt.cla()
            plt.close()

            print(' --------------------------------------------------------->  EPOCH {:.0f} Checkpoint Saved w/ Acc: {:.2f}% '.format(best_epoch,best_acc))
        
        ############ STOP TRAINING ############ 
        if epoch > num_epochs*0.75 and best_acc > 80 and average_acc > best_acc:
            print('Ending Training, Best Checkpoint Found')
            continue_train = False
            break
        
        ms_lr_scheduler.step()
        epoch += 1
# Out:
# <bound method Module.type of CrossEntropyLoss()>
# Epochs:  3000
# Loss Function:
#  CrossEntropyLoss()
# QAT:
#  {'start_epoch': 100, 'weight_bits': 8}
# Configuring device: MAX78000, simulate=False.
# 169472
# Number of Model Params: 169472
# ---------------------------------------------
#
#
#  Epoch: 1/3000 	LR: [0.0001] 	Dur: 3.58 sec
#
#  Training - Confusion Matrix:
# [[6741 5696]
#  [6785 5814]]
#
#  Validation - Confusion Matrix:
# [[ 684  806]
#  [ 637 1003]]
#
# Train Acc :  50.10147733347756
# Train Loss :  0.7042886
# Val Acc :  53.897762298583984
# Val Loss :  0.70359206
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 52.00%
# ---------------------------------------------
#
#
#  Epoch: 2/3000 	LR: [0.0001] 	Dur: 3.22 sec
#
#  Training - Confusion Matrix:
# [[6031 6406]
#  [5456 7143]]
#
#  Validation - Confusion Matrix:
# [[ 650  840]
#  [ 534 1106]]
#
# Train Acc :  53.11499152864728
# Train Loss :  0.69369984
# Val Acc :  56.10223412513733
# Val Loss :  0.6836463
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 54.61%
# ---------------------------------------------
#
#
#  Epoch: 3/3000 	LR: [0.0001] 	Dur: 3.27 sec
#
#  Training - Confusion Matrix:
# [[6211 6226]
#  [5109 7490]]
#
#  Validation - Confusion Matrix:
# [[ 708  782]
#  [ 563 1077]]
#
# Train Acc :  55.173566511699136
# Train Loss :  0.6882134
# Val Acc :  57.02875256538391
# Val Loss :  0.68244034
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 56.10%
# ---------------------------------------------
#
#
#  Epoch: 4/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[6556 5881]
#  [5363 7236]]
#
#  Validation - Confusion Matrix:
# [[ 741  749]
#  [ 606 1034]]
#
# Train Acc :  55.10499562535968
# Train Loss :  0.68652767
# Val Acc :  56.70926570892334
# Val Loss :  0.6889371
# ---------------------------------------------
#
#
#  Epoch: 5/3000 	LR: [0.0001] 	Dur: 3.20 sec
#
#  Training - Confusion Matrix:
# [[6804 5633]
#  [5278 7321]]
#
#  Validation - Confusion Matrix:
# [[ 775  715]
#  [ 569 1071]]
#
# Train Acc :  56.56965715544564
# Train Loss :  0.6812528
# Val Acc :  58.9776337146759
# Val Loss :  0.6780761
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 57.77%
# ---------------------------------------------
#
#
#  Epoch: 6/3000 	LR: [0.0001] 	Dur: 3.13 sec
#
#  Training - Confusion Matrix:
# [[6900 5537]
#  [5021 7578]]
#
#  Validation - Confusion Matrix:
# [[ 800  690]
#  [ 571 1069]]
#
# Train Acc :  58.241913999829976
# Train Loss :  0.6762891
# Val Acc :  59.71245765686035
# Val Loss :  0.6738764
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 58.98%
# ---------------------------------------------
#
#
#  Epoch: 7/3000 	LR: [0.0001] 	Dur: 3.32 sec
#
#  Training - Confusion Matrix:
# [[6959 5478]
#  [4868 7731]]
#
#  Validation - Confusion Matrix:
# [[ 786  704]
#  [ 560 1080]]
#
# Train Acc :  58.56778877122062
# Train Loss :  0.67423296
# Val Acc :  59.61661338806152
# Val Loss :  0.68006337
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 59.09%
# ---------------------------------------------
#
#
#  Epoch: 8/3000 	LR: [0.0001] 	Dur: 3.05 sec
#
#  Training - Confusion Matrix:
# [[6956 5481]
#  [4747 7852]]
#
#  Validation - Confusion Matrix:
# [[ 824  666]
#  [ 586 1054]]
#
# Train Acc :  58.676090410777505
# Train Loss :  0.67306525
# Val Acc :  59.99999642372131
# Val Loss :  0.6833857
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 59.34%
# ---------------------------------------------
#
#
#  Epoch: 9/3000 	LR: [0.0001] 	Dur: 3.14 sec
#
#  Training - Confusion Matrix:
# [[7175 5262]
#  [4797 7802]]
#
#  Validation - Confusion Matrix:
# [[ 858  632]
#  [ 572 1068]]
#
# Train Acc :  59.40335648400443
# Train Loss :  0.670507
# Val Acc :  61.533546447753906
# Val Loss :  0.68025404
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 60.47%
# ---------------------------------------------
#
#
#  Epoch: 10/3000 	LR: [0.0001] 	Dur: 3.16 sec
#
#  Training - Confusion Matrix:
# [[7471 4966]
#  [4826 7773]]
#
#  Validation - Confusion Matrix:
# [[ 869  621]
#  [ 604 1036]]
#
# Train Acc :  60.88594198226929
# Train Loss :  0.6663433
# Val Acc :  60.86261868476868
# Val Loss :  0.6718922
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 60.87%
# ---------------------------------------------
#
#
#  Epoch: 11/3000 	LR: [0.0001] 	Dur: 3.26 sec
#
#  Training - Confusion Matrix:
# [[7520 4917]
#  [4887 7712]]
#
#  Validation - Confusion Matrix:
# [[ 850  640]
#  [ 576 1064]]
#
# Train Acc :  60.761384453092305
# Train Loss :  0.66336673
# Val Acc :  61.15015745162964
# Val Loss :  0.6613476
#  --------------------------------------------------------->  EPOCH 9 Checkpoint Saved w/ Acc: 60.96%
# ---------------------------------------------
#
#
#  Epoch: 12/3000 	LR: [0.0001] 	Dur: 3.27 sec
#
#  Training - Confusion Matrix:
# [[7516 4921]
#  [4788 7811]]
#
#  Validation - Confusion Matrix:
# [[ 859  631]
#  [ 582 1058]]
#
# Train Acc :  61.06515015874591
# Train Loss :  0.66118294
# Val Acc :  61.246007680892944
# Val Loss :  0.66001785
#  --------------------------------------------------------->  EPOCH 9 Checkpoint Saved w/ Acc: 61.16%
# ---------------------------------------------
#
#
#  Epoch: 13/3000 	LR: [0.0001] 	Dur: 3.11 sec
#
#  Training - Confusion Matrix:
# [[7589 4848]
#  [4773 7826]]
#
#  Validation - Confusion Matrix:
# [[ 898  592]
#  [ 609 1031]]
#
# Train Acc :  61.868297202246524
# Train Loss :  0.65905964
# Val Acc :  61.629390716552734
# Val Loss :  0.6540819
#  --------------------------------------------------------->  EPOCH 9 Checkpoint Saved w/ Acc: 61.75%
# ---------------------------------------------
#
#
#  Epoch: 14/3000 	LR: [0.0001] 	Dur: 2.98 sec
#
#  Training - Confusion Matrix:
# [[7715 4722]
#  [4729 7870]]
#
#  Validation - Confusion Matrix:
# [[902 588]
#  [648 992]]
#
# Train Acc :  61.52389219829014
# Train Loss :  0.6576601
# Val Acc :  60.511183738708496
# Val Loss :  0.6668973
# ---------------------------------------------
#
#
#  Epoch: 15/3000 	LR: [0.0001] 	Dur: 3.23 sec
#
#  Training - Confusion Matrix:
# [[7752 4685]
#  [4684 7915]]
#
#  Validation - Confusion Matrix:
# [[922 568]
#  [667 973]]
#
# Train Acc :  62.526657751628335
# Train Loss :  0.65499574
# Val Acc :  60.543131828308105
# Val Loss :  0.66220033
# ---------------------------------------------
#
#
#  Epoch: 16/3000 	LR: [0.0001] 	Dur: 2.98 sec
#
#  Training - Confusion Matrix:
# [[7660 4777]
#  [4625 7974]]
#
#  Validation - Confusion Matrix:
# [[915 575]
#  [678 962]]
#
# Train Acc :  62.3012900352478
# Train Loss :  0.6536388
# Val Acc :  59.968048334121704
# Val Loss :  0.65618384
# ---------------------------------------------
#
#
#  Epoch: 17/3000 	LR: [0.0001] 	Dur: 3.11 sec
#
#  Training - Confusion Matrix:
# [[7845 4592]
#  [4697 7902]]
#
#  Validation - Confusion Matrix:
# [[947 543]
#  [671 969]]
#
# Train Acc :  63.10892530850002
# Train Loss :  0.6515092
# Val Acc :  61.21405363082886
# Val Loss :  0.65564424
#  --------------------------------------------------------->  EPOCH 9 Checkpoint Saved w/ Acc: 62.16%
# ---------------------------------------------
#
#
#  Epoch: 18/3000 	LR: [0.0001] 	Dur: 3.01 sec
#
#  Training - Confusion Matrix:
# [[8025 4412]
#  [4774 7825]]
#
#  Validation - Confusion Matrix:
# [[ 958  532]
#  [ 632 1008]]
#
# Train Acc :  62.889229399817324
# Train Loss :  0.649834
# Val Acc :  62.81149983406067
# Val Loss :  0.65373564
#  --------------------------------------------------------->  EPOCH 9 Checkpoint Saved w/ Acc: 62.85%
# ---------------------------------------------
#
#
#  Epoch: 19/3000 	LR: [0.0001] 	Dur: 3.30 sec
#
#  Training - Confusion Matrix:
# [[8156 4281]
#  [4757 7842]]
#
#  Validation - Confusion Matrix:
# [[ 978  512]
#  [ 614 1026]]
#
# Train Acc :  63.87407183647156
# Train Loss :  0.6469255
# Val Acc :  64.02555704116821
# Val Loss :  0.65152884
#  --------------------------------------------------------->  EPOCH 9 Checkpoint Saved w/ Acc: 63.95%
# ---------------------------------------------
#
#
#  Epoch: 20/3000 	LR: [0.0001] 	Dur: 3.17 sec
#
#  Training - Confusion Matrix:
# [[8193 4244]
#  [4833 7766]]
#
#  Validation - Confusion Matrix:
# [[ 969  521]
#  [ 584 1056]]
#
# Train Acc :  63.65534578050885
# Train Loss :  0.6463944
# Val Acc :  64.69648480415344
# Val Loss :  0.65562135
#  --------------------------------------------------------->  EPOCH 9 Checkpoint Saved w/ Acc: 64.18%
# ---------------------------------------------
#
#
#  Epoch: 21/3000 	LR: [0.0001] 	Dur: 3.14 sec
#
#  Training - Confusion Matrix:
# [[8026 4411]
#  [4662 7937]]
#
#  Validation - Confusion Matrix:
# [[ 995  495]
#  [ 592 1048]]
#
# Train Acc :  63.25577412332807
# Train Loss :  0.6454883
# Val Acc :  65.27156233787537
# Val Loss :  0.65492684
#  --------------------------------------------------------->  EPOCH 19 Checkpoint Saved w/ Acc: 64.26%
# ---------------------------------------------
#
#
#  Epoch: 22/3000 	LR: [0.0001] 	Dur: 3.16 sec
#
#  Training - Confusion Matrix:
# [[8169 4268]
#  [4680 7919]]
#
#  Validation - Confusion Matrix:
# [[ 962  528]
#  [ 591 1049]]
#
# Train Acc :  64.10526207515171
# Train Loss :  0.640891
# Val Acc :  64.24919962882996
# Val Loss :  0.64099485
# ---------------------------------------------
#
#
#  Epoch: 23/3000 	LR: [0.0001] 	Dur: 3.18 sec
#
#  Training - Confusion Matrix:
# [[8308 4129]
#  [4828 7771]]
#
#  Validation - Confusion Matrix:
# [[ 986  504]
#  [ 596 1044]]
#
# Train Acc :  64.18414541653225
# Train Loss :  0.64124906
# Val Acc :  64.85623121261597
# Val Loss :  0.6463223
#  --------------------------------------------------------->  EPOCH 19 Checkpoint Saved w/ Acc: 64.52%
# ---------------------------------------------
#
#
#  Epoch: 24/3000 	LR: [0.0001] 	Dur: 3.02 sec
#
#  Training - Confusion Matrix:
# [[8336 4101]
#  [4775 7824]]
#
#  Validation - Confusion Matrix:
# [[ 975  515]
#  [ 591 1049]]
#
# Train Acc :  64.1909692968641
# Train Loss :  0.6396783
# Val Acc :  64.66453671455383
# Val Loss :  0.64440405
# ---------------------------------------------
#
#
#  Epoch: 25/3000 	LR: [0.0001] 	Dur: 3.07 sec
#
#  Training - Confusion Matrix:
# [[8383 4054]
#  [4823 7776]]
#
#  Validation - Confusion Matrix:
# [[ 967  523]
#  [ 608 1032]]
#
# Train Acc :  64.40802642277309
# Train Loss :  0.6387502
# Val Acc :  63.86581063270569
# Val Loss :  0.64007604
# ---------------------------------------------
#
#
#  Epoch: 26/3000 	LR: [0.0001] 	Dur: 3.11 sec
#
#  Training - Confusion Matrix:
# [[8401 4036]
#  [4790 7809]]
#
#  Validation - Confusion Matrix:
# [[ 998  492]
#  [ 594 1046]]
#
# Train Acc :  64.64103715760368
# Train Loss :  0.63837063
# Val Acc :  65.30351042747498
# Val Loss :  0.64058506
#  --------------------------------------------------------->  EPOCH 19 Checkpoint Saved w/ Acc: 64.97%
# ---------------------------------------------
#
#
#  Epoch: 27/3000 	LR: [0.0001] 	Dur: 3.26 sec
#
#  Training - Confusion Matrix:
# [[8419 4018]
#  [4797 7802]]
#
#  Validation - Confusion Matrix:
# [[ 985  505]
#  [ 598 1042]]
#
# Train Acc :  64.51399326324463
# Train Loss :  0.63906723
# Val Acc :  64.76038098335266
# Val Loss :  0.65359795
# ---------------------------------------------
#
#
#  Epoch: 28/3000 	LR: [0.0001] 	Dur: 3.08 sec
#
#  Training - Confusion Matrix:
# [[8390 4047]
#  [4776 7823]]
#
#  Validation - Confusion Matrix:
# [[ 985  505]
#  [ 598 1042]]
#
# Train Acc :  64.65150032724652
# Train Loss :  0.63627094
# Val Acc :  64.76038098335266
# Val Loss :  0.6375019
# ---------------------------------------------
#
#
#  Epoch: 29/3000 	LR: [0.0001] 	Dur: 2.99 sec
#
#  Training - Confusion Matrix:
# [[8414 4023]
#  [4763 7836]]
#
#  Validation - Confusion Matrix:
# [[1008  482]
#  [ 598 1042]]
#
# Train Acc :  64.83568208558219
# Train Loss :  0.6364827
# Val Acc :  65.49520492553711
# Val Loss :  0.6429945
#  --------------------------------------------------------->  EPOCH 19 Checkpoint Saved w/ Acc: 65.17%
# ---------------------------------------------
#
#
#  Epoch: 30/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[8525 3912]
#  [4791 7808]]
#
#  Validation - Confusion Matrix:
# [[ 998  492]
#  [ 622 1018]]
#
# Train Acc :  65.18029996326992
# Train Loss :  0.63356453
# Val Acc :  64.40894603729248
# Val Loss :  0.6335141
# ---------------------------------------------
#
#
#  Epoch: 31/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8558 3879]
#  [4849 7750]]
#
#  Validation - Confusion Matrix:
# [[1002  488]
#  [ 606 1034]]
#
# Train Acc :  64.98283403260368
# Train Loss :  0.6349058
# Val Acc :  65.04791975021362
# Val Loss :  0.6493131
# ---------------------------------------------
#
#
#  Epoch: 32/3000 	LR: [0.0001] 	Dur: 3.18 sec
#
#  Training - Confusion Matrix:
# [[8524 3913]
#  [4823 7776]]
#
#  Validation - Confusion Matrix:
# [[ 994  496]
#  [ 596 1044]]
#
# Train Acc :  65.09277309690204
# Train Loss :  0.63406974
# Val Acc :  65.11182188987732
# Val Loss :  0.6370869
# ---------------------------------------------
#
#
#  Epoch: 33/3000 	LR: [0.0001] 	Dur: 3.31 sec
#
#  Training - Confusion Matrix:
# [[8592 3845]
#  [4828 7771]]
#
#  Validation - Confusion Matrix:
# [[1007  483]
#  [ 620 1020]]
#
# Train Acc :  64.98168110847473
# Train Loss :  0.63065386
# Val Acc :  64.76038098335266
# Val Loss :  0.63185745
# ---------------------------------------------
#
#
#  Epoch: 34/3000 	LR: [0.0001] 	Dur: 3.34 sec
#
#  Training - Confusion Matrix:
# [[8669 3768]
#  [4951 7648]]
#
#  Validation - Confusion Matrix:
# [[1011  479]
#  [ 619 1021]]
#
# Train Acc :  65.34504124096462
# Train Loss :  0.63024384
# Val Acc :  64.92012739181519
# Val Loss :  0.626388
# ---------------------------------------------
#
#
#  Epoch: 35/3000 	LR: [0.0001] 	Dur: 3.36 sec
#
#  Training - Confusion Matrix:
# [[8637 3800]
#  [4863 7736]]
#
#  Validation - Confusion Matrix:
# [[ 993  497]
#  [ 597 1043]]
#
# Train Acc :  64.90628634180341
# Train Loss :  0.6334101
# Val Acc :  65.04791975021362
# Val Loss :  0.6499504
# ---------------------------------------------
#
#
#  Epoch: 36/3000 	LR: [0.0001] 	Dur: 3.28 sec
#
#  Training - Confusion Matrix:
# [[8558 3879]
#  [4826 7773]]
#
#  Validation - Confusion Matrix:
# [[ 989  501]
#  [ 607 1033]]
#
# Train Acc :  65.11818766593933
# Train Loss :  0.63072586
# Val Acc :  64.60064053535461
# Val Loss :  0.636057
# ---------------------------------------------
#
#
#  Epoch: 37/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8632 3805]
#  [4884 7715]]
#
#  Validation - Confusion Matrix:
# [[1016  474]
#  [ 621 1019]]
#
# Train Acc :  65.20155923707145
# Train Loss :  0.62930673
# Val Acc :  65.01597166061401
# Val Loss :  0.6300593
# ---------------------------------------------
#
#
#  Epoch: 38/3000 	LR: [0.0001] 	Dur: 3.37 sec
#
#  Training - Confusion Matrix:
# [[8618 3819]
#  [4805 7794]]
#
#  Validation - Confusion Matrix:
# [[1010  480]
#  [ 596 1044]]
#
# Train Acc :  65.62123894691467
# Train Loss :  0.62791663
# Val Acc :  65.62300324440002
# Val Loss :  0.6310199
#  --------------------------------------------------------->  EPOCH 28 Checkpoint Saved w/ Acc: 65.62%
# ---------------------------------------------
#
#
#  Epoch: 39/3000 	LR: [0.0001] 	Dur: 3.16 sec
#
#  Training - Confusion Matrix:
# [[8624 3813]
#  [4769 7830]]
#
#  Validation - Confusion Matrix:
# [[1018  472]
#  [ 613 1027]]
#
# Train Acc :  65.40933677128383
# Train Loss :  0.6300581
# Val Acc :  65.33546447753906
# Val Loss :  0.63688904
# ---------------------------------------------
#
#
#  Epoch: 40/3000 	LR: [0.0001] 	Dur: 3.10 sec
#
#  Training - Confusion Matrix:
# [[8685 3752]
#  [4810 7789]]
#
#  Validation - Confusion Matrix:
# [[1010  480]
#  [ 608 1032]]
#
# Train Acc :  65.47909123556954
# Train Loss :  0.6283311
# Val Acc :  65.23961424827576
# Val Loss :  0.6383053
# ---------------------------------------------
#
#
#  Epoch: 41/3000 	LR: [0.0001] 	Dur: 3.04 sec
#
#  Training - Confusion Matrix:
# [[8606 3831]
#  [4777 7822]]
#
#  Validation - Confusion Matrix:
# [[1009  481]
#  [ 612 1028]]
#
# Train Acc :  65.5392016683306
# Train Loss :  0.62818104
# Val Acc :  65.07987380027771
# Val Loss :  0.63003224
# ---------------------------------------------
#
#
#  Epoch: 42/3000 	LR: [0.0001] 	Dur: 3.47 sec
#
#  Training - Confusion Matrix:
# [[8648 3789]
#  [4705 7894]]
#
#  Validation - Confusion Matrix:
# [[1002  488]
#  [ 601 1039]]
#
# Train Acc :  66.07464296477181
# Train Loss :  0.62602794
# Val Acc :  65.20766615867615
# Val Loss :  0.6295337
#  --------------------------------------------------------->  EPOCH 37 Checkpoint Saved w/ Acc: 65.64%
# ---------------------------------------------
#
#
#  Epoch: 43/3000 	LR: [0.0001] 	Dur: 3.27 sec
#
#  Training - Confusion Matrix:
# [[8650 3787]
#  [4690 7909]]
#
#  Validation - Confusion Matrix:
# [[ 998  492]
#  [ 615 1025]]
#
# Train Acc :  65.83068455968585
# Train Loss :  0.62620795
# Val Acc :  64.63258862495422
# Val Loss :  0.63445514
# ---------------------------------------------
#
#
#  Epoch: 44/3000 	LR: [0.0001] 	Dur: 3.44 sec
#
#  Training - Confusion Matrix:
# [[8653 3784]
#  [4655 7944]]
#
#  Validation - Confusion Matrix:
# [[ 995  495]
#  [ 584 1056]]
#
# Train Acc :  66.37674059186664
# Train Loss :  0.622677
# Val Acc :  65.52715301513672
# Val Loss :  0.6255004
#  --------------------------------------------------------->  EPOCH 37 Checkpoint Saved w/ Acc: 65.95%
# ---------------------------------------------
#
#
#  Epoch: 45/3000 	LR: [0.0001] 	Dur: 3.37 sec
#
#  Training - Confusion Matrix:
# [[8575 3862]
#  [4609 7990]]
#
#  Validation - Confusion Matrix:
# [[1010  480]
#  [ 610 1030]]
#
# Train Acc :  65.93431489808219
# Train Loss :  0.6245713
# Val Acc :  65.17571806907654
# Val Loss :  0.62919945
# ---------------------------------------------
#
#
#  Epoch: 46/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8643 3794]
#  [4689 7910]]
#
#  Validation - Confusion Matrix:
# [[1022  468]
#  [ 608 1032]]
#
# Train Acc :  65.78218936920166
# Train Loss :  0.62539333
# Val Acc :  65.62300324440002
# Val Loss :  0.6315601
# ---------------------------------------------
#
#
#  Epoch: 47/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8643 3794]
#  [4681 7918]]
#
#  Validation - Confusion Matrix:
# [[1017  473]
#  [ 613 1027]]
#
# Train Acc :  66.14090970584324
# Train Loss :  0.62517613
# Val Acc :  65.30351042747498
# Val Loss :  0.64184546
# ---------------------------------------------
#
#
#  Epoch: 48/3000 	LR: [0.0001] 	Dur: 3.25 sec
#
#  Training - Confusion Matrix:
# [[8606 3831]
#  [4602 7997]]
#
#  Validation - Confusion Matrix:
# [[1010  480]
#  [ 604 1036]]
#
# Train Acc :  66.20468923023769
# Train Loss :  0.6231085
# Val Acc :  65.36741256713867
# Val Loss :  0.6335954
# ---------------------------------------------
#
#
#  Epoch: 49/3000 	LR: [0.0001] 	Dur: 3.18 sec
#
#  Training - Confusion Matrix:
# [[8575 3862]
#  [4600 7999]]
#
#  Validation - Confusion Matrix:
# [[1018  472]
#  [ 572 1068]]
#
# Train Acc :  66.07597725731986
# Train Loss :  0.62152463
# Val Acc :  66.64536595344543
# Val Loss :  0.6230665
#  --------------------------------------------------------->  EPOCH 37 Checkpoint Saved w/ Acc: 66.36%
# ---------------------------------------------
#
#
#  Epoch: 50/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8683 3754]
#  [4554 8045]]
#
#  Validation - Confusion Matrix:
# [[1016  474]
#  [ 577 1063]]
#
# Train Acc :  66.69579148292542
# Train Loss :  0.61922836
# Val Acc :  66.42172336578369
# Val Loss :  0.61641765
#  --------------------------------------------------------->  EPOCH 37 Checkpoint Saved w/ Acc: 66.56%
# ---------------------------------------------
#
#
#  Epoch: 51/3000 	LR: [0.0001] 	Dur: 3.03 sec
#
#  Training - Confusion Matrix:
# [[8648 3789]
#  [4518 8081]]
#
#  Validation - Confusion Matrix:
# [[1001  489]
#  [ 569 1071]]
#
# Train Acc :  66.42359750611442
# Train Loss :  0.6223398
# Val Acc :  66.19808077812195
# Val Loss :  0.6379485
# ---------------------------------------------
#
#
#  Epoch: 52/3000 	LR: [0.0001] 	Dur: 3.49 sec
#
#  Training - Confusion Matrix:
# [[8657 3780]
#  [4551 8048]]
#
#  Validation - Confusion Matrix:
# [[1019  471]
#  [ 569 1071]]
#
# Train Acc :  66.31232329777309
# Train Loss :  0.62011534
# Val Acc :  66.77316427230835
# Val Loss :  0.6308853
# ---------------------------------------------
#
#
#  Epoch: 53/3000 	LR: [0.0001] 	Dur: 3.09 sec
#
#  Training - Confusion Matrix:
# [[8544 3893]
#  [4513 8086]]
#
#  Validation - Confusion Matrix:
# [[1009  481]
#  [ 568 1072]]
#
# Train Acc :  66.46426745823452
# Train Loss :  0.61808765
# Val Acc :  66.48561954498291
# Val Loss :  0.6170205
# ---------------------------------------------
#
#
#  Epoch: 54/3000 	LR: [0.0001] 	Dur: 3.11 sec
#
#  Training - Confusion Matrix:
# [[8652 3785]
#  [4512 8087]]
#
#  Validation - Confusion Matrix:
# [[1039  451]
#  [ 591 1049]]
#
# Train Acc :  66.78929243768964
# Train Loss :  0.61864364
# Val Acc :  66.70926213264465
# Val Loss :  0.6203287
#  --------------------------------------------------------->  EPOCH 49 Checkpoint Saved w/ Acc: 66.75%
# ---------------------------------------------
#
#
#  Epoch: 55/3000 	LR: [0.0001] 	Dur: 3.02 sec
#
#  Training - Confusion Matrix:
# [[8815 3622]
#  [4593 8006]]
#
#  Validation - Confusion Matrix:
# [[1029  461]
#  [ 583 1057]]
#
# Train Acc :  67.10285374096462
# Train Loss :  0.6172678
# Val Acc :  66.64536595344543
# Val Loss :  0.62397355
#  --------------------------------------------------------->  EPOCH 49 Checkpoint Saved w/ Acc: 66.87%
# ---------------------------------------------
#
#
#  Epoch: 56/3000 	LR: [0.0001] 	Dur: 3.11 sec
#
#  Training - Confusion Matrix:
# [[8714 3723]
#  [4589 8010]]
#
#  Validation - Confusion Matrix:
# [[1027  463]
#  [ 577 1063]]
#
# Train Acc :  66.59913573946271
# Train Loss :  0.6168586
# Val Acc :  66.77316427230835
# Val Loss :  0.6224536
# ---------------------------------------------
#
#
#  Epoch: 57/3000 	LR: [0.0001] 	Dur: 3.10 sec
#
#  Training - Confusion Matrix:
# [[8657 3780]
#  [4564 8035]]
#
#  Validation - Confusion Matrix:
# [[1040  450]
#  [ 572 1068]]
#
# Train Acc :  66.62536944661822
# Train Loss :  0.620089
# Val Acc :  67.34824180603027
# Val Loss :  0.638481
#  --------------------------------------------------------->  EPOCH 49 Checkpoint Saved w/ Acc: 66.99%
# ---------------------------------------------
#
#
#  Epoch: 58/3000 	LR: [0.0001] 	Dur: 3.07 sec
#
#  Training - Confusion Matrix:
# [[8771 3666]
#  [4539 8060]]
#
#  Validation - Confusion Matrix:
# [[1044  446]
#  [ 558 1082]]
#
# Train Acc :  67.24800382341657
# Train Loss :  0.6146731
# Val Acc :  67.9233193397522
# Val Loss :  0.61244893
#  --------------------------------------------------------->  EPOCH 49 Checkpoint Saved w/ Acc: 67.59%
# ---------------------------------------------
#
#
#  Epoch: 59/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[8745 3692]
#  [4533 8066]]
#
#  Validation - Confusion Matrix:
# [[1049  441]
#  [ 569 1071]]
#
# Train Acc :  66.87499965940204
# Train Loss :  0.61604875
# Val Acc :  67.73163080215454
# Val Loss :  0.63086975
# ---------------------------------------------
#
#
#  Epoch: 60/3000 	LR: [0.0001] 	Dur: 3.27 sec
#
#  Training - Confusion Matrix:
# [[8712 3725]
#  [4578 8021]]
#
#  Validation - Confusion Matrix:
# [[1052  438]
#  [ 579 1061]]
#
# Train Acc :  66.60295724868774
# Train Loss :  0.61742455
# Val Acc :  67.5079882144928
# Val Loss :  0.6346004
# ---------------------------------------------
#
#
#  Epoch: 61/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[8833 3604]
#  [4638 7961]]
#
#  Validation - Confusion Matrix:
# [[1070  420]
#  [ 590 1050]]
#
# Train Acc :  66.76057151385716
# Train Loss :  0.61491257
# Val Acc :  67.73163080215454
# Val Loss :  0.6316645
# ---------------------------------------------
#
#
#  Epoch: 62/3000 	LR: [0.0001] 	Dur: 3.29 sec
#
#  Training - Confusion Matrix:
# [[8792 3645]
#  [4652 7947]]
#
#  Validation - Confusion Matrix:
# [[1058  432]
#  [ 582 1058]]
#
# Train Acc :  67.00983813830784
# Train Loss :  0.61507714
# Val Acc :  67.60383248329163
# Val Loss :  0.6155789
# ---------------------------------------------
#
#
#  Epoch: 63/3000 	LR: [0.0001] 	Dur: 3.28 sec
#
#  Training - Confusion Matrix:
# [[8781 3656]
#  [4582 8017]]
#
#  Validation - Confusion Matrix:
# [[1059  431]
#  [ 584 1056]]
#
# Train Acc :  66.66425040790013
# Train Loss :  0.61614126
# Val Acc :  67.57188439369202
# Val Loss :  0.6338416
# ---------------------------------------------
#
#
#  Epoch: 64/3000 	LR: [0.0001] 	Dur: 3.18 sec
#
#  Training - Confusion Matrix:
# [[8694 3743]
#  [4471 8128]]
#
#  Validation - Confusion Matrix:
# [[1054  436]
#  [ 586 1054]]
#
# Train Acc :  67.05120546477181
# Train Loss :  0.6143568
# Val Acc :  67.34824180603027
# Val Loss :  0.6214139
# ---------------------------------------------
#
#
#  Epoch: 65/3000 	LR: [0.0001] 	Dur: 3.25 sec
#
#  Training - Confusion Matrix:
# [[8717 3720]
#  [4521 8078]]
#
#  Validation - Confusion Matrix:
# [[1034  456]
#  [ 596 1044]]
#
# Train Acc :  67.15001378740583
# Train Loss :  0.6129617
# Val Acc :  66.38977527618408
# Val Loss :  0.6170045
# ---------------------------------------------
#
#
#  Epoch: 66/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8778 3659]
#  [4625 7974]]
#
#  Validation - Confusion Matrix:
# [[1052  438]
#  [ 597 1043]]
#
# Train Acc :  66.64165599005563
# Train Loss :  0.6142303
# Val Acc :  66.9329047203064
# Val Loss :  0.619418
# ---------------------------------------------
#
#
#  Epoch: 67/3000 	LR: [0.0001] 	Dur: 3.16 sec
#
#  Training - Confusion Matrix:
# [[8872 3565]
#  [4545 8054]]
#
#  Validation - Confusion Matrix:
# [[1051  439]
#  [ 607 1033]]
#
# Train Acc :  67.57933752877372
# Train Loss :  0.6096632
# Val Acc :  66.58146977424622
# Val Loss :  0.6076795
# ---------------------------------------------
#
#
#  Epoch: 68/3000 	LR: [0.0001] 	Dur: 3.38 sec
#
#  Training - Confusion Matrix:
# [[8840 3597]
#  [4623 7976]]
#
#  Validation - Confusion Matrix:
# [[1050  440]
#  [ 593 1047]]
#
# Train Acc :  67.05784712518964
# Train Loss :  0.6142415
# Val Acc :  66.99680685997009
# Val Loss :  0.62632334
# ---------------------------------------------
#
#
#  Epoch: 69/3000 	LR: [0.0001] 	Dur: 3.07 sec
#
#  Training - Confusion Matrix:
# [[8864 3573]
#  [4597 8002]]
#
#  Validation - Confusion Matrix:
# [[1056  434]
#  [ 600 1040]]
#
# Train Acc :  67.28737013680595
# Train Loss :  0.61153847
# Val Acc :  66.964852809906
# Val Loss :  0.6147257
# ---------------------------------------------
#
#
#  Epoch: 70/3000 	LR: [0.0001] 	Dur: 3.19 sec
#
#  Training - Confusion Matrix:
# [[8761 3676]
#  [4548 8051]]
#
#  Validation - Confusion Matrix:
# [[1063  427]
#  [ 594 1046]]
#
# Train Acc :  67.01632823262896
# Train Loss :  0.61338145
# Val Acc :  67.38018989562988
# Val Loss :  0.62162584
# ---------------------------------------------
#
#
#  Epoch: 71/3000 	LR: [0.0001] 	Dur: 3.29 sec
#
#  Training - Confusion Matrix:
# [[8870 3567]
#  [4634 7965]]
#
#  Validation - Confusion Matrix:
# [[1070  420]
#  [ 607 1033]]
#
# Train Acc :  66.6830233165196
# Train Loss :  0.6132123
# Val Acc :  67.18849539756775
# Val Loss :  0.624715
# ---------------------------------------------
#
#
#  Epoch: 72/3000 	LR: [0.0001] 	Dur: 3.46 sec
#
#  Training - Confusion Matrix:
# [[8888 3549]
#  [4602 7997]]
#
#  Validation - Confusion Matrix:
# [[1068  422]
#  [ 601 1039]]
#
# Train Acc :  67.29850002697536
# Train Loss :  0.6121157
# Val Acc :  67.31629371643066
# Val Loss :  0.6223975
# ---------------------------------------------
#
#
#  Epoch: 73/3000 	LR: [0.0001] 	Dur: 3.12 sec
#
#  Training - Confusion Matrix:
# [[8782 3655]
#  [4510 8089]]
#
#  Validation - Confusion Matrix:
# [[1066  424]
#  [ 596 1044]]
#
# Train Acc :  67.44264960289001
# Train Loss :  0.6102938
# Val Acc :  67.41213798522949
# Val Loss :  0.61276525
# ---------------------------------------------
#
#
#  Epoch: 74/3000 	LR: [0.0001] 	Dur: 3.02 sec
#
#  Training - Confusion Matrix:
# [[8778 3659]
#  [4482 8117]]
#
#  Validation - Confusion Matrix:
# [[1047  443]
#  [ 571 1069]]
#
# Train Acc :  67.38851411002022
# Train Loss :  0.61069447
# Val Acc :  67.60383248329163
# Val Loss :  0.6229072
# ---------------------------------------------
#
#
#  Epoch: 75/3000 	LR: [0.0001] 	Dur: 3.41 sec
#
#  Training - Confusion Matrix:
# [[8805 3632]
#  [4595 8004]]
#
#  Validation - Confusion Matrix:
# [[1064  426]
#  [ 584 1056]]
#
# Train Acc :  67.2264107636043
# Train Loss :  0.61183864
# Val Acc :  67.73163080215454
# Val Loss :  0.6110027
# ---------------------------------------------
#
#
#  Epoch: 76/3000 	LR: [0.0001] 	Dur: 3.28 sec
#
#  Training - Confusion Matrix:
# [[8936 3501]
#  [4663 7936]]
#
#  Validation - Confusion Matrix:
# [[1052  438]
#  [ 574 1066]]
#
# Train Acc :  67.115318775177
# Train Loss :  0.6097411
# Val Acc :  67.66772866249084
# Val Loss :  0.61145794
# ---------------------------------------------
#
#
#  Epoch: 77/3000 	LR: [0.0001] 	Dur: 3.12 sec
#
#  Training - Confusion Matrix:
# [[8881 3556]
#  [4529 8070]]
#
#  Validation - Confusion Matrix:
# [[1050  440]
#  [ 583 1057]]
#
# Train Acc :  67.52868975911822
# Train Loss :  0.6060552
# Val Acc :  67.31629371643066
# Val Loss :  0.6047896
# ---------------------------------------------
#
#
#  Epoch: 78/3000 	LR: [0.0001] 	Dur: 3.24 sec
#
#  Training - Confusion Matrix:
# [[8855 3582]
#  [4591 8008]]
#
#  Validation - Confusion Matrix:
# [[1030  460]
#  [ 579 1061]]
#
# Train Acc :  67.41474781717572
# Train Loss :  0.60818046
# Val Acc :  66.80511236190796
# Val Loss :  0.60656124
# ---------------------------------------------
#
#
#  Epoch: 79/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8829 3608]
#  [4556 8043]]
#
#  Validation - Confusion Matrix:
# [[1051  439]
#  [ 578 1062]]
#
# Train Acc :  67.39100047520229
# Train Loss :  0.6113414
# Val Acc :  67.5079882144928
# Val Loss :  0.6189324
# ---------------------------------------------
#
#
#  Epoch: 80/3000 	LR: [0.0001] 	Dur: 3.14 sec
#
#  Training - Confusion Matrix:
# [[8856 3581]
#  [4566 8033]]
#
#  Validation - Confusion Matrix:
# [[1071  419]
#  [ 585 1055]]
#
# Train Acc :  67.36758777073452
# Train Loss :  0.6103331
# Val Acc :  67.9233193397522
# Val Loss :  0.6163256
#  --------------------------------------------------------->  EPOCH 57 Checkpoint Saved w/ Acc: 67.65%
# ---------------------------------------------
#
#
#  Epoch: 81/3000 	LR: [0.0001] 	Dur: 3.26 sec
#
#  Training - Confusion Matrix:
# [[8865 3572]
#  [4591 8008]]
#
#  Validation - Confusion Matrix:
# [[1053  437]
#  [ 592 1048]]
#
# Train Acc :  67.25664734840393
# Train Loss :  0.60911983
# Val Acc :  67.12459921836853
# Val Loss :  0.6168257
# ---------------------------------------------
#
#
#  Epoch: 82/3000 	LR: [0.0001] 	Dur: 3.58 sec
#
#  Training - Confusion Matrix:
# [[8891 3546]
#  [4630 7969]]
#
#  Validation - Confusion Matrix:
# [[1046  444]
#  [ 589 1051]]
#
# Train Acc :  67.04589809690204
# Train Loss :  0.61186564
# Val Acc :  66.99680685997009
# Val Loss :  0.6285281
# ---------------------------------------------
#
#
#  Epoch: 83/3000 	LR: [0.0001] 	Dur: 3.23 sec
#
#  Training - Confusion Matrix:
# [[8818 3619]
#  [4556 8043]]
#
#  Validation - Confusion Matrix:
# [[1051  439]
#  [ 575 1065]]
#
# Train Acc :  67.26993152073452
# Train Loss :  0.6102627
# Val Acc :  67.60383248329163
# Val Loss :  0.60828555
# ---------------------------------------------
#
#
#  Epoch: 84/3000 	LR: [0.0001] 	Dur: 3.52 sec
#
#  Training - Confusion Matrix:
# [[8779 3658]
#  [4521 8078]]
#
#  Validation - Confusion Matrix:
# [[1060  430]
#  [ 591 1049]]
#
# Train Acc :  67.11813977786473
# Train Loss :  0.6129506
# Val Acc :  67.38018989562988
# Val Loss :  0.628944
# ---------------------------------------------
#
#
#  Epoch: 85/3000 	LR: [0.0001] 	Dur: 3.26 sec
#
#  Training - Confusion Matrix:
# [[8887 3550]
#  [4595 8004]]
#
#  Validation - Confusion Matrix:
# [[1090  400]
#  [ 628 1012]]
#
# Train Acc :  67.42969921657017
# Train Loss :  0.6093917
# Val Acc :  67.15654730796814
# Val Loss :  0.6161104
# ---------------------------------------------
#
#
#  Epoch: 86/3000 	LR: [0.0001] 	Dur: 3.29 sec
#
#  Training - Confusion Matrix:
# [[8924 3513]
#  [4600 7999]]
#
#  Validation - Confusion Matrix:
# [[1053  437]
#  [ 583 1057]]
#
# Train Acc :  67.37589750971112
# Train Loss :  0.6093278
# Val Acc :  67.41213798522949
# Val Loss :  0.6136487
# ---------------------------------------------
#
#
#  Epoch: 87/3000 	LR: [0.0001] 	Dur: 3.31 sec
#
#  Training - Confusion Matrix:
# [[8747 3690]
#  [4404 8195]]
#
#  Validation - Confusion Matrix:
# [[1058  432]
#  [ 575 1065]]
#
# Train Acc :  67.41459625107902
# Train Loss :  0.6091567
# Val Acc :  67.82747507095337
# Val Loss :  0.61679107
# ---------------------------------------------
#
#
#  Epoch: 88/3000 	LR: [0.0001] 	Dur: 3.40 sec
#
#  Training - Confusion Matrix:
# [[8702 3735]
#  [4345 8254]]
#
#  Validation - Confusion Matrix:
# [[1065  425]
#  [ 583 1057]]
#
# Train Acc :  67.68396922520229
# Train Loss :  0.6063108
# Val Acc :  67.79552698135376
# Val Loss :  0.60759723
#  --------------------------------------------------------->  EPOCH 79 Checkpoint Saved w/ Acc: 67.74%
# ---------------------------------------------
#
#
#  Epoch: 89/3000 	LR: [0.0001] 	Dur: 3.33 sec
#
#  Training - Confusion Matrix:
# [[8892 3545]
#  [4483 8116]]
#
#  Validation - Confusion Matrix:
# [[1081  409]
#  [ 588 1052]]
#
# Train Acc :  67.56208113261631
# Train Loss :  0.60823786
# Val Acc :  68.14696192741394
# Val Loss :  0.6245636
#  --------------------------------------------------------->  EPOCH 79 Checkpoint Saved w/ Acc: 67.85%
# ---------------------------------------------
#
#
#  Epoch: 90/3000 	LR: [0.0001] 	Dur: 3.46 sec
#
#  Training - Confusion Matrix:
# [[8959 3478]
#  [4460 8139]]
#
#  Validation - Confusion Matrix:
# [[1076  414]
#  [ 579 1061]]
#
# Train Acc :  68.28949877193996
# Train Loss :  0.6028185
# Val Acc :  68.27476024627686
# Val Loss :  0.59810525
#  --------------------------------------------------------->  EPOCH 79 Checkpoint Saved w/ Acc: 68.28%
# ---------------------------------------------
#
#
#  Epoch: 91/3000 	LR: [0.0001] 	Dur: 3.20 sec
#
#  Training - Confusion Matrix:
# [[8835 3602]
#  [4459 8140]]
#
#  Validation - Confusion Matrix:
# [[1073  417]
#  [ 571 1069]]
#
# Train Acc :  67.66753196716309
# Train Loss :  0.6068216
# Val Acc :  68.4345006942749
# Val Loss :  0.6145079
# ---------------------------------------------
#
#
#  Epoch: 92/3000 	LR: [0.0001] 	Dur: 3.28 sec
#
#  Training - Confusion Matrix:
# [[8807 3630]
#  [4394 8205]]
#
#  Validation - Confusion Matrix:
# [[1086  404]
#  [ 559 1081]]
#
# Train Acc :  67.7138728754861
# Train Loss :  0.6050006
# Val Acc :  69.23322677612305
# Val Loss :  0.6155666
#  --------------------------------------------------------->  EPOCH 89 Checkpoint Saved w/ Acc: 68.47%
# ---------------------------------------------
#
#
#  Epoch: 93/3000 	LR: [0.0001] 	Dur: 3.25 sec
#
#  Training - Confusion Matrix:
# [[8785 3652]
#  [4416 8183]]
#
#  Validation - Confusion Matrix:
# [[1080  410]
#  [ 568 1072]]
#
# Train Acc :  67.47770820345197
# Train Loss :  0.606075
# Val Acc :  68.75399351119995
# Val Loss :  0.6160034
# ---------------------------------------------
#
#
#  Epoch: 94/3000 	LR: [0.0001] 	Dur: 3.17 sec
#
#  Training - Confusion Matrix:
# [[8813 3624]
#  [4422 8177]]
#
#  Validation - Confusion Matrix:
# [[1072  418]
#  [ 559 1081]]
#
# Train Acc :  67.66471096447536
# Train Loss :  0.6064046
# Val Acc :  68.78594160079956
# Val Loss :  0.62062
# ---------------------------------------------
#
#
#  Epoch: 95/3000 	LR: [0.0001] 	Dur: 3.23 sec
#
#  Training - Confusion Matrix:
# [[8850 3587]
#  [4359 8240]]
#
#  Validation - Confusion Matrix:
# [[1073  417]
#  [ 564 1076]]
#
# Train Acc :  68.39943783623832
# Train Loss :  0.6023202
# Val Acc :  68.65814328193665
# Val Loss :  0.5973314
#  --------------------------------------------------------->  EPOCH 89 Checkpoint Saved w/ Acc: 68.53%
# ---------------------------------------------
#
#
#  Epoch: 96/3000 	LR: [0.0001] 	Dur: 3.12 sec
#
#  Training - Confusion Matrix:
# [[8864 3573]
#  [4348 8251]]
#
#  Validation - Confusion Matrix:
# [[1065  425]
#  [ 562 1078]]
#
# Train Acc :  68.23851721627372
# Train Loss :  0.6046092
# Val Acc :  68.46645474433899
# Val Loss :  0.61293507
# ---------------------------------------------
#
#
#  Epoch: 97/3000 	LR: [0.0001] 	Dur: 3.10 sec
#
#  Training - Confusion Matrix:
# [[8841 3596]
#  [4384 8215]]
#
#  Validation - Confusion Matrix:
# [[1073  417]
#  [ 557 1083]]
#
# Train Acc :  67.97760554722377
# Train Loss :  0.6043674
# Val Acc :  68.88178586959839
# Val Loss :  0.6129572
# ---------------------------------------------
#
#
#  Epoch: 98/3000 	LR: [0.0001] 	Dur: 3.28 sec
#
#  Training - Confusion Matrix:
# [[8903 3534]
#  [4357 8242]]
#
#  Validation - Confusion Matrix:
# [[1080  410]
#  [ 571 1069]]
#
# Train Acc :  68.12260406357902
# Train Loss :  0.6028512
# Val Acc :  68.65814328193665
# Val Loss :  0.60919887
# ---------------------------------------------
#
#
#  Epoch: 99/3000 	LR: [0.0001] 	Dur: 3.09 sec
#
#  Training - Confusion Matrix:
# [[8762 3675]
#  [4353 8246]]
#
#  Validation - Confusion Matrix:
# [[1068  422]
#  [ 548 1092]]
#
# Train Acc :  67.81019483293805
# Train Loss :  0.60532653
# Val Acc :  69.0095841884613
# Val Loss :  0.6127337
# ---------------------------------------------
#
#
#  Epoch: 100/3000 	LR: [0.0001] 	Dur: 3.18 sec
#
#  Training - Confusion Matrix:
# [[8778 3659]
#  [4260 8339]]
#
#  Validation - Confusion Matrix:
# [[1075  415]
#  [ 568 1072]]
#
# Train Acc :  68.21792466299874
# Train Loss :  0.6050707
# Val Acc :  68.59424710273743
# Val Loss :  0.6197739
# QAT is starting!
# ---------------------------------------------
#
#
#  Epoch: 101/3000 	LR: [0.0001] 	Dur: 3.29 sec
#
#  Training - Confusion Matrix:
# [[8311 4126]
#  [4345 8254]]
#
#  Validation - Confusion Matrix:
# [[ 766  724]
#  [ 536 1104]]
#
# Train Acc :  65.74133804866246
# Train Loss :  1.1058782
# Val Acc :  59.74440574645996
# Val Loss :  0.81882083
#  --------------------------------------------------------->  EPOCH 94 Checkpoint Saved w/ Acc: 62.74%
# ---------------------------------------------
#
#
#  Epoch: 102/3000 	LR: [0.0001] 	Dur: 3.48 sec
#
#  Training - Confusion Matrix:
# [[6167 6270]
#  [4186 8413]]
#
#  Validation - Confusion Matrix:
# [[1142  348]
#  [ 902  738]]
#
# Train Acc :  58.129003218242104
# Train Loss :  0.8186816
# Val Acc :  60.06389856338501
# Val Loss :  0.76896167
# ---------------------------------------------
#
#
#  Epoch: 103/3000 	LR: [0.0001] 	Dur: 3.22 sec
#
#  Training - Confusion Matrix:
# [[7651 4786]
#  [5155 7444]]
#
#  Validation - Confusion Matrix:
# [[ 840  650]
#  [ 412 1228]]
#
# Train Acc :  61.000339473996846
# Train Loss :  0.72387093
# Val Acc :  66.07028841972351
# Val Loss :  0.67369676
#  --------------------------------------------------------->  EPOCH 94 Checkpoint Saved w/ Acc: 63.54%
# ---------------------------------------------
#
#
#  Epoch: 104/3000 	LR: [0.0001] 	Dur: 3.36 sec
#
#  Training - Confusion Matrix:
# [[7750 4687]
#  [4454 8145]]
#
#  Validation - Confusion Matrix:
# [[ 967  523]
#  [ 567 1073]]
#
# Train Acc :  63.48726749420166
# Train Loss :  0.6754255
# Val Acc :  65.17571806907654
# Val Loss :  0.66668725
#  --------------------------------------------------------->  EPOCH 94 Checkpoint Saved w/ Acc: 64.33%
# ---------------------------------------------
#
#
#  Epoch: 105/3000 	LR: [0.0001] 	Dur: 3.12 sec
#
#  Training - Confusion Matrix:
# [[7723 4714]
#  [4008 8591]]
#
#  Validation - Confusion Matrix:
# [[ 975  515]
#  [ 496 1144]]
#
# Train Acc :  65.30701007161822
# Train Loss :  0.6566722
# Val Acc :  67.69967675209045
# Val Loss :  0.6784192
#  --------------------------------------------------------->  EPOCH 94 Checkpoint Saved w/ Acc: 66.50%
# ---------------------------------------------
#
#
#  Epoch: 106/3000 	LR: [0.0001] 	Dur: 3.32 sec
#
#  Training - Confusion Matrix:
# [[8131 4306]
#  [4079 8520]]
#
#  Validation - Confusion Matrix:
# [[ 957  533]
#  [ 453 1187]]
#
# Train Acc :  66.4823727948325
# Train Loss :  0.6396743
# Val Acc :  68.4984028339386
# Val Loss :  0.6463942
#  --------------------------------------------------------->  EPOCH 94 Checkpoint Saved w/ Acc: 67.49%
# ---------------------------------------------
#
#
#  Epoch: 107/3000 	LR: [0.0001] 	Dur: 3.32 sec
#
#  Training - Confusion Matrix:
# [[7850 4587]
#  [3892 8707]]
#
#  Validation - Confusion Matrix:
# [[ 984  506]
#  [ 523 1117]]
#
# Train Acc :  66.04425396238055
# Train Loss :  0.63553256
# Val Acc :  67.12459921836853
# Val Loss :  0.65035135
# ---------------------------------------------
#
#
#  Epoch: 108/3000 	LR: [0.0001] 	Dur: 3.34 sec
#
#  Training - Confusion Matrix:
# [[8067 4370]
#  [4055 8544]]
#
#  Validation - Confusion Matrix:
# [[ 938  552]
#  [ 451 1189]]
#
# Train Acc :  66.34286386626107
# Train Loss :  0.6281394
# Val Acc :  67.9552674293518
# Val Loss :  0.6189657
# ---------------------------------------------
#
#
#  Epoch: 109/3000 	LR: [0.0001] 	Dur: 3.32 sec
#
#  Training - Confusion Matrix:
# [[7976 4461]
#  [3654 8945]]
#
#  Validation - Confusion Matrix:
# [[1052  438]
#  [ 546 1094]]
#
# Train Acc :  67.56189891270229
# Train Loss :  0.6191996
# Val Acc :  68.56229901313782
# Val Loss :  0.6212904
#  --------------------------------------------------------->  EPOCH 94 Checkpoint Saved w/ Acc: 68.06%
# ---------------------------------------------
#
#
#  Epoch: 110/3000 	LR: [0.0001] 	Dur: 3.23 sec
#
#  Training - Confusion Matrix:
# [[8109 4328]
#  [3832 8767]]
#
#  Validation - Confusion Matrix:
# [[ 935  555]
#  [ 447 1193]]
#
# Train Acc :  67.46008821896145
# Train Loss :  0.6177602
# Val Acc :  67.9872214794159
# Val Loss :  0.61181724
# ---------------------------------------------
#
#
#  Epoch: 111/3000 	LR: [0.0001] 	Dur: 3.30 sec
#
#  Training - Confusion Matrix:
# [[8066 4371]
#  [3773 8826]]
#
#  Validation - Confusion Matrix:
# [[ 952  538]
#  [ 450 1190]]
#
# Train Acc :  67.90184548922947
# Train Loss :  0.6100585
# Val Acc :  68.4345006942749
# Val Loss :  0.5763406
#  --------------------------------------------------------->  EPOCH 108 Checkpoint Saved w/ Acc: 68.17%
# ---------------------------------------------
#
#
#  Epoch: 112/3000 	LR: [0.0001] 	Dur: 3.37 sec
#
#  Training - Confusion Matrix:
# [[8195 4242]
#  [3753 8846]]
#
#  Validation - Confusion Matrix:
# [[1040  450]
#  [ 488 1152]]
#
# Train Acc :  68.47665309906006
# Train Loss :  0.61010736
# Val Acc :  70.03194689750671
# Val Loss :  0.5993136
#  --------------------------------------------------------->  EPOCH 108 Checkpoint Saved w/ Acc: 69.25%
# ---------------------------------------------
#
#
#  Epoch: 113/3000 	LR: [0.0001] 	Dur: 3.39 sec
#
#  Training - Confusion Matrix:
# [[8225 4212]
#  [3649 8950]]
#
#  Validation - Confusion Matrix:
# [[1004  486]
#  [ 444 1196]]
#
# Train Acc :  68.6958943094526
# Train Loss :  0.6018783
# Val Acc :  70.28753757476807
# Val Loss :  0.5898605
#  --------------------------------------------------------->  EPOCH 108 Checkpoint Saved w/ Acc: 69.49%
# ---------------------------------------------
#
#
#  Epoch: 114/3000 	LR: [0.0001] 	Dur: 3.16 sec
#
#  Training - Confusion Matrix:
# [[8109 4328]
#  [3505 9094]]
#
#  Validation - Confusion Matrix:
# [[1010  480]
#  [ 452 1188]]
#
# Train Acc :  68.57300485883441
# Train Loss :  0.60207516
# Val Acc :  70.22364139556885
# Val Loss :  0.6190364
# ---------------------------------------------
#
#
#  Epoch: 115/3000 	LR: [0.0001] 	Dur: 3.39 sec
#
#  Training - Confusion Matrix:
# [[8263 4174]
#  [3469 9130]]
#
#  Validation - Confusion Matrix:
# [[ 988  502]
#  [ 427 1213]]
#
# Train Acc :  69.78703652109418
# Train Loss :  0.5923829
# Val Acc :  70.31948566436768
# Val Loss :  0.5664856
#  --------------------------------------------------------->  EPOCH 108 Checkpoint Saved w/ Acc: 70.05%
# ---------------------------------------------
#
#
#  Epoch: 116/3000 	LR: [0.0001] 	Dur: 3.26 sec
#
#  Training - Confusion Matrix:
# [[8410 4027]
#  [3653 8946]]
#
#  Validation - Confusion Matrix:
# [[ 993  497]
#  [ 437 1203]]
#
# Train Acc :  69.21689936092922
# Train Loss :  0.5985757
# Val Acc :  70.15974521636963
# Val Loss :  0.59967375
# ---------------------------------------------
#
#
#  Epoch: 117/3000 	LR: [0.0001] 	Dur: 3.17 sec
#
#  Training - Confusion Matrix:
# [[8282 4155]
#  [3595 9004]]
#
#  Validation - Confusion Matrix:
# [[ 993  497]
#  [ 433 1207]]
#
# Train Acc :  68.97275873592922
# Train Loss :  0.59869957
# Val Acc :  70.28753757476807
# Val Loss :  0.61469126
# ---------------------------------------------
#
#
#  Epoch: 118/3000 	LR: [0.0001] 	Dur: 3.38 sec
#
#  Training - Confusion Matrix:
# [[8468 3969]
#  [3685 8914]]
#
#  Validation - Confusion Matrix:
# [[ 961  529]
#  [ 416 1224]]
#
# Train Acc :  69.44542101451329
# Train Loss :  0.5943019
# Val Acc :  69.80830430984497
# Val Loss :  0.5986
# ---------------------------------------------
#
#
#  Epoch: 119/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[8150 4287]
#  [3421 9178]]
#
#  Validation - Confusion Matrix:
# [[1071  419]
#  [ 496 1144]]
#
# Train Acc :  69.14681111063275
# Train Loss :  0.59511024
# Val Acc :  70.76677083969116
# Val Loss :  0.60372
# ---------------------------------------------
#
#
#  Epoch: 120/3000 	LR: [0.0001] 	Dur: 3.06 sec
#
#  Training - Confusion Matrix:
# [[8358 4079]
#  [3540 9059]]
#
#  Validation - Confusion Matrix:
# [[ 998  492]
#  [ 428 1212]]
#
# Train Acc :  69.73290017672947
# Train Loss :  0.5910836
# Val Acc :  70.60703039169312
# Val Loss :  0.60071325
#  --------------------------------------------------------->  EPOCH 108 Checkpoint Saved w/ Acc: 70.17%
# ---------------------------------------------
#
#
#  Epoch: 121/3000 	LR: [0.0001] 	Dur: 3.28 sec
#
#  Training - Confusion Matrix:
# [[8489 3948]
#  [3588 9011]]
#
#  Validation - Confusion Matrix:
# [[1003  487]
#  [ 421 1219]]
#
# Train Acc :  70.16022290502276
# Train Loss :  0.586609
# Val Acc :  70.9904134273529
# Val Loss :  0.58500934
#  --------------------------------------------------------->  EPOCH 119 Checkpoint Saved w/ Acc: 70.58%
# ---------------------------------------------
#
#
#  Epoch: 122/3000 	LR: [0.0001] 	Dur: 3.30 sec
#
#  Training - Confusion Matrix:
# [[8492 3945]
#  [3415 9184]]
#
#  Validation - Confusion Matrix:
# [[1068  422]
#  [ 488 1152]]
#
# Train Acc :  70.58108448982239
# Train Loss :  0.57885915
# Val Acc :  70.92651724815369
# Val Loss :  0.5686567
#  --------------------------------------------------------->  EPOCH 119 Checkpoint Saved w/ Acc: 70.75%
# ---------------------------------------------
#
#
#  Epoch: 123/3000 	LR: [0.0001] 	Dur: 3.10 sec
#
#  Training - Confusion Matrix:
# [[8390 4047]
#  [3481 9118]]
#
#  Validation - Confusion Matrix:
# [[1031  459]
#  [ 444 1196]]
#
# Train Acc :  70.24326069014413
# Train Loss :  0.5834883
# Val Acc :  71.15015983581543
# Val Loss :  0.56818324
# ---------------------------------------------
#
#
#  Epoch: 124/3000 	LR: [0.0001] 	Dur: 3.10 sec
#
#  Training - Confusion Matrix:
# [[8494 3943]
#  [3524 9075]]
#
#  Validation - Confusion Matrix:
# [[1064  426]
#  [ 461 1179]]
#
# Train Acc :  70.59385265622821
# Train Loss :  0.5796527
# Val Acc :  71.66134119033813
# Val Loss :  0.5557986
#  --------------------------------------------------------->  EPOCH 119 Checkpoint Saved w/ Acc: 71.13%
# ---------------------------------------------
#
#
#  Epoch: 125/3000 	LR: [0.0001] 	Dur: 3.28 sec
#
#  Training - Confusion Matrix:
# [[8459 3978]
#  [3444 9155]]
#
#  Validation - Confusion Matrix:
# [[1035  455]
#  [ 436 1204]]
#
# Train Acc :  70.55782335145133
# Train Loss :  0.5813347
# Val Acc :  71.53354287147522
# Val Loss :  0.57402694
# ---------------------------------------------
#
#
#  Epoch: 126/3000 	LR: [0.0001] 	Dur: 3.20 sec
#
#  Training - Confusion Matrix:
# [[8644 3793]
#  [3466 9133]]
#
#  Validation - Confusion Matrix:
# [[1055  435]
#  [ 449 1191]]
#
# Train Acc :  71.29173108509609
# Train Loss :  0.5746314
# Val Acc :  71.75718545913696
# Val Loss :  0.55679315
#  --------------------------------------------------------->  EPOCH 119 Checkpoint Saved w/ Acc: 71.52%
# ---------------------------------------------
#
#
#  Epoch: 127/3000 	LR: [0.0001] 	Dur: 3.08 sec
#
#  Training - Confusion Matrix:
# [[8564 3873]
#  [3445 9154]]
#
#  Validation - Confusion Matrix:
# [[1033  457]
#  [ 434 1206]]
#
# Train Acc :  70.97568256514413
# Train Loss :  0.5739331
# Val Acc :  71.53354287147522
# Val Loss :  0.5683251
# ---------------------------------------------
#
#
#  Epoch: 128/3000 	LR: [0.0001] 	Dur: 3.35 sec
#
#  Training - Confusion Matrix:
# [[8629 3808]
#  [3458 9141]]
#
#  Validation - Confusion Matrix:
# [[1048  442]
#  [ 442 1198]]
#
# Train Acc :  70.79865762165615
# Train Loss :  0.5771528
# Val Acc :  71.75718545913696
# Val Loss :  0.5884863
# ---------------------------------------------
#
#
#  Epoch: 129/3000 	LR: [0.0001] 	Dur: 3.36 sec
#
#  Training - Confusion Matrix:
# [[8480 3957]
#  [3376 9223]]
#
#  Validation - Confusion Matrix:
# [[1062  428]
#  [ 448 1192]]
#
# Train Acc :  71.06120756694249
# Train Loss :  0.573198
# Val Acc :  72.01277613639832
# Val Loss :  0.5514153
#  --------------------------------------------------------->  EPOCH 119 Checkpoint Saved w/ Acc: 71.54%
# ---------------------------------------------
#
#
#  Epoch: 130/3000 	LR: [0.0001] 	Dur: 3.38 sec
#
#  Training - Confusion Matrix:
# [[8654 3783]
#  [3495 9104]]
#
#  Validation - Confusion Matrix:
# [[1026  464]
#  [ 418 1222]]
#
# Train Acc :  71.22546434402466
# Train Loss :  0.57240677
# Val Acc :  71.82108759880066
# Val Loss :  0.571386
# ---------------------------------------------
#
#
#  Epoch: 131/3000 	LR: [0.0001] 	Dur: 3.38 sec
#
#  Training - Confusion Matrix:
# [[8657 3780]
#  [3491 9108]]
#
#  Validation - Confusion Matrix:
# [[1070  420]
#  [ 441 1199]]
#
# Train Acc :  71.00176470620292
# Train Loss :  0.5690733
# Val Acc :  72.49200940132141
# Val Loss :  0.5530683
#  --------------------------------------------------------->  EPOCH 128 Checkpoint Saved w/ Acc: 71.75%
# ---------------------------------------------
#
#
#  Epoch: 132/3000 	LR: [0.0001] 	Dur: 3.51 sec
#
#  Training - Confusion Matrix:
# [[8596 3841]
#  [3401 9198]]
#
#  Validation - Confusion Matrix:
# [[1052  438]
#  [ 450 1190]]
#
# Train Acc :  71.43372637884957
# Train Loss :  0.5669955
# Val Acc :  71.62939310073853
# Val Loss :  0.53944856
# ---------------------------------------------
#
#
# ...
#
#
#  Epoch: 1393/3000 	LR: [4.000000000000001e-06] 	Dur: 3.40 sec
#
#  Training - Confusion Matrix:
# [[10637  1800]
#  [ 1778 10821]]
#
#  Validation - Confusion Matrix:
# [[1154  336]
#  [ 171 1469]]
#
# Train Acc :  86.85928923743111
# Train Loss :  0.30352363
# Val Acc :  83.80191326141357
# Val Loss :  0.15319957
# ---------------------------------------------
#
#
#  Epoch: 1394/3000 	LR: [4.000000000000001e-06] 	Dur: 3.61 sec
#
#  Training - Confusion Matrix:
# [[10584  1853]
#  [ 1703 10896]]
#
#  Validation - Confusion Matrix:
# [[1173  317]
#  [ 176 1464]]
#
# Train Acc :  87.15656484876361
# Train Loss :  0.30320787
# Val Acc :  84.24919843673706
# Val Loss :  0.13512422
# ---------------------------------------------
#
#
#  Epoch: 1395/3000 	LR: [4.000000000000001e-06] 	Dur: 3.47 sec
#
#  Training - Confusion Matrix:
# [[10486  1951]
#  [ 1654 10945]]
#
#  Validation - Confusion Matrix:
# [[1195  295]
#  [ 202 1438]]
#
# Train Acc :  87.01323441096714
# Train Loss :  0.30310073
# Val Acc :  84.12140607833862
# Val Loss :  0.1378761
# ---------------------------------------------
#
#
#  Epoch: 1396/3000 	LR: [4.000000000000001e-06] 	Dur: 3.70 sec
#
#  Training - Confusion Matrix:
# [[10633  1804]
#  [ 1677 10922]]
#
#  Validation - Confusion Matrix:
# [[1155  335]
#  [ 174 1466]]
#
# Train Acc :  87.36300809042794
# Train Loss :  0.3023705
# Val Acc :  83.73801708221436
# Val Loss :  0.13596585
# ---------------------------------------------
#
#
#  Epoch: 1397/3000 	LR: [4.000000000000001e-06] 	Dur: 3.46 sec
#
#  Training - Confusion Matrix:
# [[10590  1847]
#  [ 1685 10914]]
#
#  Validation - Confusion Matrix:
# [[1185  305]
#  [ 189 1451]]
#
# Train Acc :  87.3781110559191
# Train Loss :  0.30065838
# Val Acc :  84.21725034713745
# Val Loss :  0.13161498
# ---------------------------------------------
#
#
#  Epoch: 1398/3000 	LR: [4.000000000000001e-06] 	Dur: 3.49 sec
#
#  Training - Confusion Matrix:
# [[10609  1828]
#  [ 1698 10901]]
#
#  Validation - Confusion Matrix:
# [[1162  328]
#  [ 177 1463]]
#
# Train Acc :  87.20606054578509
# Train Loss :  0.3019537
# Val Acc :  83.86581540107727
# Val Loss :  0.14245456
# ---------------------------------------------
#
#
#  Epoch: 1399/3000 	LR: [4.000000000000001e-06] 	Dur: 3.49 sec
#
#  Training - Confusion Matrix:
# [[10533  1904]
#  [ 1658 10941]]
#
#  Validation - Confusion Matrix:
# [[1155  335]
#  [ 172 1468]]
#
# Train Acc :  87.13563850947789
# Train Loss :  0.30225545
# Val Acc :  83.80191326141357
# Val Loss :  0.13648555
# ---------------------------------------------
#
#
#  Epoch: 1400/3000 	LR: [4.000000000000001e-06] 	Dur: 3.52 sec
#
#  Training - Confusion Matrix:
# [[10505  1932]
#  [ 1614 10985]]
#
#  Validation - Confusion Matrix:
# [[1172  318]
#  [ 177 1463]]
#
# Train Acc :  87.35685093062264
# Train Loss :  0.30039045
# Val Acc :  84.18530225753784
# Val Loss :  0.12491932
# ---------------------------------------------
#
#
#  Epoch: 1401/3000 	LR: [4.000000000000001e-06] 	Dur: 3.71 sec
#
#  Training - Confusion Matrix:
# [[10648  1789]
#  [ 1726 10873]]
#
#  Validation - Confusion Matrix:
# [[1165  325]
#  [ 170 1470]]
#
# Train Acc :  87.38226635115487
# Train Loss :  0.2998715
# Val Acc :  84.18530225753784
# Val Loss :  0.12831233
# ---------------------------------------------
#
#
#  Epoch: 1402/3000 	LR: [4.000000000000001e-06] 	Dur: 3.77 sec
#
#  Training - Confusion Matrix:
# [[10526  1911]
#  [ 1640 10959]]
#
#  Validation - Confusion Matrix:
# [[1183  307]
#  [ 176 1464]]
#
# Train Acc :  87.22913946424212
# Train Loss :  0.3026277
# Val Acc :  84.56869125366211
# Val Loss :  0.1411432
# ---------------------------------------------
#
#
#  Epoch: 1403/3000 	LR: [4.000000000000001e-06] 	Dur: 3.44 sec
#
#  Training - Confusion Matrix:
# [[10654  1783]
#  [ 1784 10815]]
#
#  Validation - Confusion Matrix:
# [[1167  323]
#  [ 178 1462]]
#
# Train Acc :  87.14576789311
# Train Loss :  0.30214533
# Val Acc :  83.99360775947571
# Val Loss :  0.12706538
# ---------------------------------------------
#
#
#  Epoch: 1404/3000 	LR: [4.000000000000001e-06] 	Dur: 3.44 sec
#
#  Training - Confusion Matrix:
# [[10461  1976]
#  [ 1606 10993]]
#
#  Validation - Confusion Matrix:
# [[1191  299]
#  [ 193 1447]]
#
# Train Acc :  86.95561119488308
# Train Loss :  0.30036077
# Val Acc :  84.28114652633667
# Val Loss :  0.13831696
# ---------------------------------------------
#
#
#  Epoch: 1405/3000 	LR: [4.000000000000001e-06] 	Dur: 3.37 sec
#
#  Training - Confusion Matrix:
# [[10613  1824]
#  [ 1724 10875]]
#
#  Validation - Confusion Matrix:
# [[1184  306]
#  [ 190 1450]]
#
# Train Acc :  87.23960263388497
# Train Loss :  0.30075392
# Val Acc :  84.15335416793823
# Val Loss :  0.12924513
# ---------------------------------------------
#
#
#  Epoch: 1406/3000 	LR: [4.000000000000001e-06] 	Dur: 3.35 sec
#
#  Training - Confusion Matrix:
# [[10619  1818]
#  [ 1702 10897]]
#
#  Validation - Confusion Matrix:
# [[1166  324]
#  [ 176 1464]]
#
# Train Acc :  87.28212288447789
# Train Loss :  0.30102727
# Val Acc :  84.02555584907532
# Val Loss :  0.14818902
# ---------------------------------------------
#
#
#  Epoch: 1407/3000 	LR: [4.000000000000001e-06] 	Dur: 3.36 sec
#
#  Training - Confusion Matrix:
# [[10561  1876]
#  [ 1614 10985]]
#
#  Validation - Confusion Matrix:
# [[1181  309]
#  [ 185 1455]]
#
# Train Acc :  87.35918658120292
# Train Loss :  0.29973885
# Val Acc :  84.21725034713745
# Val Loss :  0.1370397
# ---------------------------------------------
#
#
#  Epoch: 1408/3000 	LR: [4.000000000000001e-06] 	Dur: 3.51 sec
#
#  Training - Confusion Matrix:
# [[10583  1854]
#  [ 1707 10892]]
#
#  Validation - Confusion Matrix:
# [[1173  317]
#  [ 181 1459]]
#
# Train Acc :  87.08399023328509
# Train Loss :  0.30150363
# Val Acc :  84.08945798873901
# Val Loss :  0.14142452
# ---------------------------------------------
#
#
#  Epoch: 1409/3000 	LR: [4.000000000000001e-06] 	Dur: 3.53 sec
#
#  Training - Confusion Matrix:
# [[10567  1870]
#  [ 1651 10948]]
#
#  Validation - Confusion Matrix:
# [[1169  321]
#  [ 174 1466]]
#
# Train Acc :  87.41647601127625
# Train Loss :  0.29878137
# Val Acc :  84.18530225753784
# Val Loss :  0.12301954
# ---------------------------------------------
#
#
#  Epoch: 1410/3000 	LR: [4.000000000000001e-06] 	Dur: 3.53 sec
#
#  Training - Confusion Matrix:
# [[10538  1899]
#  [ 1683 10916]]
#
#  Validation - Confusion Matrix:
# [[1177  313]
#  [ 181 1459]]
#
# Train Acc :  87.06588404519218
# Train Loss :  0.303792
# Val Acc :  84.21725034713745
# Val Loss :  0.14367427
# ---------------------------------------------
#
#
#  Epoch: 1411/3000 	LR: [4.000000000000001e-06] 	Dur: 3.52 sec
#
#  Training - Confusion Matrix:
# [[10557  1880]
#  [ 1660 10939]]
#
#  Validation - Confusion Matrix:
# [[1175  315]
#  [ 183 1457]]
#
# Train Acc :  87.10209556988308
# Train Loss :  0.30099377
# Val Acc :  84.08945798873901
# Val Loss :  0.14158316
# ---------------------------------------------
#
#
#  Epoch: 1412/3000 	LR: [4.000000000000001e-06] 	Dur: 3.67 sec
#
#  Training - Confusion Matrix:
# [[10541  1896]
#  [ 1643 10956]]
#
#  Validation - Confusion Matrix:
# [[1178  312]
#  [ 186 1454]]
#
# Train Acc :  87.0228784424918
# Train Loss :  0.2998967
# Val Acc :  84.08945798873901
# Val Loss :  0.14801764
# ---------------------------------------------
#
#
#  Epoch: 1413/3000 	LR: [4.000000000000001e-06] 	Dur: 3.33 sec
#
#  Training - Confusion Matrix:
# [[10628  1809]
#  [ 1739 10860]]
#
#  Validation - Confusion Matrix:
# [[1178  312]
#  [ 183 1457]]
#
# Train Acc :  87.15689863477435
# Train Loss :  0.30372235
# Val Acc :  84.18530225753784
# Val Loss :  0.15254448
# ---------------------------------------------
#
#
#  Epoch: 1414/3000 	LR: [4.000000000000001e-06] 	Dur: 3.39 sec
#
#  Training - Confusion Matrix:
# [[10602  1835]
#  [ 1722 10877]]
#
#  Validation - Confusion Matrix:
# [[1170  320]
#  [ 177 1463]]
#
# Train Acc :  87.18064512525287
# Train Loss :  0.30158445
# Val Acc :  84.12140607833862
# Val Loss :  0.12646696
# ---------------------------------------------
#
#
#  Epoch: 1415/3000 	LR: [4.000000000000001e-06] 	Dur: 3.33 sec
#
#  Training - Confusion Matrix:
# [[10523  1914]
#  [ 1649 10950]]
#
#  Validation - Confusion Matrix:
# [[1169  321]
#  [ 178 1462]]
#
# Train Acc :  87.13215078626361
# Train Loss :  0.30141947
# Val Acc :  84.05750393867493
# Val Loss :  0.13717973
# ---------------------------------------------
#
#
#  Epoch: 1416/3000 	LR: [4.000000000000001e-06] 	Dur: 3.37 sec
#
#  Training - Confusion Matrix:
# [[10564  1873]
#  [ 1669 10930]]
#
#  Validation - Confusion Matrix:
# [[1158  332]
#  [ 170 1470]]
#
# Train Acc :  87.17782497406006
# Train Loss :  0.30378506
# Val Acc :  83.9616596698761
# Val Loss :  0.14764099
# ---------------------------------------------
#
#
#  Epoch: 1417/3000 	LR: [4.000000000000001e-06] 	Dur: 3.66 sec
#
#  Training - Confusion Matrix:
# [[10507  1930]
#  [ 1639 10960]]
#
#  Validation - Confusion Matrix:
# [[1186  304]
#  [ 189 1451]]
#
# Train Acc :  87.13879244668144
# Train Loss :  0.3001267
# Val Acc :  84.24919843673706
# Val Loss :  0.13813472
# ---------------------------------------------
#
#
#  Epoch: 1418/3000 	LR: [4.000000000000001e-06] 	Dur: 3.41 sec
#
#  Training - Confusion Matrix:
# [[10614  1823]
#  [ 1738 10861]]
#
#  Validation - Confusion Matrix:
# [[1175  315]
#  [ 184 1456]]
#
# Train Acc :  87.27696708270481
# Train Loss :  0.300232
# Val Acc :  84.05750393867493
# Val Loss :  0.12018245
# ---------------------------------------------
#
#
#  Epoch: 1419/3000 	LR: [4.000000000000001e-06] 	Dur: 3.55 sec
#
#  Training - Confusion Matrix:
# [[10630  1807]
#  [ 1712 10887]]
#
#  Validation - Confusion Matrix:
# [[1171  319]
#  [ 179 1461]]
#
# Train Acc :  87.14776975767953
# Train Loss :  0.30191448
# Val Acc :  84.08945798873901
# Val Loss :  0.14437747
# ---------------------------------------------
#
#
#  Epoch: 1420/3000 	LR: [4.000000000000001e-06] 	Dur: 3.71 sec
#
#  Training - Confusion Matrix:
# [[10597  1840]
#  [ 1661 10938]]
#
#  Validation - Confusion Matrix:
# [[1179  311]
#  [ 178 1462]]
#
# Train Acc :  87.26568477494376
# Train Loss :  0.30054718
# Val Acc :  84.37699675559998
# Val Loss :  0.13747196
# ---------------------------------------------
#
#
#  Epoch: 1421/3000 	LR: [4.000000000000001e-06] 	Dur: 3.60 sec
#
#  Training - Confusion Matrix:
# [[10520  1917]
#  [ 1652 10947]]
#
#  Validation - Confusion Matrix:
# [[1184  306]
#  [ 187 1453]]
#
# Train Acc :  87.0560884475708
# Train Loss :  0.30355206
# Val Acc :  84.24919843673706
# Val Loss :  0.14501008
# ---------------------------------------------
#
#
#  Epoch: 1422/3000 	LR: [4.000000000000001e-06] 	Dur: 3.63 sec
#
#  Training - Confusion Matrix:
# [[10607  1830]
#  [ 1749 10850]]
#
#  Validation - Confusion Matrix:
# [[1162  328]
#  [ 179 1461]]
#
# Train Acc :  87.15905206544059
# Train Loss :  0.30243832
# Val Acc :  83.80191326141357
# Val Loss :  0.12506908
# ---------------------------------------------
#
#
#  Epoch: 1423/3000 	LR: [4.000000000000001e-06] 	Dur: 3.45 sec
#
#  Training - Confusion Matrix:
# [[10571  1866]
#  [ 1667 10932]]
#
#  Validation - Confusion Matrix:
# [[1176  314]
#  [ 184 1456]]
#
# Train Acc :  87.26435048239571
# Train Loss :  0.30089566
# Val Acc :  84.08945798873901
# Val Loss :  0.13474979
# ---------------------------------------------
#
#
#  Epoch: 1424/3000 	LR: [4.000000000000001e-06] 	Dur: 3.65 sec
#
#  Training - Confusion Matrix:
# [[10604  1833]
#  [ 1704 10895]]
#
#  Validation - Confusion Matrix:
# [[1142  348]
#  [ 166 1474]]
#
# Train Acc :  87.08499073982239
# Train Loss :  0.30406687
# Val Acc :  83.57827067375183
# Val Loss :  0.15152562
# ---------------------------------------------
#
#
#  Epoch: 1425/3000 	LR: [4.000000000000001e-06] 	Dur: 3.66 sec
#
#  Training - Confusion Matrix:
# [[10536  1901]
#  [ 1656 10943]]
#
#  Validation - Confusion Matrix:
# [[1179  311]
#  [ 182 1458]]
#
# Train Acc :  87.01523627553668
# Train Loss :  0.30080265
# Val Acc :  84.24919843673706
# Val Loss :  0.15171202
# ---------------------------------------------
#
#
#  Epoch: 1426/3000 	LR: [4.000000000000001e-06] 	Dur: 3.54 sec
#
#  Training - Confusion Matrix:
# [[10523  1914]
#  [ 1677 10922]]
#
#  Validation - Confusion Matrix:
# [[1171  319]
#  [ 179 1461]]
#
# Train Acc :  87.06206253596714
# Train Loss :  0.30200332
# Val Acc :  84.08945798873901
# Val Loss :  0.1274805
# ---------------------------------------------
#
#
#  Epoch: 1427/3000 	LR: [4.000000000000001e-06] 	Dur: 3.55 sec
#
#  Training - Confusion Matrix:
# [[10624  1813]
#  [ 1713 10886]]
#
#  Validation - Confusion Matrix:
# [[1173  317]
#  [ 181 1459]]
#
# Train Acc :  87.06821884427752
# Train Loss :  0.3017127
# Val Acc :  84.08945798873901
# Val Loss :  0.15187082
# ---------------------------------------------
#
#
#  Epoch: 1428/3000 	LR: [4.000000000000001e-06] 	Dur: 3.47 sec
#
#  Training - Confusion Matrix:
# [[10555  1882]
#  [ 1597 11002]]
#
#  Validation - Confusion Matrix:
# [[1209  281]
#  [ 196 1444]]
#
# Train Acc :  87.42511953626361
# Train Loss :  0.30069426
# Val Acc :  84.76037979125977
# Val Loss :  0.13005126
#  --------------------------------------------------------->  EPOCH 1374 Checkpoint Saved w/ Acc: 86.09%
# ---------------------------------------------
#
#
#  Epoch: 1429/3000 	LR: [4.000000000000001e-06] 	Dur: 3.48 sec
#
#  Training - Confusion Matrix:
# [[10571  1866]
#  [ 1684 10915]]
#
#  Validation - Confusion Matrix:
# [[1162  328]
#  [ 172 1468]]
#
# Train Acc :  87.31533203806195
# Train Loss :  0.3035908
# Val Acc :  84.02555584907532
# Val Loss :  0.13643663
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 114
#     112 model.eval()
#     113 with torch.no_grad():
# --> 114     for inputs, target in val_loader:
#     115         inputs = inputs.to(device)
#     116         target = target.to(device)
#
# File c:\Users\J_C\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:681, in _BaseDataLoaderIter.__next__(self)
#     678 if self._sampler_iter is None:
#     679     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680     self._reset()  # type: ignore[call-arg]
# --> 681 data = self._next_data()
#     682 self._num_yielded += 1
#     683 if self._dataset_kind == _DatasetKind.Iterable and \
#     684         self._IterableDataset_len_called is not None and \
#     685         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\J_C\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:1359, in _MultiProcessingDataLoaderIter._next_data(self)
#    1356     return self._process_data(data)
#    1358 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1359 idx, data = self._get_data()
#    1360 self._tasks_outstanding -= 1
#    1361 if self._dataset_kind == _DatasetKind.Iterable:
#    1362     # Check for _IterableDatasetStopIteration
#
# File c:\Users\J_C\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:1315, in _MultiProcessingDataLoaderIter._get_data(self)
#    1313 elif self._pin_memory:
#    1314     while self._pin_memory_thread.is_alive():
# -> 1315         success, data = self._try_get_data()
#    1316         if success:
#    1317             return data
#
# File c:\Users\J_C\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:1163, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1150 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1151     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1152     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1160     # Returns a 2-tuple:
#    1161     #   (bool: whether successfully get data, any: data if successful else None)
#    1162     try:
# -> 1163         data = self._data_queue.get(timeout=timeout)
#    1164         return (True, data)
#    1165     except Exception as e:
#    1166         # At timeout and error, we manually check whether any worker has
#    1167         # failed. Note that this is the only mechanism for Windows to detect
#    1168         # worker failures.
#
# File c:\Users\J_C\AppData\Local\Programs\Python\Python310\lib\queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File c:\Users\J_C\AppData\Local\Programs\Python\Python310\lib\threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
