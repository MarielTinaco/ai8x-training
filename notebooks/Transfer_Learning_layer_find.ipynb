# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ## Load Libraries

# %%
import importlib
import sys
import os
import numpy as np
import time
from pathlib import Path
import matplotlib.pyplot as plt

import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, TensorDataset, DataLoader

from torch.utils import data
from torchvision import transforms

sys.path.append(os.path.join(os.getcwd(), ".."))

from distiller import apputils
import ai8x

from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

kws20 = importlib.import_module("datasets.kws20-horsecough")

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_recall_fscore_support, roc_auc_score, roc_curve


import librosa
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# FIX SEED FOR REPRODUCIBILITY
seed = 69
torch.manual_seed(seed)

# %% [markdown]
# ## Function Declarations

# %%
def rescale(audio, min_val=-1,max_val=1):
    sig = audio
    mean = np.average(sig)

    sig = sig-mean # REMOVE DC COMPONENT

    sig_max = np.max(sig)
    sig_min = np.min(sig)

    if sig_max >= np.abs(sig_min):
        sig_scaled = sig/sig_max
    else:
        sig_scaled = sig/np.abs(sig_min)

    return sig_scaled

def rescale2(audio, min_val=-1,max_val=1):
    scaler = MinMaxScaler(feature_range=(min_val,max_val))
    audio = audio.reshape(-1,1)
    scaler.fit(audio)
    scaled = np.array(scaler.transform(audio))
    
    return scaled[:,0]


def plot_confusion(y_true, y_pred, classes):
    cf_matrix = confusion_matrix(y_true = y_true, y_pred = y_pred, labels =list(range(len(classes))))
    print(cf_matrix)

def plot_roc_curve(true_y, y_prob):
    fpr, tpr, thresholds = roc_curve(true_y, y_prob)
    plt.plot(fpr, tpr)
    plt.plot([0,1], [0,1], 'r--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

def custom_dataloader(data, train_idx, val_idx, test_idx, batch_size = 2048):
    data_file = data
    x = np.asarray(data_file[0][test_idx])
    y = np.squeeze(np.asarray(data_file[1][test_idx]))
    test_set = TensorDataset(torch.Tensor(x),torch.Tensor(y).to(dtype =torch.int64))
    test_loader = DataLoader(test_set,batch_size=batch_size, num_workers=4, pin_memory=True)

    x = np.asarray(data_file[0][val_idx])
    y = np.squeeze(np.asarray(data_file[1][val_idx]))
    val_set = TensorDataset(torch.Tensor(x),torch.Tensor(y).to(dtype =torch.int64))
    val_loader = DataLoader(val_set,batch_size=batch_size, num_workers=4, pin_memory=True)

    x = np.asarray(data_file[0][train_idx])
    y = np.squeeze(np.asarray(data_file[1][train_idx]))
    train_set = TensorDataset(torch.Tensor(x),torch.Tensor(y).to(dtype =torch.int64))
    train_loader = DataLoader(train_set,batch_size=batch_size, num_workers=4, pin_memory=True)

    return train_loader,val_loader,test_loader

def count_params(model):
    model_parameters = filter(lambda p: p.requires_grad, model.parameters())
    params = sum([np.prod(p.size()) for p in model_parameters])
    print(params)
    return params

def freeze_layer(layer):
    for p in layer.parameters():
        p.requires_grad = False

# %% [markdown]
# ## Prepare Checkpoint, Plot, and Dataset Folders

# %%
model_name = 'human_others'
classes = ["combined",'cough']
checkpoint_dir = './checkpoints/'+model_name+'/'

indexer = 0
while os.path.exists(checkpoint_dir):
    model_name = 'human_others'
    model_name = model_name + '_' + str(indexer)
    checkpoint_dir = './checkpoints/'+model_name+'/'
    indexer += 1

if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

print('Model Name: ', model_name)
print('Classes: ', classes)
print('Checkpoint Dir: ', checkpoint_dir)
# Out:
# Model Name:  human_others_13
# Classes:  ['combined', 'cough']
# Checkpoint Dir:  ./checkpoints/human_others_13/

# %% [markdown]
# ## Calculate weights

# %%
raw_data_path = Path("../data/KWS_EQUINE/raw/")
class_file_count = {}

class_dirs = [d for d in raw_data_path.iterdir() if d.is_dir() and (d.stem != "__combinedkws") and (d.stem != "__combined_others") and (d.stem != "__human_cough")and (d.stem != "__human_cough_v2")]

for d in class_dirs:
    print(d)
    class_file_count[d] = len(list(d.iterdir()))

min_file_count = float(min(class_file_count.values()))

# Calculate weights
class_weights = []
for d in class_dirs:
    class_file_count[d] = min_file_count / class_file_count[d]
    print(f"{d.stem}: {round(class_file_count[d], 7)}")
    class_weights.append(round(class_file_count[d], 7))
print('Weights: ',class_weights)
# Out:
# ..\data\KWS_EQUINE\raw\combined_others
# ..\data\KWS_EQUINE\raw\human_cough_v2
# combined_others: 1.0
# human_cough_v2: 0.98327
# Weights:  [1.0, 0.98327]

# %% [markdown]
# ## Generate Processed Datafile

# %%
train_batch_size = 4096

processed_data_path = Path("../data/KWS_EQUINE/processed/")
fname = model_name+'.pt'
_, _, _, _ = apputils.get_data_loaders(kws20.KWS_HORSE_TF_get_datasets,("../data", True), 
                                       train_batch_size, 4, validation_split=0.1,
                                       download=True, fname = fname)
# Out:
# No key `noise_var` in input augmentation dictionary!  Using defaults: [Min: 0., Max: 1.]
# No key `shift` in input augmentation dictionary! Using defaults: [Min:-0.1, Max: 0.1]
# No key `strech` in input augmentation dictionary! Using defaults: [Min: 0.8, Max: 1.3]
#
# Processing train...
# Class combined not found in data
#
# Processing test...
# Class combined not found in data

# %% [markdown]
# ## Read Processed Dataset

# %%
if torch.cuda.is_available():
    device = torch.device('cuda:0')
    cpu = False
else:
     device = torch.device('cpu')
     cpu = True

print('Running on device: {}'.format(torch.cuda.get_device_name()))

processed_dir = "../data/KWS_EQUINE/processed/"

test_ratio = 0.1
val_ratio = 0.1

if os.path.exists(processed_dir+fname):
     data_file = torch.load(processed_dir+fname) # (data, class, type)
     len_dataset = len(data_file[0])

     train_indices, test_indices = train_test_split(np.arange(len_dataset),test_size=test_ratio, train_size=1-test_ratio)
     train_indices, val_indices = train_test_split(train_indices,test_size=val_ratio/(1-test_ratio), train_size=1-(val_ratio/(1-test_ratio)))

     train_loader,val_loader,test_loader = custom_dataloader(data=data_file, train_idx = train_indices,
     val_idx = val_indices, test_idx = test_indices, batch_size = train_batch_size)

     # x = np.asarray(data_file[0][test_indices])
     # y = np.squeeze(np.asarray(data_file[1][test_indices]))

     # test_set = TensorDataset(torch.Tensor(x),torch.Tensor(y).to(dtype =torch.int64))
     # test_loader = DataLoader(test_set,batch_size=train_batch_size, num_workers=4, pin_memory=True)

     # x = np.asarray(data_file[0][val_indices])
     # y = np.squeeze(np.asarray(data_file[1][val_indices]))

     # val_set = TensorDataset(torch.Tensor(x),torch.Tensor(y).to(dtype =torch.int64))
     # val_loader = DataLoader(val_set,batch_size=train_batch_size, num_workers=4, pin_memory=True)
     
     # x = np.asarray(data_file[0][train_indices])
     # y = np.squeeze(np.asarray(data_file[1][train_indices]))

     # train_set = TensorDataset(torch.Tensor(x),torch.Tensor(y).to(dtype =torch.int64))
     # train_loader = DataLoader(train_set,batch_size=train_batch_size, num_workers=4, pin_memory=True)
     
     print('Dataloaders Created')
     print('Train Loader Size: ',len(train_loader.dataset))
     print('Validation Loader Size: ',len(val_loader.dataset))
     print('Test Loader Size: ',len(test_loader.dataset))
else:
     print('Dataset does not Exist')
# Out:
# Running on device: NVIDIA GeForce RTX 2070 SUPER
# Dataloaders Created
# Train Loader Size:  25036
# Validation Loader Size:  3130
# Test Loader Size:  3130

# %% [markdown]
# ## LOOP AT EVERY CHANGE OF FROZEN LAYER TO FIND BEST PERFORMING MODEL

# %%
num_epochs = 3000

criterion = torch.nn.CrossEntropyLoss(weight=torch.FloatTensor(class_weights))
print(criterion.type)
criterion.to(device)

qat_policy = {
    'start_epoch': 100,
    'weight_bits': 8
    }
print('Epochs: ', num_epochs)
# print('Optimizer: \n',optimizer)
print('Loss Function: \n',criterion)
print('QAT: \n',qat_policy)

ai8x.set_device(device=85, simulate=False, round_avg=False)

mod = importlib.import_module("models.ai85net-kws20-v3")

for fl in range (0,8):
    model = mod.AI85KWS20Netv3(num_classes=21, num_channels=128, dimensions=(128, 1), bias=False)
    print(f'Number of Model Params: {count_params(model)}')

    # WEIGHTS OF REFERENCE MODEL
    model, compression_scheduler, optimizer, start_epoch = apputils.load_checkpoint(
                model, "../logs/kws20_original/qat_best.pth.tar")

    # FREEZE SOME LAYERS
    if fl >= 0: freeze_layer(model.voice_conv1)
    if fl >= 1: freeze_layer(model.voice_conv2)
    if fl >= 2: freeze_layer(model.voice_conv3)
    if fl >= 3: freeze_layer(model.voice_conv4)
    if fl >= 4: freeze_layer(model.kws_conv1)
    if fl >= 5: freeze_layer(model.kws_conv2)
    if fl >= 6: freeze_layer(model.kws_conv3)
    if fl >= 7: freeze_layer(model.kws_conv4)
    model.fc = ai8x.Linear(256, len(classes), bias=False, wide=True)

    model = model.to(device)
    
    optimizer = optim.Adam(model.parameters(), lr=0.0001)
    ms_lr_scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[500, 1000], gamma=0.2)

    best_acc = 0
    best_qat_acc = 0
    best_loss = 0
    best_epoch = 0

    train_acc = []
    train_loss = []
    val_acc = []
    val_loss =[]
    running_class_acc = []

    

    continue_train = True
    epoch = 0
    while(epoch < num_epochs):
        train_start = time.time()
        if epoch > 0 and epoch == qat_policy['start_epoch']:
            print('QAT is starting!')
            # Fuse the BN parameters into conv layers before Quantization Aware Training (QAT)
            ai8x.fuse_bn_layers(model)
            # Switch model from unquantized to quantized for QAT
            ai8x.initiate_qat(model, qat_policy)
            # Model is re-transferred to GPU in case parameters were added
            model.to(device)

        average_acc = 0
        ############ TRAIN SECTION ############
        running_loss = []
        y_pred_train = []
        y_true_train = []
        acc_b = []
        model.train()
        for idx, (inputs, target) in enumerate(train_loader):
            inputs = inputs.to(device)
            target = target.type(torch.int64)
            target = target.to(device)
            optimizer.zero_grad()
            
            model_out = model(inputs)
            target_out = torch.argmax(model_out, dim=1)
            
            y_pred_train.extend(target_out.cpu().numpy())
            y_true_train.extend(target.cpu().numpy())
            
            tp = torch.sum(target_out == target)
            acc_b.extend([(tp / target_out.numel()).detach().item()])

            loss = criterion(model_out, target)     
            loss.backward()
            optimizer.step()
            
            running_loss.append(loss.cpu().detach().numpy())
        
        total_acc = np.mean(acc_b)*100
        mean_loss = np.mean(running_loss)

        # TRAIN ACCURACY / TRAIN LOSS
        train_acc.append(total_acc)
        train_loss.append(mean_loss)
        average_acc += total_acc*0.5

        ############ VALIDATION SECTION ############
        acc_b = []
        y_pred_val = []
        y_true_val = []
        running_v_loss = []
        
        model.eval()
        with torch.no_grad():
            for inputs, target in val_loader:
                inputs = inputs.to(device)
                target = target.to(device)
                model_out = model(inputs)
                target_out = torch.argmax(model_out, dim=1)
                
                y_pred_val.extend(target_out.cpu().numpy())
                y_true_val.extend(target.cpu().numpy())
                
                tp = torch.sum(target_out == target)
                acc_b.extend([(tp / target_out.numel()).detach().item()])

                v_loss = criterion(model_out, target)
                running_v_loss.append(loss.cpu().detach().numpy())

            total_acc = np.mean(acc_b)*100
            mean_loss = np.mean(running_v_loss)

            if epoch == qat_policy['start_epoch']: best_acc = 0
            
            # VALIDATION ACCURACY / VALIDATION LOSS
            val_acc.append(total_acc)
            val_loss.append(mean_loss)
            average_acc += total_acc*0.5
        
        ############ CLASS ACCURACY ############
        class_acc = np.zeros(len(classes))
        for class_num,class_type in enumerate(classes):
            class_count_train = y_true_train.count(class_num)
            class_count_val = y_true_val.count(class_num)

            for t_idx, targ_val in enumerate(y_true_train):
                if targ_val == y_pred_train[t_idx] and targ_val == class_num:
                    class_acc[class_num] += 1/class_count_train*10

            for t_idx, targ_val in enumerate(y_true_val):
                if targ_val == y_pred_val[t_idx] and targ_val == class_num:
                    class_acc[class_num] += 1/class_count_val*90
            
        running_class_acc.append(class_acc)
        
        train_end = time.time()
        print('---------------------------------------------')
        print("\n\n Epoch: {}/{} \tLR: {} \tDur: {:.2f} sec".format(epoch+1, num_epochs, ms_lr_scheduler.get_lr() , (train_end-train_start)))

        ############ CONFUSION MATRIX ############   
        print("\n Training - Confusion Matrix: ")
        plot_confusion(y_true_train, y_pred_train, classes)
        print("\n Validation - Confusion Matrix: ")
        plot_confusion(y_true_val, y_pred_val, classes)
        
        ############ ACC and LOSS ############  
        print('\nTrain Acc : ', train_acc[-1])
        print('Train Loss : ', train_loss[-1])
        print('Val Acc : ', val_acc[-1])
        print('Val Loss : ', val_loss[-1])

        ############ PLOTS ############
        if (epoch%10 == 0 or epoch==num_epochs-1) and epoch > 0:
            best_epoch = checkpoint_extras['best_epoch']
            
            plt.figure(figsize=(20,10),dpi=1000)
            plt.title(model_name)
            plt.subplot(1,2,1)
            plt.plot(np.asarray(running_class_acc)[:,0],color='orange')
            plt.plot(np.asarray(running_class_acc)[:,1],color='yellow')
            plt.plot(val_acc, color ='green')
            plt.plot(train_acc, color = 'red')
            plt.stem(best_epoch,train_acc[best_epoch])
            plt.legend([classes[0],classes[1],'Validation','Train','Checkpoint'])
            plt.title('Train Acc: {:.2f}   Val Acc: {:.2f}'.format(train_acc[best_epoch],val_acc[best_epoch]))
            plt.xlabel('Epochs')
            plt.ylabel('Value')

            plt.subplot(1,2,2)
            plt.plot(val_loss,color='green')
            plt.plot(train_loss,color='red')
            plt.stem(best_epoch,train_loss[best_epoch])
            plt.legend(['Validation','Train','Checkpoint'])
            plt.title('Train Loss: {:.2f}   Train Loss: {:.2f}'.format(train_loss[best_epoch],val_loss[best_epoch]))
            plt.xlabel('Epochs')
            plt.ylabel('Value')

            plt.savefig(checkpoint_dir+model_name+'_'+str(fl)+'.png')
            
            plt.clf()
            plt.cla()
            plt.close()
        
        ############ CHECKPOINT CRITERION ############   
        if average_acc > best_acc:
            best_acc = average_acc

            # SAVE CHECKPOINT
            checkpoint_extras = {'best_ave_acc': best_acc,'best_epoch': epoch}
            # model_prefix = f'{model_name}' if epoch < qat_policy['start_epoch'] else (f'qat_{model_name}')
            # apputils.save_checkpoint(epoch, model_name, model, optimizer=optimizer,
            #                             scheduler=None, extras=checkpoint_extras,
            #                             is_best=True, name=model_prefix,
            #                             dir=checkpoint_dir)

            # PLOT CONFUSION MATRIX AND STAT MEASURES ON TRAIN
            conf_mat_train = confusion_matrix(y_true_train, y_pred_train)
            cm_display_train = ConfusionMatrixDisplay(confusion_matrix = conf_mat_train, display_labels = classes)
            p_train,r_train,f1_train,_= precision_recall_fscore_support(y_true_train, y_pred_train, average=None)
            cm_display_train.plot(cmap= 'Blues',colorbar=False, values_format = 'd')
            plt.title('Preicison: ({:.2f} {:.2f})   Recall: ({:.2f} {:.2f})   F1-Score: ({:.2f} {:.2f})'.format(p_train[0],p_train[1],r_train[0],r_train[1],f1_train[0],f1_train[1]))
            plt.savefig(checkpoint_dir+model_name+'_'+str(fl)+'_cm_train.png')
            plt.clf()
            plt.cla()
            plt.close()

            # PLOT CONFUSION MATRIX AND STAT MEASURES ON VALIDATION
            conf_mat_val = confusion_matrix(y_true_val, y_pred_val)
            cm_display_val = ConfusionMatrixDisplay(confusion_matrix = conf_mat_val, display_labels = classes)
            p_val,r_val,f1_val,_= precision_recall_fscore_support(y_true_val, y_pred_val, average=None)
            cm_display_val.plot(cmap= 'Blues',colorbar=False, values_format = 'd')
            plt.title('Preicison: ({:.2f} {:.2f})   Recall: ({:.2f} {:.2f})   F1-Score: ({:.2f} {:.2f})'.format(p_val[0],p_val[1],r_val[0],r_val[1],f1_val[0],f1_val[1]))
            plt.savefig(checkpoint_dir+model_name+'_'+str(fl)+'_cm_Val.png')
            plt.clf()
            plt.cla()
            plt.close()

            # PLOT ROC ON VAL
            plot_roc_curve(y_true_val, y_pred_val)
            plt.title('AUC: {:.2f}'.format(roc_auc_score(y_true_val, y_pred_val)))
            plt.savefig(checkpoint_dir+model_name+'_'+str(fl)+'_roc_val.png')
            plt.clf()
            plt.cla()
            plt.close()

            print(' --------------------------------------------------------->  EPOCH {:.0f} Checkpoint Saved w/ Acc: {:.2f}% '.format(best_epoch,best_acc))
        
        ############ STOP TRAINING ############ 
        if epoch > num_epochs*0.75 and best_acc > 80 and average_acc > best_acc:
            print('Ending Training, Best Checkpoint Found')
            continue_train = False
            break
        
        ms_lr_scheduler.step()
        epoch += 1
# Out:
# <bound method Module.type of CrossEntropyLoss()>
# Epochs:  3000
# Loss Function:
#  CrossEntropyLoss()
# QAT:
#  {'start_epoch': 100, 'weight_bits': 8}
# Configuring device: MAX78000, simulate=False.
# 169472
# Number of Model Params: 169472
# ---------------------------------------------
#
#
#  Epoch: 1/3000 	LR: [0.0001] 	Dur: 5.34 sec
#
#  Training - Confusion Matrix:
# [[ 1613 10781]
#  [ 1165 11477]]
#
#  Validation - Confusion Matrix:
# [[ 373 1210]
#  [ 303 1244]]
#
# Train Acc :  52.49120422771999
# Train Loss :  0.7094678
# Val Acc :  51.66134238243103
# Val Loss :  0.7023412
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 52.08%
# ---------------------------------------------
#
#
#  Epoch: 2/3000 	LR: [0.0001] 	Dur: 3.13 sec
#
#  Training - Confusion Matrix:
# [[3714 8680]
#  [2962 9680]]
#
#  Validation - Confusion Matrix:
# [[ 669  914]
#  [ 520 1027]]
#
# Train Acc :  53.6341769354684
# Train Loss :  0.6933359
# Val Acc :  54.185301065444946
# Val Loss :  0.6811513
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 53.91%
# ---------------------------------------------
#
#
#  Epoch: 3/3000 	LR: [0.0001] 	Dur: 3.27 sec
#
#  Training - Confusion Matrix:
# [[5788 6606]
#  [4795 7847]]
#
#  Validation - Confusion Matrix:
# [[865 718]
#  [710 837]]
#
# Train Acc :  54.25417252949306
# Train Loss :  0.6884552
# Val Acc :  54.37699556350708
# Val Loss :  0.69165176
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 54.32%
# ---------------------------------------------
#
#
#  Epoch: 4/3000 	LR: [0.0001] 	Dur: 3.39 sec
#
#  Training - Confusion Matrix:
# [[7090 5304]
#  [5851 6791]]
#
#  Validation - Confusion Matrix:
# [[947 636]
#  [751 796]]
#
# Train Acc :  55.33269814082554
# Train Loss :  0.68420345
# Val Acc :  55.68689703941345
# Val Loss :  0.6866212
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 55.51%
# ---------------------------------------------
#
#
#  Epoch: 5/3000 	LR: [0.0001] 	Dur: 3.27 sec
#
#  Training - Confusion Matrix:
# [[7361 5033]
#  [5860 6782]]
#
#  Validation - Confusion Matrix:
# [[923 660]
#  [696 851]]
#
# Train Acc :  56.74270902361188
# Train Loss :  0.68071747
# Val Acc :  56.67731761932373
# Val Loss :  0.6819602
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 56.71%
# ---------------------------------------------
#
#
#  Epoch: 6/3000 	LR: [0.0001] 	Dur: 3.06 sec
#
#  Training - Confusion Matrix:
# [[7166 5228]
#  [5444 7198]]
#
#  Validation - Confusion Matrix:
# [[918 665]
#  [649 898]]
#
# Train Acc :  57.485927002770566
# Train Loss :  0.6767561
# Val Acc :  58.01916718482971
# Val Loss :  0.67770976
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 57.75%
# ---------------------------------------------
#
#
#  Epoch: 7/3000 	LR: [0.0001] 	Dur: 3.07 sec
#
#  Training - Confusion Matrix:
# [[6985 5409]
#  [5001 7641]]
#
#  Validation - Confusion Matrix:
# [[866 717]
#  [593 954]]
#
# Train Acc :  58.31700648580279
# Train Loss :  0.6724977
# Val Acc :  58.14696550369263
# Val Loss :  0.66899544
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 58.23%
# ---------------------------------------------
#
#
#  Epoch: 8/3000 	LR: [0.0001] 	Dur: 3.28 sec
#
#  Training - Confusion Matrix:
# [[6855 5539]
#  [4786 7856]]
#
#  Validation - Confusion Matrix:
# [[899 684]
#  [580 967]]
#
# Train Acc :  58.50319010870797
# Train Loss :  0.6710499
# Val Acc :  59.61661338806152
# Val Loss :  0.6741347
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 59.06%
# ---------------------------------------------
#
#
#  Epoch: 9/3000 	LR: [0.0001] 	Dur: 3.41 sec
#
#  Training - Confusion Matrix:
# [[7022 5372]
#  [4677 7965]]
#
#  Validation - Confusion Matrix:
# [[941 642]
#  [598 949]]
#
# Train Acc :  59.796620266778135
# Train Loss :  0.6641911
# Val Acc :  60.38338541984558
# Val Loss :  0.6559074
#  --------------------------------------------------------->  EPOCH 0 Checkpoint Saved w/ Acc: 60.09%
# ---------------------------------------------
#
#
#  Epoch: 10/3000 	LR: [0.0001] 	Dur: 3.26 sec
#
#  Training - Confusion Matrix:
# [[7138 5256]
#  [4785 7857]]
#
#  Validation - Confusion Matrix:
# [[936 647]
#  [597 950]]
#
# Train Acc :  59.65911235128131
# Train Loss :  0.66633505
# Val Acc :  60.255587100982666
# Val Loss :  0.6763874
# ---------------------------------------------
#
#
#  Epoch: 11/3000 	LR: [0.0001] 	Dur: 3.20 sec
#
#  Training - Confusion Matrix:
# [[7435 4959]
#  [4824 7818]]
#
#  Validation - Confusion Matrix:
# [[972 611]
#  [583 964]]
#
# Train Acc :  61.00003634180341
# Train Loss :  0.66183245
# Val Acc :  61.85303330421448
# Val Loss :  0.66760546
#  --------------------------------------------------------->  EPOCH 8 Checkpoint Saved w/ Acc: 61.43%
# ---------------------------------------------
#
#
#  Epoch: 12/3000 	LR: [0.0001] 	Dur: 3.39 sec
#
#  Training - Confusion Matrix:
# [[7586 4808]
#  [4957 7685]]
#
#  Validation - Confusion Matrix:
# [[1003  580]
#  [ 595  952]]
#
# Train Acc :  60.86983765874591
# Train Loss :  0.659492
# Val Acc :  62.46006488800049
# Val Loss :  0.66784567
#  --------------------------------------------------------->  EPOCH 8 Checkpoint Saved w/ Acc: 61.66%
# ---------------------------------------------
#
#
#  Epoch: 13/3000 	LR: [0.0001] 	Dur: 3.25 sec
#
#  Training - Confusion Matrix:
# [[7589 4805]
#  [4747 7895]]
#
#  Validation - Confusion Matrix:
# [[978 605]
#  [589 958]]
#
# Train Acc :  61.640290703092305
# Train Loss :  0.6563679
# Val Acc :  61.85303330421448
# Val Loss :  0.66335416
#  --------------------------------------------------------->  EPOCH 8 Checkpoint Saved w/ Acc: 61.75%
# ---------------------------------------------
#
#
#  Epoch: 14/3000 	LR: [0.0001] 	Dur: 3.12 sec
#
#  Training - Confusion Matrix:
# [[7784 4610]
#  [4735 7907]]
#
#  Validation - Confusion Matrix:
# [[991 592]
#  [570 977]]
#
# Train Acc :  62.74820395878383
# Train Loss :  0.65047914
# Val Acc :  62.87539601325989
# Val Loss :  0.65589476
#  --------------------------------------------------------->  EPOCH 8 Checkpoint Saved w/ Acc: 62.81%
# ---------------------------------------------
#
#
#  Epoch: 15/3000 	LR: [0.0001] 	Dur: 3.20 sec
#
#  Training - Confusion Matrix:
# [[7754 4640]
#  [4749 7893]]
#
#  Validation - Confusion Matrix:
# [[1027  556]
#  [ 560  987]]
#
# Train Acc :  62.01581273760114
# Train Loss :  0.6512353
# Val Acc :  64.34504389762878
# Val Loss :  0.6652225
#  --------------------------------------------------------->  EPOCH 8 Checkpoint Saved w/ Acc: 63.18%
# ---------------------------------------------
#
#
#  Epoch: 16/3000 	LR: [0.0001] 	Dur: 3.10 sec
#
#  Training - Confusion Matrix:
# [[7891 4503]
#  [4739 7903]]
#
#  Validation - Confusion Matrix:
# [[1015  568]
#  [ 582  965]]
#
# Train Acc :  63.02473545074463
# Train Loss :  0.6463954
# Val Acc :  63.258785009384155
# Val Loss :  0.649892
# ---------------------------------------------
#
#
#  Epoch: 17/3000 	LR: [0.0001] 	Dur: 3.12 sec
#
#  Training - Confusion Matrix:
# [[7915 4479]
#  [4727 7915]]
#
#  Validation - Confusion Matrix:
# [[1024  559]
#  [ 569  978]]
#
# Train Acc :  63.28813433647156
# Train Loss :  0.6441994
# Val Acc :  63.961660861968994
# Val Loss :  0.6460877
#  --------------------------------------------------------->  EPOCH 8 Checkpoint Saved w/ Acc: 63.62%
# ---------------------------------------------
#
#
#  Epoch: 18/3000 	LR: [0.0001] 	Dur: 3.23 sec
#
#  Training - Confusion Matrix:
# [[7962 4432]
#  [4703 7939]]
#
#  Validation - Confusion Matrix:
# [[1054  529]
#  [ 570  977]]
#
# Train Acc :  63.48062583378383
# Train Loss :  0.6414479
# Val Acc :  64.88817930221558
# Val Loss :  0.6392284
#  --------------------------------------------------------->  EPOCH 8 Checkpoint Saved w/ Acc: 64.18%
# ---------------------------------------------
#
#
#  Epoch: 19/3000 	LR: [0.0001] 	Dur: 3.10 sec
#
#  Training - Confusion Matrix:
# [[8068 4326]
#  [4688 7954]]
#
#  Validation - Confusion Matrix:
# [[1083  500]
#  [ 578  969]]
#
# Train Acc :  63.737231492996216
# Train Loss :  0.63777894
# Val Acc :  65.5591070652008
# Val Loss :  0.6392347
#  --------------------------------------------------------->  EPOCH 8 Checkpoint Saved w/ Acc: 64.65%
# ---------------------------------------------
#
#
#  Epoch: 20/3000 	LR: [0.0001] 	Dur: 3.13 sec
#
#  Training - Confusion Matrix:
# [[8207 4187]
#  [4784 7858]]
#
#  Validation - Confusion Matrix:
# [[1068  515]
#  [ 596  951]]
#
# Train Acc :  64.57640784127372
# Train Loss :  0.635508
# Val Acc :  64.50479030609131
# Val Loss :  0.6260304
# ---------------------------------------------
#
#
#  Epoch: 21/3000 	LR: [0.0001] 	Dur: 3.05 sec
#
#  Training - Confusion Matrix:
# [[8237 4157]
#  [4794 7848]]
#
#  Validation - Confusion Matrix:
# [[1087  496]
#  [ 585  962]]
#
# Train Acc :  64.26020775522504
# Train Loss :  0.63652235
# Val Acc :  65.4632568359375
# Val Loss :  0.638748
#  --------------------------------------------------------->  EPOCH 18 Checkpoint Saved w/ Acc: 64.86%
# ---------------------------------------------
#
#
#  Epoch: 22/3000 	LR: [0.0001] 	Dur: 3.13 sec
#
#  Training - Confusion Matrix:
# [[8234 4160]
#  [4766 7876]]
#
#  Validation - Confusion Matrix:
# [[1087  496]
#  [ 588  959]]
#
# Train Acc :  63.87874228613717
# Train Loss :  0.63704604
# Val Acc :  65.36741256713867
# Val Loss :  0.6506081
# ---------------------------------------------
#
#
#  Epoch: 23/3000 	LR: [0.0001] 	Dur: 3.23 sec
#
#  Training - Confusion Matrix:
# [[8255 4139]
#  [4764 7878]]
#
#  Validation - Confusion Matrix:
# [[1076  507]
#  [ 577  970]]
#
# Train Acc :  64.28977761949811
# Train Loss :  0.6340898
# Val Acc :  65.36741256713867
# Val Loss :  0.6388748
# ---------------------------------------------
#
#
#  Epoch: 24/3000 	LR: [0.0001] 	Dur: 3.22 sec
#
#  Training - Confusion Matrix:
# [[8316 4078]
#  [4699 7943]]
#
#  Validation - Confusion Matrix:
# [[1079  504]
#  [ 573  974]]
#
# Train Acc :  64.75679874420166
# Train Loss :  0.63218576
# Val Acc :  65.59105515480042
# Val Loss :  0.6347028
#  --------------------------------------------------------->  EPOCH 18 Checkpoint Saved w/ Acc: 65.17%
# ---------------------------------------------
#
#
#  Epoch: 25/3000 	LR: [0.0001] 	Dur: 3.31 sec
#
#  Training - Confusion Matrix:
# [[8313 4081]
#  [4710 7932]]
#
#  Validation - Confusion Matrix:
# [[1079  504]
#  [ 582  965]]
#
# Train Acc :  64.57012976918902
# Train Loss :  0.63165796
# Val Acc :  65.30351042747498
# Val Loss :  0.63711524
# ---------------------------------------------
#
#
#  Epoch: 26/3000 	LR: [0.0001] 	Dur: 3.23 sec
#
#  Training - Confusion Matrix:
# [[8328 4066]
#  [4637 8005]]
#
#  Validation - Confusion Matrix:
# [[1062  521]
#  [ 557  990]]
#
# Train Acc :  64.90461826324463
# Train Loss :  0.6317397
# Val Acc :  65.5591070652008
# Val Loss :  0.63908154
#  --------------------------------------------------------->  EPOCH 18 Checkpoint Saved w/ Acc: 65.23%
# ---------------------------------------------
#
#
#  Epoch: 27/3000 	LR: [0.0001] 	Dur: 3.10 sec
#
#  Training - Confusion Matrix:
# [[8421 3973]
#  [4712 7930]]
#
#  Validation - Confusion Matrix:
# [[1087  496]
#  [ 568  979]]
#
# Train Acc :  65.18794213022504
# Train Loss :  0.63037235
# Val Acc :  66.00638628005981
# Val Loss :  0.63390464
#  --------------------------------------------------------->  EPOCH 18 Checkpoint Saved w/ Acc: 65.60%
# ---------------------------------------------
#
#
#  Epoch: 28/3000 	LR: [0.0001] 	Dur: 3.35 sec
#
#  Training - Confusion Matrix:
# [[8446 3948]
#  [4698 7944]]
#
#  Validation - Confusion Matrix:
# [[1086  497]
#  [ 562  985]]
#
# Train Acc :  65.29639533587864
# Train Loss :  0.63114244
# Val Acc :  66.16613268852234
# Val Loss :  0.6429829
#  --------------------------------------------------------->  EPOCH 18 Checkpoint Saved w/ Acc: 65.73%
# ---------------------------------------------
#
#
#  Epoch: 29/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[8414 3980]
#  [4641 8001]]
#
#  Validation - Confusion Matrix:
# [[1063  520]
#  [ 548  999]]
#
# Train Acc :  65.52142926624843
# Train Loss :  0.6272489
# Val Acc :  65.87859392166138
# Val Loss :  0.6268239
# ---------------------------------------------
#
#
#  Epoch: 30/3000 	LR: [0.0001] 	Dur: 3.19 sec
#
#  Training - Confusion Matrix:
# [[8360 4034]
#  [4587 8055]]
#
#  Validation - Confusion Matrix:
# [[1069  514]
#  [ 549  998]]
#
# Train Acc :  65.41115641593933
# Train Loss :  0.62798214
# Val Acc :  66.0383403301239
# Val Loss :  0.6379886
# ---------------------------------------------
#
#
#  Epoch: 31/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8394 4000]
#  [4588 8054]]
#
#  Validation - Confusion Matrix:
# [[1080  503]
#  [ 538 1009]]
#
# Train Acc :  65.7743649823325
# Train Loss :  0.6247193
# Val Acc :  66.74121022224426
# Val Loss :  0.626868
#  --------------------------------------------------------->  EPOCH 27 Checkpoint Saved w/ Acc: 66.26%
# ---------------------------------------------
#
#
#  Epoch: 32/3000 	LR: [0.0001] 	Dur: 3.32 sec
#
#  Training - Confusion Matrix:
# [[8532 3862]
#  [4586 8056]]
#
#  Validation - Confusion Matrix:
# [[1091  492]
#  [ 557  990]]
#
# Train Acc :  66.17994223322187
# Train Loss :  0.6241196
# Val Acc :  66.48561954498291
# Val Loss :  0.63133925
#  --------------------------------------------------------->  EPOCH 27 Checkpoint Saved w/ Acc: 66.33%
# ---------------------------------------------
#
#
#  Epoch: 33/3000 	LR: [0.0001] 	Dur: 3.26 sec
#
#  Training - Confusion Matrix:
# [[8513 3881]
#  [4625 8017]]
#
#  Validation - Confusion Matrix:
# [[1074  509]
#  [ 555  992]]
#
# Train Acc :  65.75710858617511
# Train Loss :  0.62412846
# Val Acc :  66.00638628005981
# Val Loss :  0.63353115
# ---------------------------------------------
#
#
#  Epoch: 34/3000 	LR: [0.0001] 	Dur: 3.37 sec
#
#  Training - Confusion Matrix:
# [[8571 3823]
#  [4553 8089]]
#
#  Validation - Confusion Matrix:
# [[1083  500]
#  [ 542 1005]]
#
# Train Acc :  66.29321660314288
# Train Loss :  0.6238435
# Val Acc :  66.70926213264465
# Val Loss :  0.63466287
#  --------------------------------------------------------->  EPOCH 27 Checkpoint Saved w/ Acc: 66.50%
# ---------------------------------------------
#
#
#  Epoch: 35/3000 	LR: [0.0001] 	Dur: 3.13 sec
#
#  Training - Confusion Matrix:
# [[8529 3865]
#  [4579 8063]]
#
#  Validation - Confusion Matrix:
# [[1103  480]
#  [ 549  998]]
#
# Train Acc :  65.9182105745588
# Train Loss :  0.62370855
# Val Acc :  67.12459921836853
# Val Loss :  0.6344151
#  --------------------------------------------------------->  EPOCH 27 Checkpoint Saved w/ Acc: 66.52%
# ---------------------------------------------
#
#
#  Epoch: 36/3000 	LR: [0.0001] 	Dur: 3.10 sec
#
#  Training - Confusion Matrix:
# [[8503 3891]
#  [4566 8076]]
#
#  Validation - Confusion Matrix:
# [[1099  484]
#  [ 558  989]]
#
# Train Acc :  66.53450642313275
# Train Loss :  0.6214148
# Val Acc :  66.70926213264465
# Val Loss :  0.62771565
#  --------------------------------------------------------->  EPOCH 27 Checkpoint Saved w/ Acc: 66.62%
# ---------------------------------------------
#
#
#  Epoch: 37/3000 	LR: [0.0001] 	Dur: 3.16 sec
#
#  Training - Confusion Matrix:
# [[8500 3894]
#  [4533 8109]]
#
#  Validation - Confusion Matrix:
# [[1065  518]
#  [ 535 1012]]
#
# Train Acc :  66.50129726954869
# Train Loss :  0.62295425
# Val Acc :  66.35782718658447
# Val Loss :  0.6339458
# ---------------------------------------------
#
#
#  Epoch: 38/3000 	LR: [0.0001] 	Dur: 3.09 sec
#
#  Training - Confusion Matrix:
# [[8523 3871]
#  [4465 8177]]
#
#  Validation - Confusion Matrix:
# [[1086  497]
#  [ 534 1013]]
#
# Train Acc :  66.23974868229458
# Train Loss :  0.6230045
# Val Acc :  67.06070303916931
# Val Loss :  0.6465834
#  --------------------------------------------------------->  EPOCH 27 Checkpoint Saved w/ Acc: 66.65%
# ---------------------------------------------
#
#
#  Epoch: 39/3000 	LR: [0.0001] 	Dur: 3.29 sec
#
#  Training - Confusion Matrix:
# [[8476 3918]
#  [4512 8130]]
#
#  Validation - Confusion Matrix:
# [[1069  514]
#  [ 523 1024]]
#
# Train Acc :  66.10487954957145
# Train Loss :  0.6192257
# Val Acc :  66.86900854110718
# Val Loss :  0.6168739
# ---------------------------------------------
#
#
#  Epoch: 40/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8480 3914]
#  [4497 8145]]
#
#  Validation - Confusion Matrix:
# [[1075  508]
#  [ 534 1013]]
#
# Train Acc :  66.08844229153225
# Train Loss :  0.61954874
# Val Acc :  66.70926213264465
# Val Loss :  0.635409
# ---------------------------------------------
#
#
#  Epoch: 41/3000 	LR: [0.0001] 	Dur: 3.20 sec
#
#  Training - Confusion Matrix:
# [[8521 3873]
#  [4502 8140]]
#
#  Validation - Confusion Matrix:
# [[1089  494]
#  [ 520 1027]]
#
# Train Acc :  66.5448180266789
# Train Loss :  0.6193164
# Val Acc :  67.60383248329163
# Val Loss :  0.62643737
#  --------------------------------------------------------->  EPOCH 37 Checkpoint Saved w/ Acc: 67.07%
# ---------------------------------------------
#
#
#  Epoch: 42/3000 	LR: [0.0001] 	Dur: 3.30 sec
#
#  Training - Confusion Matrix:
# [[8550 3844]
#  [4571 8071]]
#
#  Validation - Confusion Matrix:
# [[1084  499]
#  [ 529 1018]]
#
# Train Acc :  66.35017309870038
# Train Loss :  0.61914957
# Val Acc :  67.15654730796814
# Val Loss :  0.6205578
# ---------------------------------------------
#
#
#  Epoch: 43/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[8576 3818]
#  [4509 8133]]
#
#  Validation - Confusion Matrix:
# [[1065  518]
#  [ 518 1029]]
#
# Train Acc :  66.3538430418287
# Train Loss :  0.6221677
# Val Acc :  66.90095663070679
# Val Loss :  0.6475327
# ---------------------------------------------
#
#
#  Epoch: 44/3000 	LR: [0.0001] 	Dur: 3.11 sec
#
#  Training - Confusion Matrix:
# [[8499 3895]
#  [4404 8238]]
#
#  Validation - Confusion Matrix:
# [[1072  511]
#  [ 516 1031]]
#
# Train Acc :  66.64447614124843
# Train Loss :  0.617562
# Val Acc :  67.18849539756775
# Val Loss :  0.6212317
# ---------------------------------------------
#
#
#  Epoch: 45/3000 	LR: [0.0001] 	Dur: 3.06 sec
#
#  Training - Confusion Matrix:
# [[8468 3926]
#  [4355 8287]]
#
#  Validation - Confusion Matrix:
# [[1053  530]
#  [ 515 1032]]
#
# Train Acc :  66.84509600911822
# Train Loss :  0.6182276
# Val Acc :  66.61341786384583
# Val Loss :  0.6270801
# ---------------------------------------------
#
#
#  Epoch: 46/3000 	LR: [0.0001] 	Dur: 3.08 sec
#
#  Training - Confusion Matrix:
# [[8498 3896]
#  [4445 8197]]
#
#  Validation - Confusion Matrix:
# [[1075  508]
#  [ 510 1037]]
#
# Train Acc :  66.22231006622314
# Train Loss :  0.6204279
# Val Acc :  67.47603416442871
# Val Loss :  0.64549476
# ---------------------------------------------
#
#
#  Epoch: 47/3000 	LR: [0.0001] 	Dur: 3.32 sec
#
#  Training - Confusion Matrix:
# [[8586 3808]
#  [4405 8237]]
#
#  Validation - Confusion Matrix:
# [[1062  521]
#  [ 515 1032]]
#
# Train Acc :  67.38551088741848
# Train Loss :  0.6136715
# Val Acc :  66.90095663070679
# Val Loss :  0.6111464
#  --------------------------------------------------------->  EPOCH 37 Checkpoint Saved w/ Acc: 67.14%
# ---------------------------------------------
#
#
#  Epoch: 48/3000 	LR: [0.0001] 	Dur: 3.09 sec
#
#  Training - Confusion Matrix:
# [[8488 3906]
#  [4409 8233]]
#
#  Validation - Confusion Matrix:
# [[1053  530]
#  [ 501 1046]]
#
# Train Acc :  66.89192226954869
# Train Loss :  0.6159468
# Val Acc :  67.06070303916931
# Val Loss :  0.6150844
# ---------------------------------------------
#
#
#  Epoch: 49/3000 	LR: [0.0001] 	Dur: 3.11 sec
#
#  Training - Confusion Matrix:
# [[8443 3951]
#  [4329 8313]]
#
#  Validation - Confusion Matrix:
# [[1045  538]
#  [ 496 1051]]
#
# Train Acc :  66.82101573262896
# Train Loss :  0.6176104
# Val Acc :  66.964852809906
# Val Loss :  0.6289305
# ---------------------------------------------
#
#
#  Epoch: 50/3000 	LR: [0.0001] 	Dur: 3.22 sec
#
#  Training - Confusion Matrix:
# [[8476 3918]
#  [4305 8337]]
#
#  Validation - Confusion Matrix:
# [[1048  535]
#  [ 495 1052]]
#
# Train Acc :  66.90954310553414
# Train Loss :  0.6145592
# Val Acc :  67.09265112876892
# Val Loss :  0.6273742
# ---------------------------------------------
#
#
#  Epoch: 51/3000 	LR: [0.0001] 	Dur: 3.11 sec
#
#  Training - Confusion Matrix:
# [[8566 3828]
#  [4337 8305]]
#
#  Validation - Confusion Matrix:
# [[1052  531]
#  [ 498 1049]]
#
# Train Acc :  67.52535360200065
# Train Loss :  0.61425596
# Val Acc :  67.12459921836853
# Val Loss :  0.6218926
#  --------------------------------------------------------->  EPOCH 46 Checkpoint Saved w/ Acc: 67.32%
# ---------------------------------------------
#
#
#  Epoch: 52/3000 	LR: [0.0001] 	Dur: 3.18 sec
#
#  Training - Confusion Matrix:
# [[8514 3880]
#  [4373 8269]]
#
#  Validation - Confusion Matrix:
# [[1059  524]
#  [ 507 1040]]
#
# Train Acc :  66.80491140910557
# Train Loss :  0.61758953
# Val Acc :  67.06070303916931
# Val Loss :  0.6369419
# ---------------------------------------------
#
#
#  Epoch: 53/3000 	LR: [0.0001] 	Dur: 3.20 sec
#
#  Training - Confusion Matrix:
# [[8423 3971]
#  [4371 8271]]
#
#  Validation - Confusion Matrix:
# [[1042  541]
#  [ 502 1045]]
#
# Train Acc :  66.63234489304679
# Train Loss :  0.6172331
# Val Acc :  66.67731404304504
# Val Loss :  0.6251724
# ---------------------------------------------
#
#
#  Epoch: 54/3000 	LR: [0.0001] 	Dur: 3.06 sec
#
#  Training - Confusion Matrix:
# [[8371 4023]
#  [4253 8389]]
#
#  Validation - Confusion Matrix:
# [[1054  529]
#  [ 508 1039]]
#
# Train Acc :  66.9452394757952
# Train Loss :  0.6143399
# Val Acc :  66.86900854110718
# Val Loss :  0.62190455
# ---------------------------------------------
#
#
#  Epoch: 55/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[8503 3891]
#  [4304 8338]]
#
#  Validation - Confusion Matrix:
# [[1069  514]
#  [ 481 1066]]
#
# Train Acc :  67.03476735523769
# Train Loss :  0.615481
# Val Acc :  68.21086406707764
# Val Loss :  0.6251701
#  --------------------------------------------------------->  EPOCH 46 Checkpoint Saved w/ Acc: 67.62%
# ---------------------------------------------
#
#
#  Epoch: 56/3000 	LR: [0.0001] 	Dur: 3.38 sec
#
#  Training - Confusion Matrix:
# [[8449 3945]
#  [4302 8340]]
#
#  Validation - Confusion Matrix:
# [[1080  503]
#  [ 475 1072]]
#
# Train Acc :  66.93611059870038
# Train Loss :  0.6144118
# Val Acc :  68.75399351119995
# Val Loss :  0.6146197
#  --------------------------------------------------------->  EPOCH 46 Checkpoint Saved w/ Acc: 67.85%
# ---------------------------------------------
#
#
#  Epoch: 57/3000 	LR: [0.0001] 	Dur: 3.10 sec
#
#  Training - Confusion Matrix:
# [[8469 3925]
#  [4270 8372]]
#
#  Validation - Confusion Matrix:
# [[1084  499]
#  [ 493 1054]]
#
# Train Acc :  67.03476735523769
# Train Loss :  0.6152452
# Val Acc :  68.30670833587646
# Val Loss :  0.6271457
# ---------------------------------------------
#
#
#  Epoch: 58/3000 	LR: [0.0001] 	Dur: 3.13 sec
#
#  Training - Confusion Matrix:
# [[8685 3709]
#  [4386 8256]]
#
#  Validation - Confusion Matrix:
# [[1095  488]
#  [ 495 1052]]
#
# Train Acc :  67.76949422700065
# Train Loss :  0.6116515
# Val Acc :  68.59424710273743
# Val Loss :  0.62042445
#  --------------------------------------------------------->  EPOCH 46 Checkpoint Saved w/ Acc: 68.18%
# ---------------------------------------------
#
#
#  Epoch: 59/3000 	LR: [0.0001] 	Dur: 3.23 sec
#
#  Training - Confusion Matrix:
# [[8641 3753]
#  [4409 8233]]
#
#  Validation - Confusion Matrix:
# [[1089  494]
#  [ 510 1037]]
#
# Train Acc :  67.6460896219526
# Train Loss :  0.6117592
# Val Acc :  67.9233193397522
# Val Loss :  0.61525404
# ---------------------------------------------
#
#
#  Epoch: 60/3000 	LR: [0.0001] 	Dur: 3.19 sec
#
#  Training - Confusion Matrix:
# [[8587 3807]
#  [4312 8330]]
#
#  Validation - Confusion Matrix:
# [[1081  502]
#  [ 493 1054]]
#
# Train Acc :  67.57551601954869
# Train Loss :  0.6115756
# Val Acc :  68.21086406707764
# Val Loss :  0.61901253
# ---------------------------------------------
#
#
#  Epoch: 61/3000 	LR: [0.0001] 	Dur: 3.07 sec
#
#  Training - Confusion Matrix:
# [[8453 3941]
#  [4266 8376]]
#
#  Validation - Confusion Matrix:
# [[1059  524]
#  [ 494 1053]]
#
# Train Acc :  67.241028376988
# Train Loss :  0.6120611
# Val Acc :  67.47603416442871
# Val Loss :  0.61748147
# ---------------------------------------------
#
#
#  Epoch: 62/3000 	LR: [0.0001] 	Dur: 3.43 sec
#
#  Training - Confusion Matrix:
# [[8576 3818]
#  [4239 8403]]
#
#  Validation - Confusion Matrix:
# [[1060  523]
#  [ 486 1061]]
#
# Train Acc :  67.59877800941467
# Train Loss :  0.6106776
# Val Acc :  67.76357889175415
# Val Loss :  0.6237267
# ---------------------------------------------
#
#
#  Epoch: 63/3000 	LR: [0.0001] 	Dur: 3.30 sec
#
#  Training - Confusion Matrix:
# [[8619 3775]
#  [4314 8328]]
#
#  Validation - Confusion Matrix:
# [[1088  495]
#  [ 490 1057]]
#
# Train Acc :  67.62501171657017
# Train Loss :  0.6103559
# Val Acc :  68.53035092353821
# Val Loss :  0.61791813
# ---------------------------------------------
#
#
#  Epoch: 64/3000 	LR: [0.0001] 	Dur: 3.10 sec
#
#  Training - Confusion Matrix:
# [[8675 3719]
#  [4401 8241]]
#
#  Validation - Confusion Matrix:
# [[1073  510]
#  [ 498 1049]]
#
# Train Acc :  67.26877859660557
# Train Loss :  0.6118021
# Val Acc :  67.79552698135376
# Val Loss :  0.6296107
# ---------------------------------------------
#
#
#  Epoch: 65/3000 	LR: [0.0001] 	Dur: 3.02 sec
#
#  Training - Confusion Matrix:
# [[8618 3776]
#  [4296 8346]]
#
#  Validation - Confusion Matrix:
# [[1051  532]
#  [ 485 1062]]
#
# Train Acc :  67.46375731059483
# Train Loss :  0.60882044
# Val Acc :  67.5079882144928
# Val Loss :  0.61975676
# ---------------------------------------------
#
#
#  Epoch: 66/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8546 3848]
#  [4186 8456]]
#
#  Validation - Confusion Matrix:
# [[1071  512]
#  [ 493 1054]]
#
# Train Acc :  67.92710934366498
# Train Loss :  0.6091284
# Val Acc :  67.89137125015259
# Val Loss :  0.6112368
# ---------------------------------------------
#
#
#  Epoch: 67/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[8559 3835]
#  [4213 8429]]
#
#  Validation - Confusion Matrix:
# [[1052  531]
#  [ 486 1061]]
#
# Train Acc :  67.68530351775033
# Train Loss :  0.6098065
# Val Acc :  67.5079882144928
# Val Loss :  0.6155812
# ---------------------------------------------
#
#
#  Epoch: 68/3000 	LR: [0.0001] 	Dur: 3.20 sec
#
#  Training - Confusion Matrix:
# [[8590 3804]
#  [4302 8340]]
#
#  Validation - Confusion Matrix:
# [[1060  523]
#  [ 494 1053]]
#
# Train Acc :  67.31760672160557
# Train Loss :  0.60873073
# Val Acc :  67.5079882144928
# Val Loss :  0.6138753
# ---------------------------------------------
#
#
#  Epoch: 69/3000 	LR: [0.0001] 	Dur: 3.22 sec
#
#  Training - Confusion Matrix:
# [[8626 3768]
#  [4221 8421]]
#
#  Validation - Confusion Matrix:
# [[1056  527]
#  [ 482 1065]]
#
# Train Acc :  68.00135203770229
# Train Loss :  0.6083817
# Val Acc :  67.76357889175415
# Val Loss :  0.6181109
# ---------------------------------------------
#
#
#  Epoch: 70/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8509 3885]
#  [4151 8491]]
#
#  Validation - Confusion Matrix:
# [[1049  534]
#  [ 481 1066]]
#
# Train Acc :  67.53417934690204
# Train Loss :  0.6114839
# Val Acc :  67.57188439369202
# Val Loss :  0.624947
# ---------------------------------------------
#
#
#  Epoch: 71/3000 	LR: [0.0001] 	Dur: 4.06 sec
#
#  Training - Confusion Matrix:
# [[8432 3962]
#  [4063 8579]]
#
#  Validation - Confusion Matrix:
# [[1044  539]
#  [ 481 1066]]
#
# Train Acc :  67.9860668522971
# Train Loss :  0.6103851
# Val Acc :  67.41213798522949
# Val Loss :  0.61297256
# ---------------------------------------------
#
#
#  Epoch: 72/3000 	LR: [0.0001] 	Dur: 3.31 sec
#
#  Training - Confusion Matrix:
# [[8361 4033]
#  [4085 8557]]
#
#  Validation - Confusion Matrix:
# [[1048  535]
#  [ 482 1065]]
#
# Train Acc :  67.41359489304679
# Train Loss :  0.6136046
# Val Acc :  67.5079882144928
# Val Loss :  0.6274091
# ---------------------------------------------
#
#
#  Epoch: 73/3000 	LR: [0.0001] 	Dur: 3.18 sec
#
#  Training - Confusion Matrix:
# [[8428 3966]
#  [4124 8518]]
#
#  Validation - Confusion Matrix:
# [[1050  533]
#  [ 507 1040]]
#
# Train Acc :  67.40097829273769
# Train Loss :  0.6109668
# Val Acc :  66.77316427230835
# Val Loss :  0.6219079
# ---------------------------------------------
#
#
#  Epoch: 74/3000 	LR: [0.0001] 	Dur: 3.16 sec
#
#  Training - Confusion Matrix:
# [[8535 3859]
#  [4127 8515]]
#
#  Validation - Confusion Matrix:
# [[1060  523]
#  [ 501 1046]]
#
# Train Acc :  67.92911120823452
# Train Loss :  0.61080015
# Val Acc :  67.28434562683105
# Val Loss :  0.61719555
# ---------------------------------------------
#
#
#  Epoch: 75/3000 	LR: [0.0001] 	Dur: 3.20 sec
#
#  Training - Confusion Matrix:
# [[8440 3954]
#  [4135 8507]]
#
#  Validation - Confusion Matrix:
# [[1030  553]
#  [ 490 1057]]
#
# Train Acc :  67.26662516593933
# Train Loss :  0.6127859
# Val Acc :  66.67731404304504
# Val Loss :  0.63247657
# ---------------------------------------------
#
#
#  Epoch: 76/3000 	LR: [0.0001] 	Dur: 3.34 sec
#
#  Training - Confusion Matrix:
# [[8441 3953]
#  [4137 8505]]
#
#  Validation - Confusion Matrix:
# [[1052  531]
#  [ 495 1052]]
#
# Train Acc :  67.29070544242859
# Train Loss :  0.61132497
# Val Acc :  67.22044348716736
# Val Loss :  0.6167915
# ---------------------------------------------
#
#
#  Epoch: 77/3000 	LR: [0.0001] 	Dur: 3.31 sec
#
#  Training - Confusion Matrix:
# [[8539 3855]
#  [4167 8475]]
#
#  Validation - Confusion Matrix:
# [[1041  542]
#  [ 492 1055]]
#
# Train Acc :  67.69328032221112
# Train Loss :  0.611637
# Val Acc :  66.964852809906
# Val Loss :  0.62112856
# ---------------------------------------------
#
#
#  Epoch: 78/3000 	LR: [0.0001] 	Dur: 3.10 sec
#
#  Training - Confusion Matrix:
# [[8555 3839]
#  [4194 8448]]
#
#  Validation - Confusion Matrix:
# [[1062  521]
#  [ 505 1042]]
#
# Train Acc :  67.76518821716309
# Train Loss :  0.6082323
# Val Acc :  67.22044348716736
# Val Loss :  0.6120851
# ---------------------------------------------
#
#
#  Epoch: 79/3000 	LR: [0.0001] 	Dur: 3.14 sec
#
#  Training - Confusion Matrix:
# [[8567 3827]
#  [4153 8489]]
#
#  Validation - Confusion Matrix:
# [[1058  525]
#  [ 482 1065]]
#
# Train Acc :  68.03274154663086
# Train Loss :  0.6080357
# Val Acc :  67.82747507095337
# Val Loss :  0.61862147
# ---------------------------------------------
#
#
#  Epoch: 80/3000 	LR: [0.0001] 	Dur: 3.32 sec
#
#  Training - Confusion Matrix:
# [[8628 3766]
#  [4199 8443]]
#
#  Validation - Confusion Matrix:
# [[1095  488]
#  [ 495 1052]]
#
# Train Acc :  68.0574893951416
# Train Loss :  0.6078447
# Val Acc :  68.59424710273743
# Val Loss :  0.6127259
#  --------------------------------------------------------->  EPOCH 57 Checkpoint Saved w/ Acc: 68.33%
# ---------------------------------------------
#
#
#  Epoch: 81/3000 	LR: [0.0001] 	Dur: 3.38 sec
#
#  Training - Confusion Matrix:
# [[8676 3718]
#  [4266 8376]]
#
#  Validation - Confusion Matrix:
# [[1072  511]
#  [ 507 1040]]
#
# Train Acc :  67.79824580465045
# Train Loss :  0.60820687
# Val Acc :  67.47603416442871
# Val Loss :  0.62029433
# ---------------------------------------------
#
#
#  Epoch: 82/3000 	LR: [0.0001] 	Dur: 3.37 sec
#
#  Training - Confusion Matrix:
# [[8634 3760]
#  [4207 8435]]
#
#  Validation - Confusion Matrix:
# [[1083  500]
#  [ 495 1052]]
#
# Train Acc :  67.99537794930595
# Train Loss :  0.60708374
# Val Acc :  68.21086406707764
# Val Loss :  0.60748625
# ---------------------------------------------
#
#
#  Epoch: 83/3000 	LR: [0.0001] 	Dur: 3.14 sec
#
#  Training - Confusion Matrix:
# [[8575 3819]
#  [4127 8515]]
#
#  Validation - Confusion Matrix:
# [[1083  500]
#  [ 498 1049]]
#
# Train Acc :  68.26159698622567
# Train Loss :  0.6085604
# Val Acc :  68.11501383781433
# Val Loss :  0.61646336
# ---------------------------------------------
#
#
#  Epoch: 84/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8561 3833]
#  [4199 8443]]
#
#  Validation - Confusion Matrix:
# [[1075  508]
#  [ 494 1053]]
#
# Train Acc :  67.90651679039001
# Train Loss :  0.6092181
# Val Acc :  67.9872214794159
# Val Loss :  0.61851496
# ---------------------------------------------
#
#
#  Epoch: 85/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[8647 3747]
#  [4209 8433]]
#
#  Validation - Confusion Matrix:
# [[1095  488]
#  [ 500 1047]]
#
# Train Acc :  68.14401490347726
# Train Loss :  0.6052783
# Val Acc :  68.4345006942749
# Val Loss :  0.6021413
# ---------------------------------------------
#
#
#  Epoch: 86/3000 	LR: [0.0001] 	Dur: 3.35 sec
#
#  Training - Confusion Matrix:
# [[8794 3600]
#  [4407 8235]]
#
#  Validation - Confusion Matrix:
# [[1102  481]
#  [ 539 1008]]
#
# Train Acc :  67.96614101954869
# Train Loss :  0.6089271
# Val Acc :  67.41213798522949
# Val Loss :  0.6197381
# ---------------------------------------------
#
#
#  Epoch: 87/3000 	LR: [0.0001] 	Dur: 3.25 sec
#
#  Training - Confusion Matrix:
# [[8739 3655]
#  [4290 8352]]
#
#  Validation - Confusion Matrix:
# [[1070  513]
#  [ 511 1036]]
#
# Train Acc :  68.32022070884705
# Train Loss :  0.60616016
# Val Acc :  67.28434562683105
# Val Loss :  0.6061543
# ---------------------------------------------
#
#
#  Epoch: 88/3000 	LR: [0.0001] 	Dur: 3.06 sec
#
#  Training - Confusion Matrix:
# [[8639 3755]
#  [4168 8474]]
#
#  Validation - Confusion Matrix:
# [[1051  532]
#  [ 487 1060]]
#
# Train Acc :  68.36938261985779
# Train Loss :  0.605025
# Val Acc :  67.4440860748291
# Val Loss :  0.59843755
# ---------------------------------------------
#
#
#  Epoch: 89/3000 	LR: [0.0001] 	Dur: 3.22 sec
#
#  Training - Confusion Matrix:
# [[8557 3837]
#  [4070 8572]]
#
#  Validation - Confusion Matrix:
# [[1074  509]
#  [ 506 1041]]
#
# Train Acc :  68.50789104189191
# Train Loss :  0.6050668
# Val Acc :  67.57188439369202
# Val Loss :  0.6009143
# ---------------------------------------------
#
#
#  Epoch: 90/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[8737 3657]
#  [4281 8361]]
#
#  Validation - Confusion Matrix:
# [[1111  472]
#  [ 501 1046]]
#
# Train Acc :  68.09652192252022
# Train Loss :  0.6075259
# Val Acc :  68.913733959198
# Val Loss :  0.6157488
#  --------------------------------------------------------->  EPOCH 79 Checkpoint Saved w/ Acc: 68.51%
# ---------------------------------------------
#
#
#  Epoch: 91/3000 	LR: [0.0001] 	Dur: 3.22 sec
#
#  Training - Confusion Matrix:
# [[8763 3631]
#  [4281 8361]]
#
#  Validation - Confusion Matrix:
# [[1091  492]
#  [ 496 1051]]
#
# Train Acc :  68.62829327583313
# Train Loss :  0.6044348
# Val Acc :  68.4345006942749
# Val Loss :  0.60116374
#  --------------------------------------------------------->  EPOCH 89 Checkpoint Saved w/ Acc: 68.53%
# ---------------------------------------------
#
#
#  Epoch: 92/3000 	LR: [0.0001] 	Dur: 3.39 sec
#
#  Training - Confusion Matrix:
# [[8662 3732]
#  [4218 8424]]
#
#  Validation - Confusion Matrix:
# [[1077  506]
#  [ 487 1060]]
#
# Train Acc :  68.33035094397408
# Train Loss :  0.6047329
# Val Acc :  68.27476024627686
# Val Loss :  0.6093706
# ---------------------------------------------
#
#
#  Epoch: 93/3000 	LR: [0.0001] 	Dur: 3.33 sec
#
#  Training - Confusion Matrix:
# [[8699 3695]
#  [4152 8490]]
#
#  Validation - Confusion Matrix:
# [[1089  494]
#  [ 473 1074]]
#
# Train Acc :  68.30363188471112
# Train Loss :  0.6045335
# Val Acc :  69.10542845726013
# Val Loss :  0.61841184
#  --------------------------------------------------------->  EPOCH 89 Checkpoint Saved w/ Acc: 68.70%
# ---------------------------------------------
#
#
#  Epoch: 94/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8691 3703]
#  [4218 8424]]
#
#  Validation - Confusion Matrix:
# [[1103  480]
#  [ 498 1049]]
#
# Train Acc :  68.18338121686664
# Train Loss :  0.60476017
# Val Acc :  68.75399351119995
# Val Loss :  0.61220187
# ---------------------------------------------
#
#
#  Epoch: 95/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8776 3618]
#  [4300 8342]]
#
#  Validation - Confusion Matrix:
# [[1100  483]
#  [ 499 1048]]
#
# Train Acc :  68.60736693654742
# Train Loss :  0.6024025
# Val Acc :  68.62619519233704
# Val Loss :  0.59330255
# ---------------------------------------------
#
#
#  Epoch: 96/3000 	LR: [0.0001] 	Dur: 3.00 sec
#
#  Training - Confusion Matrix:
# [[8817 3577]
#  [4282 8360]]
#
#  Validation - Confusion Matrix:
# [[1103  480]
#  [ 498 1049]]
#
# Train Acc :  68.75800575528827
# Train Loss :  0.6025895
# Val Acc :  68.75399351119995
# Val Loss :  0.60125107
#  --------------------------------------------------------->  EPOCH 89 Checkpoint Saved w/ Acc: 68.76%
# ---------------------------------------------
#
#
#  Epoch: 97/3000 	LR: [0.0001] 	Dur: 3.28 sec
#
#  Training - Confusion Matrix:
# [[8826 3568]
#  [4307 8335]]
#
#  Validation - Confusion Matrix:
# [[1112  471]
#  [ 512 1035]]
#
# Train Acc :  68.31624848502022
# Train Loss :  0.6020516
# Val Acc :  68.59424710273743
# Val Loss :  0.6085218
# ---------------------------------------------
#
#
#  Epoch: 98/3000 	LR: [0.0001] 	Dur: 3.11 sec
#
#  Training - Confusion Matrix:
# [[8786 3608]
#  [4303 8339]]
#
#  Validation - Confusion Matrix:
# [[1100  483]
#  [ 506 1041]]
#
# Train Acc :  68.13555359840393
# Train Loss :  0.60229343
# Val Acc :  68.4025526046753
# Val Loss :  0.60469395
# ---------------------------------------------
#
#
#  Epoch: 99/3000 	LR: [0.0001] 	Dur: 3.23 sec
#
#  Training - Confusion Matrix:
# [[8733 3661]
#  [4237 8405]]
#
#  Validation - Confusion Matrix:
# [[1096  487]
#  [ 491 1056]]
#
# Train Acc :  68.2635988507952
# Train Loss :  0.60376656
# Val Acc :  68.75399351119995
# Val Loss :  0.60535824
# ---------------------------------------------
#
#
#  Epoch: 100/3000 	LR: [0.0001] 	Dur: 3.14 sec
#
#  Training - Confusion Matrix:
# [[8705 3689]
#  [4214 8428]]
#
#  Validation - Confusion Matrix:
# [[1074  509]
#  [ 496 1051]]
#
# Train Acc :  68.32886423383441
# Train Loss :  0.6039441
# Val Acc :  67.89137125015259
# Val Loss :  0.6049837
# QAT is starting!
# ---------------------------------------------
#
#
#  Epoch: 101/3000 	LR: [0.0001] 	Dur: 3.46 sec
#
#  Training - Confusion Matrix:
# [[7947 4447]
#  [4500 8142]]
#
#  Validation - Confusion Matrix:
# [[1285  298]
#  [1165  382]]
#
# Train Acc :  63.970908948353355
# Train Loss :  1.3340274
# Val Acc :  53.258782625198364
# Val Loss :  1.0129472
#  --------------------------------------------------------->  EPOCH 95 Checkpoint Saved w/ Acc: 58.61%
# ---------------------------------------------
#
#
#  Epoch: 102/3000 	LR: [0.0001] 	Dur: 3.31 sec
#
#  Training - Confusion Matrix:
# [[8764 3630]
#  [6303 6339]]
#
#  Validation - Confusion Matrix:
# [[1000  583]
#  [ 571  976]]
#
# Train Acc :  60.449309008462095
# Train Loss :  0.9113328
# Val Acc :  63.13098669052124
# Val Loss :  0.852324
#  --------------------------------------------------------->  EPOCH 95 Checkpoint Saved w/ Acc: 61.79%
# ---------------------------------------------
#
#
#  Epoch: 103/3000 	LR: [0.0001] 	Dur: 3.27 sec
#
#  Training - Confusion Matrix:
# [[6949 5445]
#  [3668 8974]]
#
#  Validation - Confusion Matrix:
# [[1242  341]
#  [ 755  792]]
#
# Train Acc :  63.75033344541278
# Train Loss :  0.7717849
# Val Acc :  64.9840235710144
# Val Loss :  0.72602844
#  --------------------------------------------------------->  EPOCH 95 Checkpoint Saved w/ Acc: 64.37%
# ---------------------------------------------
#
#
#  Epoch: 104/3000 	LR: [0.0001] 	Dur: 3.42 sec
#
#  Training - Confusion Matrix:
# [[8555 3839]
#  [4999 7643]]
#
#  Validation - Confusion Matrix:
# [[ 892  691]
#  [ 389 1158]]
#
# Train Acc :  64.70945732934135
# Train Loss :  0.71079856
# Val Acc :  65.49520492553711
# Val Loss :  0.6792273
#  --------------------------------------------------------->  EPOCH 95 Checkpoint Saved w/ Acc: 65.10%
# ---------------------------------------------
#
#
#  Epoch: 105/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[7182 5212]
#  [3577 9065]]
#
#  Validation - Confusion Matrix:
# [[1073  510]
#  [ 517 1030]]
#
# Train Acc :  64.43926436560494
# Train Loss :  0.69428694
# Val Acc :  67.18849539756775
# Val Loss :  0.7239156
#  --------------------------------------------------------->  EPOCH 95 Checkpoint Saved w/ Acc: 65.81%
# ---------------------------------------------
#
#
#  Epoch: 106/3000 	LR: [0.0001] 	Dur: 3.19 sec
#
#  Training - Confusion Matrix:
# [[8530 3864]
#  [4670 7972]]
#
#  Validation - Confusion Matrix:
# [[ 995  588]
#  [ 457 1090]]
#
# Train Acc :  65.68702033587864
# Train Loss :  0.66435814
# Val Acc :  66.61341786384583
# Val Loss :  0.67729926
#  --------------------------------------------------------->  EPOCH 95 Checkpoint Saved w/ Acc: 66.15%
# ---------------------------------------------
#
#
#  Epoch: 107/3000 	LR: [0.0001] 	Dur: 3.45 sec
#
#  Training - Confusion Matrix:
# [[7797 4597]
#  [4003 8639]]
#
#  Validation - Confusion Matrix:
# [[1014  569]
#  [ 467 1080]]
#
# Train Acc :  65.84278515407017
# Train Loss :  0.6507467
# Val Acc :  66.90095663070679
# Val Loss :  0.6528885
#  --------------------------------------------------------->  EPOCH 95 Checkpoint Saved w/ Acc: 66.37%
# ---------------------------------------------
#
#
#  Epoch: 108/3000 	LR: [0.0001] 	Dur: 3.28 sec
#
#  Training - Confusion Matrix:
# [[8267 4127]
#  [4326 8316]]
#
#  Validation - Confusion Matrix:
# [[1063  520]
#  [ 508 1039]]
#
# Train Acc :  66.24520761626107
# Train Loss :  0.6435043
# Val Acc :  67.15654730796814
# Val Loss :  0.64383703
#  --------------------------------------------------------->  EPOCH 95 Checkpoint Saved w/ Acc: 66.70%
# ---------------------------------------------
#
#
#  Epoch: 109/3000 	LR: [0.0001] 	Dur: 3.41 sec
#
#  Training - Confusion Matrix:
# [[8138 4256]
#  [4050 8592]]
#
#  Validation - Confusion Matrix:
# [[1009  574]
#  [ 444 1103]]
#
# Train Acc :  66.67519892965045
# Train Loss :  0.63409984
# Val Acc :  67.47603416442871
# Val Loss :  0.6540332
#  --------------------------------------------------------->  EPOCH 95 Checkpoint Saved w/ Acc: 67.08%
# ---------------------------------------------
#
#
#  Epoch: 110/3000 	LR: [0.0001] 	Dur: 3.32 sec
#
#  Training - Confusion Matrix:
# [[8400 3994]
#  [4271 8371]]
#
#  Validation - Confusion Matrix:
# [[1032  551]
#  [ 489 1058]]
#
# Train Acc :  66.68035387992859
# Train Loss :  0.6270786
# Val Acc :  66.77316427230835
# Val Loss :  0.64868927
# ---------------------------------------------
#
#
#  Epoch: 111/3000 	LR: [0.0001] 	Dur: 3.17 sec
#
#  Training - Confusion Matrix:
# [[8430 3964]
#  [4197 8445]]
#
#  Validation - Confusion Matrix:
# [[ 999  584]
#  [ 454 1093]]
#
# Train Acc :  67.34632764543805
# Train Loss :  0.6219765
# Val Acc :  66.83706045150757
# Val Loss :  0.63851726
#  --------------------------------------------------------->  EPOCH 108 Checkpoint Saved w/ Acc: 67.09%
# ---------------------------------------------
#
#
#  Epoch: 112/3000 	LR: [0.0001] 	Dur: 3.52 sec
#
#  Training - Confusion Matrix:
# [[8383 4011]
#  [4057 8585]]
#
#  Validation - Confusion Matrix:
# [[1071  512]
#  [ 496 1051]]
#
# Train Acc :  67.64311790466309
# Train Loss :  0.6122466
# Val Acc :  67.79552698135376
# Val Loss :  0.6256797
#  --------------------------------------------------------->  EPOCH 108 Checkpoint Saved w/ Acc: 67.72%
# ---------------------------------------------
#
#
#  Epoch: 113/3000 	LR: [0.0001] 	Dur: 3.42 sec
#
#  Training - Confusion Matrix:
# [[8625 3769]
#  [4328 8314]]
#
#  Validation - Confusion Matrix:
# [[1017  566]
#  [ 455 1092]]
#
# Train Acc :  67.29386023112706
# Train Loss :  0.61185014
# Val Acc :  67.38018989562988
# Val Loss :  0.6467296
# ---------------------------------------------
#
#
#  Epoch: 114/3000 	LR: [0.0001] 	Dur: 3.29 sec
#
#  Training - Confusion Matrix:
# [[8422 3972]
#  [3893 8749]]
#
#  Validation - Confusion Matrix:
# [[1104  479]
#  [ 508 1039]]
#
# Train Acc :  68.54410256658282
# Train Loss :  0.6048065
# Val Acc :  68.46645474433899
# Val Loss :  0.61643094
#  --------------------------------------------------------->  EPOCH 108 Checkpoint Saved w/ Acc: 68.51%
# ---------------------------------------------
#
#
#  Epoch: 115/3000 	LR: [0.0001] 	Dur: 3.36 sec
#
#  Training - Confusion Matrix:
# [[8831 3563]
#  [4340 8302]]
#
#  Validation - Confusion Matrix:
# [[1036  547]
#  [ 444 1103]]
#
# Train Acc :  68.68725078446525
# Train Loss :  0.60194236
# Val Acc :  68.33865642547607
# Val Loss :  0.61566526
#  --------------------------------------------------------->  EPOCH 108 Checkpoint Saved w/ Acc: 68.51%
# ---------------------------------------------
#
#
#  Epoch: 116/3000 	LR: [0.0001] 	Dur: 3.30 sec
#
#  Training - Confusion Matrix:
# [[8570 3824]
#  [3980 8662]]
#
#  Validation - Confusion Matrix:
# [[1096  487]
#  [ 485 1062]]
#
# Train Acc :  68.75685368265424
# Train Loss :  0.6013756
# Val Acc :  68.94568800926208
# Val Loss :  0.6140245
#  --------------------------------------------------------->  EPOCH 108 Checkpoint Saved w/ Acc: 68.85%
# ---------------------------------------------
#
#
#  Epoch: 117/3000 	LR: [0.0001] 	Dur: 3.33 sec
#
#  Training - Confusion Matrix:
# [[8741 3653]
#  [4116 8526]]
#
#  Validation - Confusion Matrix:
# [[1054  529]
#  [ 455 1092]]
#
# Train Acc :  68.60324229512896
# Train Loss :  0.60113543
# Val Acc :  68.56229901313782
# Val Loss :  0.63297284
# ---------------------------------------------
#
#
#  Epoch: 118/3000 	LR: [0.0001] 	Dur: 3.27 sec
#
#  Training - Confusion Matrix:
# [[8665 3729]
#  [3968 8674]]
#
#  Validation - Confusion Matrix:
# [[1043  540]
#  [ 446 1101]]
#
# Train Acc :  69.15760806628636
# Train Loss :  0.5937333
# Val Acc :  68.4984028339386
# Val Loss :  0.606396
# ---------------------------------------------
#
#
#  Epoch: 119/3000 	LR: [0.0001] 	Dur: 3.42 sec
#
#  Training - Confusion Matrix:
# [[8719 3675]
#  [4002 8640]]
#
#  Validation - Confusion Matrix:
# [[1123  460]
#  [ 505 1042]]
#
# Train Acc :  69.08952168055943
# Train Loss :  0.59121805
# Val Acc :  69.16933059692383
# Val Loss :  0.6142582
#  --------------------------------------------------------->  EPOCH 108 Checkpoint Saved w/ Acc: 69.13%
# ---------------------------------------------
#
#
#  Epoch: 120/3000 	LR: [0.0001] 	Dur: 3.16 sec
#
#  Training - Confusion Matrix:
# [[8836 3558]
#  [4104 8538]]
#
#  Validation - Confusion Matrix:
# [[1018  565]
#  [ 420 1127]]
#
# Train Acc :  69.25211037908282
# Train Loss :  0.5885478
# Val Acc :  68.53035092353821
# Val Loss :  0.5983247
# ---------------------------------------------
#
#
#  Epoch: 121/3000 	LR: [0.0001] 	Dur: 3.40 sec
#
#  Training - Confusion Matrix:
# [[8592 3802]
#  [3828 8814]]
#
#  Validation - Confusion Matrix:
# [[1146  437]
#  [ 512 1035]]
#
# Train Acc :  69.52912637165615
# Train Loss :  0.58734626
# Val Acc :  69.68051195144653
# Val Loss :  0.5963532
#  --------------------------------------------------------->  EPOCH 118 Checkpoint Saved w/ Acc: 69.60%
# ---------------------------------------------
#
#
#  Epoch: 122/3000 	LR: [0.0001] 	Dur: 3.48 sec
#
#  Training - Confusion Matrix:
# [[9040 3354]
#  [4233 8409]]
#
#  Validation - Confusion Matrix:
# [[1077  506]
#  [ 451 1096]]
#
# Train Acc :  69.67909846987042
# Train Loss :  0.58532566
# Val Acc :  69.42492127418518
# Val Loss :  0.5898017
# ---------------------------------------------
#
#
#  Epoch: 123/3000 	LR: [0.0001] 	Dur: 3.40 sec
#
#  Training - Confusion Matrix:
# [[8653 3741]
#  [3824 8818]]
#
#  Validation - Confusion Matrix:
# [[1035  548]
#  [ 430 1117]]
#
# Train Acc :  69.61798753057208
# Train Loss :  0.5875462
# Val Acc :  68.75399351119995
# Val Loss :  0.6104687
# ---------------------------------------------
#
#
#  Epoch: 124/3000 	LR: [0.0001] 	Dur: 3.21 sec
#
#  Training - Confusion Matrix:
# [[8916 3478]
#  [3976 8666]]
#
#  Validation - Confusion Matrix:
# [[1034  549]
#  [ 415 1132]]
#
# Train Acc :  70.25323850767953
# Train Loss :  0.5824913
# Val Acc :  69.20127868652344
# Val Loss :  0.583537
#  --------------------------------------------------------->  EPOCH 118 Checkpoint Saved w/ Acc: 69.73%
# ---------------------------------------------
#
#
#  Epoch: 125/3000 	LR: [0.0001] 	Dur: 3.14 sec
#
#  Training - Confusion Matrix:
# [[8821 3573]
#  [3935 8707]]
#
#  Validation - Confusion Matrix:
# [[1105  478]
#  [ 451 1096]]
#
# Train Acc :  70.25787915502276
# Train Loss :  0.5824484
# Val Acc :  70.31948566436768
# Val Loss :  0.5904591
#  --------------------------------------------------------->  EPOCH 118 Checkpoint Saved w/ Acc: 70.29%
# ---------------------------------------------
#
#
#  Epoch: 126/3000 	LR: [0.0001] 	Dur: 3.50 sec
#
#  Training - Confusion Matrix:
# [[8945 3449]
#  [4072 8570]]
#
#  Validation - Confusion Matrix:
# [[1040  543]
#  [ 410 1137]]
#
# Train Acc :  70.04712905202594
# Train Loss :  0.5815092
# Val Acc :  69.55271363258362
# Val Loss :  0.59028476
# ---------------------------------------------
#
#
#  Epoch: 127/3000 	LR: [0.0001] 	Dur: 3.39 sec
#
#  Training - Confusion Matrix:
# [[8854 3540]
#  [3843 8799]]
#
#  Validation - Confusion Matrix:
# [[1097  486]
#  [ 453 1094]]
#
# Train Acc :  70.41816200528827
# Train Loss :  0.5783083
# Val Acc :  69.9999988079071
# Val Loss :  0.5917462
# ---------------------------------------------
#
#
#  Epoch: 128/3000 	LR: [0.0001] 	Dur: 3.42 sec
#
#  Training - Confusion Matrix:
# [[8904 3490]
#  [3937 8705]]
#
#  Validation - Confusion Matrix:
# [[1042  541]
#  [ 398 1149]]
#
# Train Acc :  69.98902048383441
# Train Loss :  0.5808454
# Val Acc :  69.9999988079071
# Val Loss :  0.6126338
# ---------------------------------------------
#
#
#  Epoch: 129/3000 	LR: [0.0001] 	Dur: 3.39 sec
#
#  Training - Confusion Matrix:
# [[8788 3606]
#  [3813 8829]]
#
#  Validation - Confusion Matrix:
# [[1111  472]
#  [ 442 1105]]
#
# Train Acc :  70.1823319707598
# Train Loss :  0.5804596
# Val Acc :  70.79871892929077
# Val Loss :  0.60063684
#  --------------------------------------------------------->  EPOCH 118 Checkpoint Saved w/ Acc: 70.49%
# ---------------------------------------------
#
#
#  Epoch: 130/3000 	LR: [0.0001] 	Dur: 3.25 sec
#
#  Training - Confusion Matrix:
# [[8995 3399]
#  [3961 8681]]
#
#  Validation - Confusion Matrix:
# [[1075  508]
#  [ 417 1130]]
#
# Train Acc :  70.66378934042794
# Train Loss :  0.57207185
# Val Acc :  70.44728398323059
# Val Loss :  0.564667
#  --------------------------------------------------------->  EPOCH 118 Checkpoint Saved w/ Acc: 70.56%
# ---------------------------------------------
#
#
# ...
# [[9181 3213]
#  [3405 9237]]
#
#  Validation - Confusion Matrix:
# [[1064  519]
#  [ 327 1220]]
#
# Train Acc :  73.69277051516941
# Train Loss :  0.530006
# Val Acc :  72.9712426662445
# Val Loss :  0.51946735
# ---------------------------------------------
#
#
#  Epoch: 178/3000 	LR: [0.0001] 	Dur: 3.34 sec
#
#  Training - Confusion Matrix:
# [[9346 3048]
#  [3480 9162]]
#
#  Validation - Confusion Matrix:
# [[1054  529]
#  [ 305 1242]]
#
# Train Acc :  73.84125675473895
# Train Loss :  0.52972
# Val Acc :  73.35463166236877
# Val Loss :  0.5289924
# ---------------------------------------------
#
#
#  Epoch: 179/3000 	LR: [0.0001] 	Dur: 3.19 sec
#
#  Training - Confusion Matrix:
# [[9324 3070]
#  [3377 9265]]
#
#  Validation - Confusion Matrix:
# [[1121  462]
#  [ 349 1198]]
#
# Train Acc :  74.34430718421936
# Train Loss :  0.52662903
# Val Acc :  74.08945560455322
# Val Loss :  0.5199388
#  --------------------------------------------------------->  EPOCH 167 Checkpoint Saved w/ Acc: 74.22%
# ---------------------------------------------
#
#
#  Epoch: 180/3000 	LR: [0.0001] 	Dur: 3.19 sec
#
#  Training - Confusion Matrix:
# [[9336 3058]
#  [3451 9191]]
#
#  Validation - Confusion Matrix:
# [[1039  544]
#  [ 300 1247]]
#
# Train Acc :  73.93509149551392
# Train Loss :  0.5271387
# Val Acc :  73.0351448059082
# Val Loss :  0.5346274
# ---------------------------------------------
#
#
#  Epoch: 181/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[9241 3153]
#  [3342 9300]]
#
#  Validation - Confusion Matrix:
# [[1096  487]
#  [ 333 1214]]
#
# Train Acc :  74.1493284702301
# Train Loss :  0.5270893
# Val Acc :  73.80191683769226
# Val Loss :  0.52583903
# ---------------------------------------------
#
#
#  Epoch: 182/3000 	LR: [0.0001] 	Dur: 3.34 sec
#
#  Training - Confusion Matrix:
# [[9373 3021]
#  [3476 9166]]
#
#  Validation - Confusion Matrix:
# [[1065  518]
#  [ 313 1234]]
#
# Train Acc :  73.86667132377625
# Train Loss :  0.5272426
# Val Acc :  73.4504759311676
# Val Loss :  0.5369252
# ---------------------------------------------
#
#
#  Epoch: 183/3000 	LR: [0.0001] 	Dur: 3.34 sec
#
#  Training - Confusion Matrix:
# [[9363 3031]
#  [3466 9176]]
#
#  Validation - Confusion Matrix:
# [[1126  457]
#  [ 359 1188]]
#
# Train Acc :  74.0596490246909
# Train Loss :  0.52361494
# Val Acc :  73.9297091960907
# Val Loss :  0.52243555
# ---------------------------------------------
#
#
#  Epoch: 184/3000 	LR: [0.0001] 	Dur: 3.23 sec
#
#  Training - Confusion Matrix:
# [[9257 3137]
#  [3330 9312]]
#
#  Validation - Confusion Matrix:
# [[1116  467]
#  [ 337 1210]]
#
# Train Acc :  74.43996242114476
# Train Loss :  0.52476186
# Val Acc :  74.31309819221497
# Val Loss :  0.51773643
#  --------------------------------------------------------->  EPOCH 178 Checkpoint Saved w/ Acc: 74.38%
# ---------------------------------------------
#
#
#  Epoch: 185/3000 	LR: [0.0001] 	Dur: 3.36 sec
#
#  Training - Confusion Matrix:
# [[9512 2882]
#  [3597 9045]]
#
#  Validation - Confusion Matrix:
# [[1034  549]
#  [ 270 1277]]
#
# Train Acc :  74.26026889256069
# Train Loss :  0.5216713
# Val Acc :  73.83386492729187
# Val Loss :  0.51017964
# ---------------------------------------------
#
#
#  Epoch: 186/3000 	LR: [0.0001] 	Dur: 3.33 sec
#
#  Training - Confusion Matrix:
# [[9246 3148]
#  [3294 9348]]
#
#  Validation - Confusion Matrix:
# [[1129  454]
#  [ 340 1207]]
#
# Train Acc :  74.60985950061253
# Train Loss :  0.5218292
# Val Acc :  74.63258504867554
# Val Loss :  0.5065145
#  --------------------------------------------------------->  EPOCH 178 Checkpoint Saved w/ Acc: 74.62%
# ---------------------------------------------
#
#
#  Epoch: 187/3000 	LR: [0.0001] 	Dur: 3.35 sec
#
#  Training - Confusion Matrix:
# [[9381 3013]
#  [3396 9246]]
#
#  Validation - Confusion Matrix:
# [[1068  515]
#  [ 309 1238]]
#
# Train Acc :  74.55954551696777
# Train Loss :  0.52407366
# Val Acc :  73.67411851882935
# Val Loss :  0.52738893
# ---------------------------------------------
#
#
#  Epoch: 188/3000 	LR: [0.0001] 	Dur: 3.25 sec
#
#  Training - Confusion Matrix:
# [[9449 2945]
#  [3480 9162]]
#
#  Validation - Confusion Matrix:
# [[1089  494]
#  [ 331 1216]]
#
# Train Acc :  74.64158279555184
# Train Loss :  0.5198795
# Val Acc :  73.64217042922974
# Val Loss :  0.5145328
# ---------------------------------------------
#
#
#  Epoch: 189/3000 	LR: [0.0001] 	Dur: 3.39 sec
#
#  Training - Confusion Matrix:
# [[9312 3082]
#  [3295 9347]]
#
#  Validation - Confusion Matrix:
# [[1081  502]
#  [ 314 1233]]
#
# Train Acc :  74.34033496039254
# Train Loss :  0.51832724
# Val Acc :  73.9297091960907
# Val Loss :  0.5121044
# ---------------------------------------------
#
#
#  Epoch: 190/3000 	LR: [0.0001] 	Dur: 3.14 sec
#
#  Training - Confusion Matrix:
# [[9488 2906]
#  [3455 9187]]
#
#  Validation - Confusion Matrix:
# [[1083  500]
#  [ 325 1222]]
#
# Train Acc :  74.6718202318464
# Train Loss :  0.5170623
# Val Acc :  73.64217042922974
# Val Loss :  0.49781767
# ---------------------------------------------
#
#
#  Epoch: 191/3000 	LR: [0.0001] 	Dur: 3.45 sec
#
#  Training - Confusion Matrix:
# [[9336 3058]
#  [3360 9282]]
#
#  Validation - Confusion Matrix:
# [[1100  483]
#  [ 314 1233]]
#
# Train Acc :  74.307610307421
# Train Loss :  0.5213289
# Val Acc :  74.53674077987671
# Val Loss :  0.51606196
# ---------------------------------------------
#
#
#  Epoch: 192/3000 	LR: [0.0001] 	Dur: 3.49 sec
#
#  Training - Confusion Matrix:
# [[9437 2957]
#  [3429 9213]]
#
#  Validation - Confusion Matrix:
# [[1056  527]
#  [ 277 1270]]
#
# Train Acc :  74.91544485092163
# Train Loss :  0.5174195
# Val Acc :  74.31309819221497
# Val Loss :  0.50203025
# ---------------------------------------------
#
#
#  Epoch: 193/3000 	LR: [0.0001] 	Dur: 3.46 sec
#
#  Training - Confusion Matrix:
# [[9294 3100]
#  [3282 9360]]
#
#  Validation - Confusion Matrix:
# [[1077  506]
#  [ 294 1253]]
#
# Train Acc :  74.79155489376613
# Train Loss :  0.5192813
# Val Acc :  74.4408905506134
# Val Loss :  0.51347935
# ---------------------------------------------
#
#
#  Epoch: 194/3000 	LR: [0.0001] 	Dur: 3.20 sec
#
#  Training - Confusion Matrix:
# [[9346 3048]
#  [3301 9341]]
#
#  Validation - Confusion Matrix:
# [[1075  508]
#  [ 317 1230]]
#
# Train Acc :  75.18233145986285
# Train Loss :  0.5156056
# Val Acc :  73.64217042922974
# Val Loss :  0.49398977
# ---------------------------------------------
#
#
#  Epoch: 195/3000 	LR: [0.0001] 	Dur: 3.40 sec
#
#  Training - Confusion Matrix:
# [[9380 3014]
#  [3375 9267]]
#
#  Validation - Confusion Matrix:
# [[1079  504]
#  [ 289 1258]]
#
# Train Acc :  74.87741368157523
# Train Loss :  0.5160213
# Val Acc :  74.66453313827515
# Val Loss :  0.5027177
#  --------------------------------------------------------->  EPOCH 185 Checkpoint Saved w/ Acc: 74.77%
# ---------------------------------------------
#
#
#  Epoch: 196/3000 	LR: [0.0001] 	Dur: 3.42 sec
#
#  Training - Confusion Matrix:
# [[9271 3123]
#  [3314 9328]]
#
#  Validation - Confusion Matrix:
# [[1067  516]
#  [ 296 1251]]
#
# Train Acc :  74.40675326756069
# Train Loss :  0.5174383
# Val Acc :  74.05750751495361
# Val Loss :  0.51058346
# ---------------------------------------------
#
#
#  Epoch: 197/3000 	LR: [0.0001] 	Dur: 3.18 sec
#
#  Training - Confusion Matrix:
# [[9364 3030]
#  [3295 9347]]
#
#  Validation - Confusion Matrix:
# [[1064  519]
#  [ 300 1247]]
#
# Train Acc :  74.93521911757333
# Train Loss :  0.512742
# Val Acc :  73.83386492729187
# Val Loss :  0.49991468
# ---------------------------------------------
#
#
#  Epoch: 198/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[9407 2987]
#  [3307 9335]]
#
#  Validation - Confusion Matrix:
# [[1110  473]
#  [ 316 1231]]
#
# Train Acc :  75.09847453662327
# Train Loss :  0.51490766
# Val Acc :  74.79233145713806
# Val Loss :  0.5064239
#  --------------------------------------------------------->  EPOCH 185 Checkpoint Saved w/ Acc: 74.95%
# ---------------------------------------------
#
#
#  Epoch: 199/3000 	LR: [0.0001] 	Dur: 3.26 sec
#
#  Training - Confusion Matrix:
# [[9480 2914]
#  [3315 9327]]
#
#  Validation - Confusion Matrix:
# [[1078  505]
#  [ 299 1248]]
#
# Train Acc :  75.10463084493365
# Train Loss :  0.51081383
# Val Acc :  74.31309819221497
# Val Loss :  0.5094833
# ---------------------------------------------
#
#
#  Epoch: 200/3000 	LR: [0.0001] 	Dur: 3.26 sec
#
#  Training - Confusion Matrix:
# [[9468 2926]
#  [3361 9281]]
#
#  Validation - Confusion Matrix:
# [[1100  483]
#  [ 302 1245]]
#
# Train Acc :  75.04018374851772
# Train Loss :  0.5096146
# Val Acc :  74.9201238155365
# Val Loss :  0.5018195
#  --------------------------------------------------------->  EPOCH 185 Checkpoint Saved w/ Acc: 74.98%
# ---------------------------------------------
#
#
#  Epoch: 201/3000 	LR: [0.0001] 	Dur: 3.43 sec
#
#  Training - Confusion Matrix:
# [[9486 2908]
#  [3358 9284]]
#
#  Validation - Confusion Matrix:
# [[1028  555]
#  [ 257 1290]]
#
# Train Acc :  75.25126678603036
# Train Loss :  0.5121027
# Val Acc :  74.05750751495361
# Val Loss :  0.4954721
# ---------------------------------------------
#
#
#  Epoch: 202/3000 	LR: [0.0001] 	Dur: 3.39 sec
#
#  Training - Confusion Matrix:
# [[9348 3046]
#  [3227 9415]]
#
#  Validation - Confusion Matrix:
# [[1108  475]
#  [ 303 1244]]
#
# Train Acc :  75.19928472382682
# Train Loss :  0.5107301
# Val Acc :  75.14376640319824
# Val Loss :  0.49660042
#  --------------------------------------------------------->  EPOCH 199 Checkpoint Saved w/ Acc: 75.17%
# ---------------------------------------------
#
#
#  Epoch: 203/3000 	LR: [0.0001] 	Dur: 3.38 sec
#
#  Training - Confusion Matrix:
# [[9340 3054]
#  [3223 9419]]
#
#  Validation - Confusion Matrix:
# [[1117  466]
#  [ 333 1214]]
#
# Train Acc :  75.24047068187168
# Train Loss :  0.5103555
# Val Acc :  74.47284460067749
# Val Loss :  0.49764147
# ---------------------------------------------
#
#
#  Epoch: 204/3000 	LR: [0.0001] 	Dur: 3.16 sec
#
#  Training - Confusion Matrix:
# [[9587 2807]
#  [3402 9240]]
#
#  Validation - Confusion Matrix:
# [[1045  538]
#  [ 260 1287]]
#
# Train Acc :  75.36736301013401
# Train Loss :  0.5096075
# Val Acc :  74.5047926902771
# Val Loss :  0.5072504
# ---------------------------------------------
#
#
#  Epoch: 205/3000 	LR: [0.0001] 	Dur: 3.27 sec
#
#  Training - Confusion Matrix:
# [[9397 2997]
#  [3205 9437]]
#
#  Validation - Confusion Matrix:
# [[1105  478]
#  [ 293 1254]]
#
# Train Acc :  75.52961792264666
# Train Loss :  0.5099251
# Val Acc :  75.36740899085999
# Val Loss :  0.50762373
#  --------------------------------------------------------->  EPOCH 199 Checkpoint Saved w/ Acc: 75.45%
# ---------------------------------------------
#
#
#  Epoch: 206/3000 	LR: [0.0001] 	Dur: 3.27 sec
#
#  Training - Confusion Matrix:
# [[9410 2984]
#  [3224 9418]]
#
#  Validation - Confusion Matrix:
# [[1098  485]
#  [ 288 1259]]
#
# Train Acc :  75.53625958306449
# Train Loss :  0.5062074
# Val Acc :  75.30351281166077
# Val Loss :  0.4944914
# ---------------------------------------------
#
#
#  Epoch: 207/3000 	LR: [0.0001] 	Dur: 3.19 sec
#
#  Training - Confusion Matrix:
# [[9439 2955]
#  [3287 9355]]
#
#  Validation - Confusion Matrix:
# [[1102  481]
#  [ 292 1255]]
#
# Train Acc :  75.44524499348232
# Train Loss :  0.5091948
# Val Acc :  75.30351281166077
# Val Loss :  0.5001983
# ---------------------------------------------
#
#
#  Epoch: 208/3000 	LR: [0.0001] 	Dur: 3.43 sec
#
#  Training - Confusion Matrix:
# [[9451 2943]
#  [3310 9332]]
#
#  Validation - Confusion Matrix:
# [[1090  493]
#  [ 285 1262]]
#
# Train Acc :  75.241471188409
# Train Loss :  0.50465447
# Val Acc :  75.14376640319824
# Val Loss :  0.49130732
# ---------------------------------------------
#
#
#  Epoch: 209/3000 	LR: [0.0001] 	Dur: 3.37 sec
#
#  Training - Confusion Matrix:
# [[9329 3065]
#  [3172 9470]]
#
#  Validation - Confusion Matrix:
# [[1112  471]
#  [ 304 1243]]
#
# Train Acc :  75.37997961044312
# Train Loss :  0.5070888
# Val Acc :  75.23961663246155
# Val Loss :  0.49426097
# ---------------------------------------------
#
#
#  Epoch: 210/3000 	LR: [0.0001] 	Dur: 3.22 sec
#
#  Training - Confusion Matrix:
# [[9457 2937]
#  [3221 9421]]
#
#  Validation - Confusion Matrix:
# [[1095  488]
#  [ 301 1246]]
#
# Train Acc :  75.51766889435905
# Train Loss :  0.50405276
# Val Acc :  74.79233145713806
# Val Loss :  0.48363495
# ---------------------------------------------
#
#
#  Epoch: 211/3000 	LR: [0.0001] 	Dur: 3.25 sec
#
#  Training - Confusion Matrix:
# [[9415 2979]
#  [3283 9359]]
#
#  Validation - Confusion Matrix:
# [[1126  457]
#  [ 321 1226]]
#
# Train Acc :  75.3754905291966
# Train Loss :  0.5015818
# Val Acc :  75.14376640319824
# Val Loss :  0.4652171
# ---------------------------------------------
#
#
#  Epoch: 212/3000 	LR: [0.0001] 	Dur: 3.36 sec
#
#  Training - Confusion Matrix:
# [[9456 2938]
#  [3222 9420]]
#
#  Validation - Confusion Matrix:
# [[1108  475]
#  [ 297 1250]]
#
# Train Acc :  75.64853429794312
# Train Loss :  0.5009349
# Val Acc :  75.33546090126038
# Val Loss :  0.46596196
#  --------------------------------------------------------->  EPOCH 204 Checkpoint Saved w/ Acc: 75.49%
# ---------------------------------------------
#
#
#  Epoch: 213/3000 	LR: [0.0001] 	Dur: 3.42 sec
#
#  Training - Confusion Matrix:
# [[9406 2988]
#  [3183 9459]]
#
#  Validation - Confusion Matrix:
# [[1134  449]
#  [ 314 1233]]
#
# Train Acc :  75.58260049138751
# Train Loss :  0.50343525
# Val Acc :  75.62299966812134
# Val Loss :  0.48629043
#  --------------------------------------------------------->  EPOCH 204 Checkpoint Saved w/ Acc: 75.60%
# ---------------------------------------------
#
#
#  Epoch: 214/3000 	LR: [0.0001] 	Dur: 3.31 sec
#
#  Training - Confusion Matrix:
# [[9428 2966]
#  [3236 9406]]
#
#  Validation - Confusion Matrix:
# [[1136  447]
#  [ 321 1226]]
#
# Train Acc :  75.58475392205375
# Train Loss :  0.49787092
# Val Acc :  75.46325922012329
# Val Loss :  0.46006164
# ---------------------------------------------
#
#
#  Epoch: 215/3000 	LR: [0.0001] 	Dur: 3.38 sec
#
#  Training - Confusion Matrix:
# [[9453 2941]
#  [3211 9431]]
#
#  Validation - Confusion Matrix:
# [[1116  467]
#  [ 301 1246]]
#
# Train Acc :  75.92454978397915
# Train Loss :  0.49702317
# Val Acc :  75.46325922012329
# Val Loss :  0.46112907
#  --------------------------------------------------------->  EPOCH 204 Checkpoint Saved w/ Acc: 75.69%
# ---------------------------------------------
#
#
#  Epoch: 216/3000 	LR: [0.0001] 	Dur: 3.24 sec
#
#  Training - Confusion Matrix:
# [[9567 2827]
#  [3287 9355]]
#
#  Validation - Confusion Matrix:
# [[1081  502]
#  [ 282 1265]]
#
# Train Acc :  76.02951441492353
# Train Loss :  0.5022701
# Val Acc :  74.95207786560059
# Val Loss :  0.48120475
# ---------------------------------------------
#
#
#  Epoch: 217/3000 	LR: [0.0001] 	Dur: 3.46 sec
#
#  Training - Confusion Matrix:
# [[9322 3072]
#  [3137 9505]]
#
#  Validation - Confusion Matrix:
# [[1125  458]
#  [ 309 1238]]
#
# Train Acc :  75.4224990095411
# Train Loss :  0.50159967
# Val Acc :  75.4952073097229
# Val Loss :  0.48248234
# ---------------------------------------------
#
#
#  Epoch: 218/3000 	LR: [0.0001] 	Dur: 3.27 sec
#
#  Training - Confusion Matrix:
# [[9562 2832]
#  [3183 9459]]
#
#  Validation - Confusion Matrix:
# [[1107  476]
#  [ 293 1254]]
#
# Train Acc :  76.12668531281608
# Train Loss :  0.49959326
# Val Acc :  75.43131113052368
# Val Loss :  0.48977038
#  --------------------------------------------------------->  EPOCH 204 Checkpoint Saved w/ Acc: 75.78%
# ---------------------------------------------
#
#
#  Epoch: 219/3000 	LR: [0.0001] 	Dur: 3.15 sec
#
#  Training - Confusion Matrix:
# [[9418 2976]
#  [3230 9412]]
#
#  Validation - Confusion Matrix:
# [[1126  457]
#  [ 316 1231]]
#
# Train Acc :  75.48809903008598
# Train Loss :  0.49858826
# Val Acc :  75.30351281166077
# Val Loss :  0.45897272
# ---------------------------------------------
#
#
#  Epoch: 220/3000 	LR: [0.0001] 	Dur: 3.45 sec
#
#  Training - Confusion Matrix:
# [[9426 2968]
#  [3200 9442]]
#
#  Validation - Confusion Matrix:
# [[1114  469]
#  [ 287 1260]]
#
# Train Acc :  75.51035966191974
# Train Loss :  0.5015883
# Val Acc :  75.84664225578308
# Val Loss :  0.48121235
# ---------------------------------------------
#
#
#  Epoch: 221/3000 	LR: [0.0001] 	Dur: 3.33 sec
#
#  Training - Confusion Matrix:
# [[9551 2843]
#  [3292 9350]]
#
#  Validation - Confusion Matrix:
# [[1095  488]
#  [ 283 1264]]
#
# Train Acc :  75.90113622801644
# Train Loss :  0.49929354
# Val Acc :  75.36740899085999
# Val Loss :  0.47673056
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 96
#      93     loss.backward()
#      94     optimizer.step()
# ---> 96     running_loss.append(loss.cpu().detach().numpy())
#      98 total_acc = np.mean(acc_b)*100
#      99 mean_loss = np.mean(running_loss)
#
# KeyboardInterrupt:
