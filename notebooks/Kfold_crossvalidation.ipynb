# %% [markdown]
# # Transfer Learning
#
# ## Load Libraries

# %%
import importlib
import sys
import os
import numpy as np
import time
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

import torch
from torch import nn
import torch.optim as optim

from torch.utils import data
from torchvision import transforms

sys.path.append(os.path.join(os.getcwd(), ".."))

from distiller import apputils
import ai8x

from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

kws20 = importlib.import_module("datasets.kws20-horsecough")

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_recall_fscore_support, roc_auc_score, roc_curve

def plot_confusion(y_true, y_pred, classes):
    cf_matrix = confusion_matrix(y_true = y_true, y_pred = y_pred, labels =list(range(len(classes))))
    print(cf_matrix)

def plot_roc_curve(true_y, y_prob):
    fpr, tpr, thresholds = roc_curve(true_y, y_prob)
    plt.plot(fpr, tpr)
    plt.plot([0,1], [0,1], 'r--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

# %% [markdown]
# ## Prepare Checkpoint, Plot, and Dataset Folders

# %%
# MODEL AND DATASET NAME 
model_name = 'human_others'
classes = ["combined",'human_cough']
checkpoint_dir = './checkpoints/'+model_name+'/'

indexer = 0
while os.path.exists(checkpoint_dir):
    model_name = 'human_others'
    model_name = model_name + '_' + str(indexer)
    checkpoint_dir = './checkpoints/'+model_name+'/'
    indexer += 1

if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

print('Model Name: ', model_name)
print('Classes: ', classes)
print('Checkpoint Dir: ', checkpoint_dir)
# Out:
# Model Name:  human_others_4
# Classes:  ['combined', 'human_cough']
# Checkpoint Dir:  ./checkpoints/human_others_4/

# %% [markdown]
# ## Calculate weights

# %%
raw_data_path = Path("../data/KWS_EQUINE/raw/")
class_file_count = {}

class_dirs = [d for d in raw_data_path.iterdir() if d.is_dir() and (d.stem != "__combinedkws") and (d.stem != "__combined_others") and (d.stem != "__human_cough")]

for d in class_dirs:
    print(d)
    class_file_count[d] = len(list(d.iterdir()))

min_file_count = float(min(class_file_count.values()))

# Calculate weights
class_weights = []
for d in class_dirs:
    class_file_count[d] = min_file_count / class_file_count[d]
    print(f"{d.stem}: {round(class_file_count[d], 7)}")
    class_weights.append(round(class_file_count[d], 7))
class_weights = [0.5, 1]
print('Weights: ',class_weights)
# Out:
# ..\data\KWS_EQUINE\raw\combined
# ..\data\KWS_EQUINE\raw\human_cough
# combined: 0.7269915
# human_cough: 1.0
# Weights:  [0.5, 1]

# %% [markdown]
# ## Generate Processed Dataset

# %%
train_batch_size = 4096
if torch.cuda.is_available():
    device = torch.device('cuda:0')
    cpu = False
else:
     device = torch.device('cpu')
     cpu = True

print('Running on device: {}'.format(torch.cuda.get_device_name()))

processed_data_path = Path("../data/KWS_EQUINE/processed/")
if len(os.listdir(processed_data_path)) == 0:
    train_loader, val_loader, test_loader, _ = apputils.get_data_loaders(kws20.KWS_HORSE_TF_get_datasets, ("../data", True), train_batch_size, 4, validation_split=0.1,cpu=cpu)
    print(f"Dataset sizes:\n\ttraining={len(train_loader.sampler)}\n\tvalidation={len(val_loader.sampler)}\n\ttest={len(test_loader.sampler)}")
else:
    print('Dataset Exists')
# Out:
# Running on device: NVIDIA GeForce RTX 2070 SUPER
# No key `noise_var` in input augmentation dictionary!  Using defaults: [Min: 0., Max: 1.]
# No key `shift` in input augmentation dictionary! Using defaults: [Min:-0.1, Max: 0.1]
# No key `strech` in input augmentation dictionary! Using defaults: [Min: 0.8, Max: 1.3]
# Generating dataset from raw data samples for the first time.
# This process will take significant time (~60 minutes)...
# data_len: 16384
# ------------- Label Size ---------------
# combined:  	5172
# human_cough:  	3760
# ------------------------------------------
# Processing the label: combined. 1 of 2
# 	1 of 5172
# 	1001 of 5172
# 	2001 of 5172
# 	3001 of 5172
# 	4001 of 5172
# 	5001 of 5172
# Finished in 106.045 seconds.
# (15516, 128, 128)
# Data concatenation finished in 0.027 seconds.
# Processing the label: human_cough. 2 of 2
# 	1 of 3760
# 	1001 of 3760
# 	2001 of 3760
# 	3001 of 3760
# Finished in 75.171 seconds.
# (11280, 128, 128)
# Data concatenation finished in 0.059 seconds.
# Dataset created.
# Training+Validation: 3403,  Test: 357
#
# Processing train...
# Class combined not found in data
#
# Processing test...
# Class combined not found in data
# Dataset sizes:
# 	training=21783
# 	validation=2421
# 	test=2592

# %% [markdown]
# ## Load Reference Model

# %%
def count_params(model):
    model_parameters = filter(lambda p: p.requires_grad, model.parameters())
    params = sum([np.prod(p.size()) for p in model_parameters])
    print(params)
    return params

ai8x.set_device(device=85, simulate=False, round_avg=False)

mod = importlib.import_module("models.ai85net-kws20-v3")

model = mod.AI85KWS20Netv3(num_classes=21, num_channels=128, dimensions=(128, 1), bias=False)
print(f'Number of Model Params: {count_params(model)}')

# WEIGHTS OF REFERENCE MODEL
model, compression_scheduler, optimizer, start_epoch = apputils.load_checkpoint(
            model, "../logs/kws20_original/qat_best.pth.tar")

 # FREEZE SOME LAYERS
def freeze_layer(layer):
    for p in layer.parameters():
        p.requires_grad = False

# freeze_layer(model.voice_conv1)
# freeze_layer(model.voice_conv2)
freeze_layer(model.voice_conv3)
freeze_layer(model.voice_conv4)
freeze_layer(model.kws_conv1)
freeze_layer(model.kws_conv2)
freeze_layer(model.kws_conv3)
# freeze_layer(model.kws_conv4)
model.fc = ai8x.Linear(256, len(classes), bias=False, wide=True)

model = model.to(device)
# Out:
# Configuring device: MAX78000, simulate=False.
# 169472
# Number of Model Params: 169472

# %% [markdown]
# ## Prepare Training Params

# %%
num_epochs = 20000
optimizer = optim.Adam(model.parameters(), lr=0.001)
ms_lr_scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[500, 1000], gamma=0.2)

criterion = torch.nn.CrossEntropyLoss(weight=torch.FloatTensor(class_weights))
criterion.to(device)

qat_policy = {
    'start_epoch': 400,
    'weight_bits': 8
    }

# %% [markdown]
# ## Train the Model

# %%
best_acc = 0
best_qat_acc = 0
best_loss = 0
best_epoch = 0

train_acc = []
train_loss = []
val_acc = []
val_loss =[]
running_class_acc = []

for epoch in range(0, num_epochs):
    train_start = time.time()
    if epoch > 0 and epoch == qat_policy['start_epoch']:
        print('QAT is starting!')
        # Fuse the BN parameters into conv layers before Quantization Aware Training (QAT)
        ai8x.fuse_bn_layers(model)
        # Switch model from unquantized to quantized for QAT
        ai8x.initiate_qat(model, qat_policy)
        # Model is re-transferred to GPU in case parameters were added
        model.to(device)

    average_acc = 0
    ############ TRAIN SECTION ############
    running_loss = []
    y_pred_train = []
    y_true_train = []
    acc_b = []
    model.train()
    for idx, (inputs, target) in enumerate(train_loader):
        inputs = inputs.to(device)
        target = target.to(device)
        optimizer.zero_grad()
        
        model_out = model(inputs)
        target_out = torch.argmax(model_out, dim=1)
        
        y_pred_train.extend(target_out.cpu().numpy())
        y_true_train.extend(target.cpu().numpy())
        
        tp = torch.sum(target_out == target)
        acc_b.extend([(tp / target_out.numel()).detach().item()])
        
        loss = criterion(model_out, target)     
        loss.backward()
        optimizer.step()
        
        running_loss.append(loss.cpu().detach().numpy())
    
    total_acc = np.mean(acc_b)*100
    mean_loss = np.mean(running_loss)

    # TRAIN ACCURACY / TRAIN LOSS
    train_acc.append(total_acc)
    train_loss.append(mean_loss)
    average_acc += total_acc/2

    ############ VALIDATION SECTION ############
    acc_b = []
    y_pred_val = []
    y_true_val = []
    running_v_loss = []
    
    model.eval()
    with torch.no_grad():
        for inputs, target in test_loader:
            inputs = inputs.to(device)
            target = target.to(device)
            model_out = model(inputs)
            target_out = torch.argmax(model_out, dim=1)
            
            y_pred_val.extend(target_out.cpu().numpy())
            y_true_val.extend(target.cpu().numpy())
            
            tp = torch.sum(target_out == target)
            acc_b.extend([(tp / target_out.numel()).detach().item()])

            v_loss = criterion(model_out, target)
            running_v_loss.append(loss.cpu().detach().numpy())

        total_acc = np.mean(acc_b)*100
        mean_loss = np.mean(running_v_loss)

        if epoch == qat_policy['start_epoch']: best_acc = 0
        
        # VALIDATION ACCURACY / VALIDATION LOSS
        val_acc.append(total_acc)
        val_loss.append(mean_loss)
        average_acc += total_acc/2
    
    train_end = time.time()
    ms_lr_scheduler.step()

    ############ CLASS ACCURACY ############
    class_acc = np.zeros(len(classes))
    for class_num,class_type in enumerate(classes):
        class_count_train = y_true_train.count(class_num)
        class_count_val = y_true_val.count(class_num)

        for t_idx, targ_val in enumerate(y_true_train):
            if targ_val == y_pred_train[t_idx] and targ_val == class_num:
                class_acc[class_num] += 1/class_count_train/2*100

        for t_idx, targ_val in enumerate(y_true_val):
            if targ_val == y_pred_val[t_idx] and targ_val == class_num:
                class_acc[class_num] += 1/class_count_val/2*100
        
    running_class_acc.append(class_acc)
    print('---------------------------------------------')
    print("\n\n Epoch: {}/{} \tLR: {} \tDur: {:.2f} sec".format(epoch+1, num_epochs, ms_lr_scheduler.get_lr() , (train_end-train_start)))

    ############ SAVE CHECKPOINT ############   
    if average_acc > best_acc:
        best_acc = average_acc
        checkpoint_extras = {'best_ave_acc': best_acc,
                                'best_epoch': epoch}
        
        model_prefix = f'{model_name}' if epoch < qat_policy['start_epoch'] else (f'qat_{model_name}')
        apputils.save_checkpoint(epoch, model_name+'_'+str(epoch), model, optimizer=optimizer,
                                    scheduler=None, extras=checkpoint_extras,
                                    is_best=True, name=model_prefix,
                                    dir=checkpoint_dir)

        # PLOT CONFUSION MATRIX AND STAT MEASURES ON TRAIN
        conf_mat_train = confusion_matrix(y_true_train, y_pred_train)
        cm_display_train = ConfusionMatrixDisplay(confusion_matrix = conf_mat_train, display_labels = classes)
        p_train,r_train,f1_train,_= precision_recall_fscore_support(y_true_train, y_pred_train, average=None)
        cm_display_train.plot(cmap= 'Blues',colorbar=False, values_format = 'd')
        plt.title('Preicison: ({:.2f} {:.2f})   Recall: ({:.2f} {:.2f})   F1-Score: ({:.2f} {:.2f})'.format(p_train[0],p_train[1],r_train[0],r_train[1],f1_train[0],f1_train[1]))
        plt.savefig(checkpoint_dir+model_name+'_cm_train.png')
        plt.clf()
        plt.cla()
        plt.close()

        # PLOT ROC ON TRAIN
        plot_roc_curve(y_true_train, y_pred_train)
        plt.title('AUC: {:2f}'.format(roc_auc_score(y_true_train, y_pred_train)))
        plt.savefig(checkpoint_dir+model_name+'_roc_train.png')
        plt.clf()
        plt.cla()
        plt.close()

        # PLOT CONFUSION MATRIX AND STAT MEASURES ON VALIDATION
        conf_mat_val = confusion_matrix(y_true_val, y_pred_val)
        cm_display_val = ConfusionMatrixDisplay(confusion_matrix = conf_mat_val, display_labels = classes)
        p_val,r_val,f1_val,_= precision_recall_fscore_support(y_true_val, y_pred_val, average=None)
        cm_display_val.plot(cmap= 'Blues',colorbar=False, values_format = 'd')
        plt.title('Preicison: ({:.2f} {:.2f})   Recall: ({:.2f} {:.2f})   F1-Score: ({:.2f} {:.2f})'.format(p_val[0],p_val[1],r_val[0],r_val[1],f1_val[0],f1_val[1]))
        plt.savefig(checkpoint_dir+model_name+'_cm_Val.png')
        plt.clf()
        plt.cla()
        plt.close()

        # PLOT ROC ON VAL
        plot_roc_curve(y_true_val, y_pred_val)
        plt.title('AUC: {:.2f}'.format(roc_auc_score(y_true_val, y_pred_val)))
        plt.savefig(checkpoint_dir+model_name+'_roc_val.png')
        plt.clf()
        plt.cla()
        plt.close()

        print(f' --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : {best_acc:.2f}%')

    ############ CONFUSION MATRIX ############   
    print("\n Training - Confusion Matrix: ")
    plot_confusion(y_true_train, y_pred_train, classes)
    print("\n Validation - Confusion Matrix: ")
    plot_confusion(y_true_val, y_pred_val, classes)
    
    ############ ACC and LOSS ############  
    print('\nTrain Acc : ', train_acc[-1])
    print('Train Loss : ', train_loss[-1])
    print('Val Acc : ', val_acc[-1])
    print('Val Loss : ', val_loss[-1])

    ############ PLOTS ############
    if (epoch%2 == 0 or epoch==num_epochs-1) and epoch > 0:
        best_epoch = checkpoint_extras['best_epoch']
        
        plt.figure(figsize=(20,10))
        plt.title(model_name)
        plt.subplot(1,2,1)
        plt.plot(val_acc, color ='green')
        plt.plot(train_acc, color = 'red')
        plt.plot(np.asarray(running_class_acc)[:,0],color='orange')
        plt.plot(np.asarray(running_class_acc)[:,1],color='yellow')
        plt.stem(best_epoch,train_acc[best_epoch])
        plt.legend(['Validation','Train',classes[0],classes[1],'Checkpoint'])
        plt.title('Accuracy: {:.2f}'.format(train_acc[best_epoch]))
        plt.xlabel('Epochs')
        plt.ylabel('Value')

        plt.subplot(1,2,2)
        plt.plot(val_loss,color='green')
        plt.plot(train_loss,color='red')
        plt.stem(best_epoch,train_loss[best_epoch])
        plt.legend(['Validation','Train','Checkpoint'])
        plt.title('Loss: {:.2f}'.format(train_loss[best_epoch]))
        plt.xlabel('Epochs')
        plt.ylabel('Value')

        plt.savefig(checkpoint_dir+model_name+'.png')
        
        plt.clf()
        plt.cla()
        plt.close()
# Out:
# ---------------------------------------------
#
#
#  Epoch: 1/20000 	LR: [0.001] 	Dur: 9.62 sec
#  --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : 44.53%
#
#  Training - Confusion Matrix:
# [[4500 8060]
#  [3164 6059]]
#
#  Validation - Confusion Matrix:
# [[  12 1509]
#  [  12 1059]]
#
# Train Acc :  47.74432828028996
# Train Loss :  0.6944224
# Val Acc :  41.31944477558136
# Val Loss :  0.68024546
# ---------------------------------------------
#
#
#  Epoch: 2/20000 	LR: [0.001] 	Dur: 8.49 sec
#  --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : 46.25%
#
#  Training - Confusion Matrix:
# [[  490 12070]
#  [  238  8985]]
#
#  Validation - Confusion Matrix:
# [[ 341 1180]
#  [ 159  912]]
#
# Train Acc :  44.15338784456253
# Train Loss :  0.66716367
# Val Acc :  48.3410507440567
# Val Loss :  0.64576316
# ---------------------------------------------
#
#
#  Epoch: 3/20000 	LR: [0.001] 	Dur: 8.49 sec
#  --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : 54.18%
#
#  Training - Confusion Matrix:
# [[4448 8112]
#  [2004 7219]]
#
#  Validation - Confusion Matrix:
# [[559 962]
#  [208 863]]
#
# Train Acc :  53.49131325880686
# Train Loss :  0.6507593
# Val Acc :  54.86111044883728
# Val Loss :  0.6540902
# ---------------------------------------------
#
#
#  Epoch: 4/20000 	LR: [0.001] 	Dur: 8.52 sec
#
#  Training - Confusion Matrix:
# [[3474 9086]
#  [1425 7798]]
#
#  Validation - Confusion Matrix:
# [[ 323 1198]
#  [  93  978]]
#
# Train Acc :  51.63111686706543
# Train Loss :  0.63783157
# Val Acc :  50.192904472351074
# Val Loss :  0.6338965
# ---------------------------------------------
#
#
#  Epoch: 5/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[3115 9445]
#  [1276 7947]]
#
#  Validation - Confusion Matrix:
# [[ 495 1026]
#  [ 198  873]]
#
# Train Acc :  51.099338134129844
# Train Loss :  0.63232166
# Val Acc :  52.77777910232544
# Val Loss :  0.6304254
# ---------------------------------------------
#
#
#  Epoch: 6/20000 	LR: [0.001] 	Dur: 8.51 sec
#  --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : 55.57%
#
#  Training - Confusion Matrix:
# [[4937 7623]
#  [2068 7155]]
#
#  Validation - Confusion Matrix:
# [[590 931]
#  [219 852]]
#
# Train Acc :  55.508468548456825
# Train Loss :  0.6261069
# Val Acc :  55.63271641731262
# Val Loss :  0.62560576
# ---------------------------------------------
#
#
#  Epoch: 7/20000 	LR: [0.001] 	Dur: 8.46 sec
#
#  Training - Confusion Matrix:
# [[4545 8015]
#  [1821 7402]]
#
#  Validation - Confusion Matrix:
# [[535 986]
#  [203 868]]
#
# Train Acc :  54.595748583475746
# Train Loss :  0.62646073
# Val Acc :  54.12808656692505
# Val Loss :  0.6296798
# ---------------------------------------------
#
#
#  Epoch: 8/20000 	LR: [0.001] 	Dur: 8.43 sec
#  --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : 57.14%
#
#  Training - Confusion Matrix:
# [[5390 7170]
#  [2327 6896]]
#
#  Validation - Confusion Matrix:
# [[687 834]
#  [263 808]]
#
# Train Acc :  56.61184787750244
# Train Loss :  0.6248095
# Val Acc :  57.67747163772583
# Val Loss :  0.6189197
# ---------------------------------------------
#
#
#  Epoch: 9/20000 	LR: [0.001] 	Dur: 8.49 sec
#
#  Training - Confusion Matrix:
# [[5241 7319]
#  [2179 7044]]
#
#  Validation - Confusion Matrix:
# [[535 986]
#  [211 860]]
#
# Train Acc :  56.18040164311727
# Train Loss :  0.62102896
# Val Acc :  53.8194477558136
# Val Loss :  0.6238272
# ---------------------------------------------
#
#
#  Epoch: 10/20000 	LR: [0.001] 	Dur: 8.44 sec
#  --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : 58.11%
#
#  Training - Confusion Matrix:
# [[5089 7471]
#  [2068 7155]]
#
#  Validation - Confusion Matrix:
# [[756 765]
#  [278 793]]
#
# Train Acc :  56.46711587905884
# Train Loss :  0.6202175
# Val Acc :  59.76080298423767
# Val Loss :  0.6217488
# ---------------------------------------------
#
#
#  Epoch: 11/20000 	LR: [0.001] 	Dur: 8.45 sec
#  --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : 59.58%
#
#  Training - Confusion Matrix:
# [[6465 6095]
#  [2687 6536]]
#
#  Validation - Confusion Matrix:
# [[731 790]
#  [255 816]]
#
# Train Acc :  59.486302733421326
# Train Loss :  0.6150689
# Val Acc :  59.68364477157593
# Val Loss :  0.6175428
# ---------------------------------------------
#
#
#  Epoch: 12/20000 	LR: [0.001] 	Dur: 8.53 sec
#
#  Training - Confusion Matrix:
# [[5215 7345]
#  [2142 7081]]
#
#  Validation - Confusion Matrix:
# [[613 908]
#  [205 866]]
#
# Train Acc :  56.547874212265015
# Train Loss :  0.61320925
# Val Acc :  57.06018805503845
# Val Loss :  0.610629
# ---------------------------------------------
#
#
#  Epoch: 13/20000 	LR: [0.001] 	Dur: 8.43 sec
#  --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : 60.19%
#
#  Training - Confusion Matrix:
# [[5690 6870]
#  [2392 6831]]
#
#  Validation - Confusion Matrix:
# [[895 626]
#  [339 732]]
#
# Train Acc :  57.61167506376902
# Train Loss :  0.61359096
# Val Acc :  62.77006268501282
# Val Loss :  0.61671835
# ---------------------------------------------
#
#
#  Epoch: 14/20000 	LR: [0.001] 	Dur: 8.41 sec
#
#  Training - Confusion Matrix:
# [[6331 6229]
#  [2692 6531]]
#
#  Validation - Confusion Matrix:
# [[593 928]
#  [231 840]]
#
# Train Acc :  58.81604651610056
# Train Loss :  0.61143595
# Val Acc :  55.28549551963806
# Val Loss :  0.6117941
# ---------------------------------------------
#
#
#  Epoch: 15/20000 	LR: [0.001] 	Dur: 8.46 sec
#
#  Training - Confusion Matrix:
# [[5298 7262]
#  [2185 7038]]
#
#  Validation - Confusion Matrix:
# [[788 733]
#  [280 791]]
#
# Train Acc :  56.97229405244192
# Train Loss :  0.6087486
# Val Acc :  60.918211936950684
# Val Loss :  0.6027934
# ---------------------------------------------
#
#
#  Epoch: 16/20000 	LR: [0.001] 	Dur: 8.69 sec
#
#  Training - Confusion Matrix:
# [[6157 6403]
#  [2585 6638]]
#
#  Validation - Confusion Matrix:
# [[735 786]
#  [242 829]]
#
# Train Acc :  58.656808733940125
# Train Loss :  0.6090811
# Val Acc :  60.33950448036194
# Val Loss :  0.6138581
# ---------------------------------------------
#
#
#  Epoch: 17/20000 	LR: [0.001] 	Dur: 8.47 sec
#
#  Training - Confusion Matrix:
# [[5573 6987]
#  [2232 6991]]
#
#  Validation - Confusion Matrix:
# [[748 773]
#  [278 793]]
#
# Train Acc :  57.821531097094216
# Train Loss :  0.60887975
# Val Acc :  59.45215821266174
# Val Loss :  0.6153003
# ---------------------------------------------
#
#
#  Epoch: 18/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[6170 6390]
#  [2532 6691]]
#
#  Validation - Confusion Matrix:
# [[813 708]
#  [305 766]]
#
# Train Acc :  59.05619263648987
# Train Loss :  0.6086547
# Val Acc :  60.918211936950684
# Val Loss :  0.6101983
# ---------------------------------------------
#
#
#  Epoch: 19/20000 	LR: [0.001] 	Dur: 8.36 sec
#
#  Training - Confusion Matrix:
# [[6053 6507]
#  [2509 6714]]
#
#  Validation - Confusion Matrix:
# [[760 761]
#  [293 778]]
#
# Train Acc :  58.656262358029686
# Train Loss :  0.6095777
# Val Acc :  59.33641791343689
# Val Loss :  0.6112223
# ---------------------------------------------
#
#
#  Epoch: 20/20000 	LR: [0.001] 	Dur: 8.41 sec
#
#  Training - Confusion Matrix:
# [[5592 6968]
#  [2309 6914]]
#
#  Validation - Confusion Matrix:
# [[788 733]
#  [287 784]]
#
# Train Acc :  57.280258337656655
# Train Loss :  0.61056095
# Val Acc :  60.648149251937866
# Val Loss :  0.6137381
# ---------------------------------------------
#
#
#  Epoch: 21/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[5945 6615]
#  [2448 6775]]
#
#  Validation - Confusion Matrix:
# [[785 736]
#  [304 767]]
#
# Train Acc :  58.68306855360667
# Train Loss :  0.6087053
# Val Acc :  59.876543283462524
# Val Loss :  0.5970892
# ---------------------------------------------
#
#
#  Epoch: 22/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[5849 6711]
#  [2389 6834]]
#
#  Validation - Confusion Matrix:
# [[740 781]
#  [279 792]]
#
# Train Acc :  58.09641579786936
# Train Loss :  0.6119122
# Val Acc :  59.10493731498718
# Val Loss :  0.6184514
# ---------------------------------------------
#
#
#  Epoch: 23/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[5655 6905]
#  [2347 6876]]
#
#  Validation - Confusion Matrix:
# [[780 741]
#  [328 743]]
#
# Train Acc :  57.90530343850454
# Train Loss :  0.6127701
# Val Acc :  58.75771641731262
# Val Loss :  0.6004142
# ---------------------------------------------
#
#
#  Epoch: 24/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[5719 6841]
#  [2363 6860]]
#
#  Validation - Confusion Matrix:
# [[677 844]
#  [256 815]]
#
# Train Acc :  57.777902483940125
# Train Loss :  0.6144834
# Val Acc :  57.56173133850098
# Val Loss :  0.6223622
# ---------------------------------------------
#
#
#  Epoch: 25/20000 	LR: [0.001] 	Dur: 8.35 sec
#
#  Training - Confusion Matrix:
# [[5173 7387]
#  [2213 7010]]
#
#  Validation - Confusion Matrix:
# [[744 777]
#  [308 763]]
#
# Train Acc :  55.965967973073326
# Train Loss :  0.6171186
# Val Acc :  58.140432834625244
# Val Loss :  0.6113667
# ---------------------------------------------
#
#
#  Epoch: 26/20000 	LR: [0.001] 	Dur: 8.41 sec
#
#  Training - Confusion Matrix:
# [[5703 6857]
#  [2488 6735]]
#
#  Validation - Confusion Matrix:
# [[680 841]
#  [245 826]]
#
# Train Acc :  57.14311798413595
# Train Loss :  0.6185248
# Val Acc :  58.101850748062134
# Val Loss :  0.61696374
# ---------------------------------------------
#
#
#  Epoch: 27/20000 	LR: [0.001] 	Dur: 8.41 sec
#
#  Training - Confusion Matrix:
# [[5415 7145]
#  [2410 6813]]
#
#  Validation - Confusion Matrix:
# [[637 884]
#  [273 798]]
#
# Train Acc :  56.12290799617767
# Train Loss :  0.6202619
# Val Acc :  55.362653732299805
# Val Loss :  0.6153976
# ---------------------------------------------
#
#
#  Epoch: 28/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[5329 7231]
#  [2512 6711]]
#
#  Validation - Confusion Matrix:
# [[625 896]
#  [272 799]]
#
# Train Acc :  55.2794357140859
# Train Loss :  0.62365025
# Val Acc :  54.9382746219635
# Val Loss :  0.6065556
# ---------------------------------------------
#
#
#  Epoch: 29/20000 	LR: [0.001] 	Dur: 8.32 sec
#
#  Training - Confusion Matrix:
# [[5062 7498]
#  [2355 6868]]
#
#  Validation - Confusion Matrix:
# [[692 829]
#  [336 735]]
#
# Train Acc :  54.88417645295461
# Train Loss :  0.62209505
# Val Acc :  55.054014921188354
# Val Loss :  0.62192184
# ---------------------------------------------
#
#
#  Epoch: 30/20000 	LR: [0.001] 	Dur: 8.35 sec
#
#  Training - Confusion Matrix:
# [[5124 7436]
#  [2373 6850]]
#
#  Validation - Confusion Matrix:
# [[643 878]
#  [288 783]]
#
# Train Acc :  54.99343772729238
# Train Loss :  0.61927414
# Val Acc :  55.015432834625244
# Val Loss :  0.6092049
# ---------------------------------------------
#
#
#  Epoch: 31/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[5177 7383]
#  [2374 6849]]
#
#  Validation - Confusion Matrix:
# [[774 747]
#  [341 730]]
#
# Train Acc :  55.14397223790487
# Train Loss :  0.62030405
# Val Acc :  58.02469253540039
# Val Loss :  0.62597984
# ---------------------------------------------
#
#
#  Epoch: 32/20000 	LR: [0.001] 	Dur: 8.45 sec
#
#  Training - Confusion Matrix:
# [[5439 7121]
#  [2428 6795]]
#
#  Validation - Confusion Matrix:
# [[638 883]
#  [278 793]]
#
# Train Acc :  56.007770697275795
# Train Loss :  0.6158201
# Val Acc :  55.20833134651184
# Val Loss :  0.62029594
# ---------------------------------------------
#
#
#  Epoch: 33/20000 	LR: [0.001] 	Dur: 8.36 sec
#
#  Training - Confusion Matrix:
# [[5047 7513]
#  [2233 6990]]
#
#  Validation - Confusion Matrix:
# [[652 869]
#  [250 821]]
#
# Train Acc :  55.1625649134318
# Train Loss :  0.61511934
# Val Acc :  56.82870149612427
# Val Loss :  0.6158197
# ---------------------------------------------
#
#
#  Epoch: 34/20000 	LR: [0.001] 	Dur: 8.41 sec
#
#  Training - Confusion Matrix:
# [[4363 8197]
#  [1867 7356]]
#
#  Validation - Confusion Matrix:
# [[741 780]
#  [307 764]]
#
# Train Acc :  54.06922598679861
# Train Loss :  0.6152711
# Val Acc :  58.0632746219635
# Val Loss :  0.61709046
# ---------------------------------------------
#
#
#  Epoch: 35/20000 	LR: [0.001] 	Dur: 8.37 sec
#
#  Training - Confusion Matrix:
# [[6419 6141]
#  [2840 6383]]
#
#  Validation - Confusion Matrix:
# [[613 908]
#  [275 796]]
#
# Train Acc :  58.42363238334656
# Train Loss :  0.61489785
# Val Acc :  54.359567165374756
# Val Loss :  0.62434024
# ---------------------------------------------
#
#
#  Epoch: 36/20000 	LR: [0.001] 	Dur: 8.43 sec
#
#  Training - Confusion Matrix:
# [[4519 8041]
#  [1923 7300]]
#
#  Validation - Confusion Matrix:
# [[710 811]
#  [303 768]]
#
# Train Acc :  54.43251629670461
# Train Loss :  0.61368084
# Val Acc :  57.02160596847534
# Val Loss :  0.607396
# ---------------------------------------------
#
#
#  Epoch: 37/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[5766 6794]
#  [2599 6624]]
#
#  Validation - Confusion Matrix:
# [[633 888]
#  [286 785]]
#
# Train Acc :  56.62509202957153
# Train Loss :  0.61639154
# Val Acc :  54.706788063049316
# Val Loss :  0.62906617
# ---------------------------------------------
#
#
#  Epoch: 38/20000 	LR: [0.001] 	Dur: 8.46 sec
#
#  Training - Confusion Matrix:
# [[5715 6845]
#  [2543 6680]]
#
#  Validation - Confusion Matrix:
# [[563 958]
#  [252 819]]
#
# Train Acc :  56.68032467365265
# Train Loss :  0.6147068
# Val Acc :  53.317904472351074
# Val Loss :  0.62136817
# ---------------------------------------------
#
#
#  Epoch: 39/20000 	LR: [0.001] 	Dur: 8.37 sec
#
#  Training - Confusion Matrix:
# [[4808 7752]
#  [2146 7077]]
#
#  Validation - Confusion Matrix:
# [[682 839]
#  [288 783]]
#
# Train Acc :  54.8319011926651
# Train Loss :  0.6138655
# Val Acc :  56.52006268501282
# Val Loss :  0.59811443
# ---------------------------------------------
#
#
#  Epoch: 40/20000 	LR: [0.001] 	Dur: 8.35 sec
#
#  Training - Confusion Matrix:
# [[5594 6966]
#  [2571 6652]]
#
#  Validation - Confusion Matrix:
# [[617 904]
#  [249 822]]
#
# Train Acc :  55.7774951060613
# Train Loss :  0.615696
# Val Acc :  55.51697611808777
# Val Loss :  0.6274886
# ---------------------------------------------
#
#
#  Epoch: 41/20000 	LR: [0.001] 	Dur: 8.42 sec
#
#  Training - Confusion Matrix:
# [[5004 7556]
#  [2266 6957]]
#
#  Validation - Confusion Matrix:
# [[671 850]
#  [268 803]]
#
# Train Acc :  54.92309629917145
# Train Loss :  0.61514264
# Val Acc :  56.86728358268738
# Val Loss :  0.6134153
# ---------------------------------------------
#
#
#  Epoch: 42/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[6275 6285]
#  [2852 6371]]
#
#  Validation - Confusion Matrix:
# [[546 975]
#  [183 888]]
#
# Train Acc :  57.69292414188385
# Train Loss :  0.6137227
# Val Acc :  55.324071645736694
# Val Loss :  0.6132738
# ---------------------------------------------
#
#
#  Epoch: 43/20000 	LR: [0.001] 	Dur: 8.43 sec
#
#  Training - Confusion Matrix:
# [[4623 7937]
#  [2134 7089]]
#
#  Validation - Confusion Matrix:
# [[718 803]
#  [282 789]]
#
# Train Acc :  54.01457647482554
# Train Loss :  0.61265314
# Val Acc :  58.140432834625244
# Val Loss :  0.6096015
# ---------------------------------------------
#
#
#  Epoch: 44/20000 	LR: [0.001] 	Dur: 8.37 sec
#
#  Training - Confusion Matrix:
# [[6183 6377]
#  [2757 6466]]
#
#  Validation - Confusion Matrix:
# [[562 959]
#  [221 850]]
#
# Train Acc :  57.89701541264852
# Train Loss :  0.60837394
# Val Acc :  54.47530746459961
# Val Loss :  0.5895771
# ---------------------------------------------
#
#
#  Epoch: 45/20000 	LR: [0.001] 	Dur: 8.34 sec
#
#  Training - Confusion Matrix:
# [[5172 7388]
#  [2244 6979]]
#
#  Validation - Confusion Matrix:
# [[757 764]
#  [306 765]]
#
# Train Acc :  56.28058115641276
# Train Loss :  0.60905576
# Val Acc :  58.71913433074951
# Val Loss :  0.6118835
# ---------------------------------------------
#
#
#  Epoch: 46/20000 	LR: [0.001] 	Dur: 8.44 sec
#
#  Training - Confusion Matrix:
# [[5234 7326]
#  [2241 6982]]
#
#  Validation - Confusion Matrix:
# [[761 760]
#  [290 781]]
#
# Train Acc :  55.85603018601736
# Train Loss :  0.60957474
# Val Acc :  59.49074029922485
# Val Loss :  0.6138896
# ---------------------------------------------
#
#
#  Epoch: 47/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[6698 5862]
#  [2872 6351]]
#
#  Validation - Confusion Matrix:
# [[690 831]
#  [252 819]]
#
# Train Acc :  60.00432868798574
# Train Loss :  0.6066161
# Val Acc :  58.21759104728699
# Val Loss :  0.5969912
# ---------------------------------------------
#
#
#  Epoch: 48/20000 	LR: [0.001] 	Dur: 8.37 sec
#
#  Training - Confusion Matrix:
# [[4684 7876]
#  [1977 7246]]
#
#  Validation - Confusion Matrix:
# [[858 663]
#  [349 722]]
#
# Train Acc :  55.2941103776296
# Train Loss :  0.6073296
# Val Acc :  60.956788063049316
# Val Loss :  0.60065186
# ---------------------------------------------
#
#
#  Epoch: 49/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[6749 5811]
#  [2931 6292]]
#
#  Validation - Confusion Matrix:
# [[608 913]
#  [228 843]]
#
# Train Acc :  59.56184367338816
# Train Loss :  0.6069513
# Val Acc :  55.97993731498718
# Val Loss :  0.6011588
# ---------------------------------------------
#
#
#  Epoch: 50/20000 	LR: [0.001] 	Dur: 8.45 sec
#
#  Training - Confusion Matrix:
# [[4819 7741]
#  [2004 7219]]
#
#  Validation - Confusion Matrix:
# [[927 594]
#  [370 701]]
#
# Train Acc :  55.80333868662516
# Train Loss :  0.6129853
# Val Acc :  62.80864477157593
# Val Loss :  0.61809725
# ---------------------------------------------
#
#
#  Epoch: 51/20000 	LR: [0.001] 	Dur: 8.31 sec
#
#  Training - Confusion Matrix:
# [[6903 5657]
#  [3126 6097]]
#
#  Validation - Confusion Matrix:
# [[627 894]
#  [242 829]]
#
# Train Acc :  59.22057429949442
# Train Loss :  0.6130006
# Val Acc :  56.17284178733826
# Val Loss :  0.61163
# ---------------------------------------------
#
#
#  Epoch: 52/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[5258 7302]
#  [2275 6948]]
#
#  Validation - Confusion Matrix:
# [[839 682]
#  [343 728]]
#
# Train Acc :  56.06827735900879
# Train Loss :  0.6111854
# Val Acc :  60.45524477958679
# Val Loss :  0.6121126
# ---------------------------------------------
#
#
#  Epoch: 53/20000 	LR: [0.001] 	Dur: 8.35 sec
#
#  Training - Confusion Matrix:
# [[6490 6070]
#  [2848 6375]]
#
#  Validation - Confusion Matrix:
# [[655 866]
#  [253 818]]
#
# Train Acc :  58.5578719774882
# Train Loss :  0.6111915
# Val Acc :  56.82870149612427
# Val Loss :  0.6194392
# ---------------------------------------------
#
#
#  Epoch: 54/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[5141 7419]
#  [2160 7063]]
#
#  Validation - Confusion Matrix:
# [[831 690]
#  [326 745]]
#
# Train Acc :  56.32179876168569
# Train Loss :  0.6093251
# Val Acc :  60.80247163772583
# Val Loss :  0.6050659
# ---------------------------------------------
#
#
#  Epoch: 55/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[6132 6428]
#  [2690 6533]]
#
#  Validation - Confusion Matrix:
# [[669 852]
#  [261 810]]
#
# Train Acc :  57.98828502496084
# Train Loss :  0.60956484
# Val Acc :  57.06018805503845
# Val Loss :  0.6056952
# ---------------------------------------------
#
#
#  Epoch: 56/20000 	LR: [0.001] 	Dur: 8.41 sec
#
#  Training - Confusion Matrix:
# [[5606 6954]
#  [2419 6804]]
#
#  Validation - Confusion Matrix:
# [[792 729]
#  [347 724]]
#
# Train Acc :  57.12512731552124
# Train Loss :  0.6071591
# Val Acc :  58.487653732299805
# Val Loss :  0.5959943
# ---------------------------------------------
#
#
#  Epoch: 57/20000 	LR: [0.001] 	Dur: 8.36 sec
#
#  Training - Confusion Matrix:
# [[6143 6417]
#  [2647 6576]]
#
#  Validation - Confusion Matrix:
# [[700 821]
#  [296 775]]
#
# Train Acc :  58.112069964408875
# Train Loss :  0.60914236
# Val Acc :  56.90586566925049
# Val Loss :  0.6104042
# ---------------------------------------------
#
#
#  Epoch: 58/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[5522 7038]
#  [2309 6914]]
#
#  Validation - Confusion Matrix:
# [[753 768]
#  [328 743]]
#
# Train Acc :  57.17858970165253
# Train Loss :  0.6082621
# Val Acc :  57.71604776382446
# Val Loss :  0.6099831
# ---------------------------------------------
#
#
#  Epoch: 59/20000 	LR: [0.001] 	Dur: 8.35 sec
#
#  Training - Confusion Matrix:
# [[6313 6247]
#  [2703 6520]]
#
#  Validation - Confusion Matrix:
# [[666 855]
#  [280 791]]
#
# Train Acc :  58.79398683706919
# Train Loss :  0.6067932
# Val Acc :  56.21141791343689
# Val Loss :  0.60912436
# ---------------------------------------------
#
#
#  Epoch: 60/20000 	LR: [0.001] 	Dur: 8.35 sec
#
#  Training - Confusion Matrix:
# [[5451 7109]
#  [2354 6869]]
#
#  Validation - Confusion Matrix:
# [[820 701]
#  [337 734]]
#
# Train Acc :  56.91591203212738
# Train Loss :  0.60785323
# Val Acc :  59.95370149612427
# Val Loss :  0.5897565
# ---------------------------------------------
#
#
#  Epoch: 61/20000 	LR: [0.001] 	Dur: 8.46 sec
#
#  Training - Confusion Matrix:
# [[6120 6440]
#  [2692 6531]]
#
#  Validation - Confusion Matrix:
# [[647 874]
#  [273 798]]
#
# Train Acc :  58.00109505653381
# Train Loss :  0.6073031
# Val Acc :  55.748456716537476
# Val Loss :  0.5963298
# ---------------------------------------------
#
#
#  Epoch: 62/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[5651 6909]
#  [2363 6860]]
#
#  Validation - Confusion Matrix:
# [[810 711]
#  [320 751]]
#
# Train Acc :  57.76286919911703
# Train Loss :  0.60595053
# Val Acc :  60.223764181137085
# Val Loss :  0.6006009
# ---------------------------------------------
#
#
#  Epoch: 63/20000 	LR: [0.001] 	Dur: 8.34 sec
#
#  Training - Confusion Matrix:
# [[5907 6653]
#  [2622 6601]]
#
#  Validation - Confusion Matrix:
# [[652 869]
#  [266 805]]
#
# Train Acc :  57.41922656695048
# Train Loss :  0.60678047
# Val Acc :  56.21141791343689
# Val Loss :  0.6057691
# ---------------------------------------------
#
#
#  Epoch: 64/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[5262 7298]
#  [2166 7057]]
#
#  Validation - Confusion Matrix:
# [[877 644]
#  [353 718]]
#
# Train Acc :  56.65018359820048
# Train Loss :  0.60652566
# Val Acc :  61.53549551963806
# Val Loss :  0.6154884
# ---------------------------------------------
#
#
#  Epoch: 65/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[6330 6230]
#  [2813 6410]]
#
#  Validation - Confusion Matrix:
# [[609 912]
#  [244 827]]
#
# Train Acc :  58.110299706459045
# Train Loss :  0.607918
# Val Acc :  55.401235818862915
# Val Loss :  0.61268574
# ---------------------------------------------
#
#
#  Epoch: 66/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[5605 6955]
#  [2342 6881]]
#
#  Validation - Confusion Matrix:
# [[799 722]
#  [329 742]]
#
# Train Acc :  57.7919731537501
# Train Loss :  0.6045752
# Val Acc :  59.45215821266174
# Val Loss :  0.6048514
# ---------------------------------------------
#
#
#  Epoch: 67/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[5519 7041]
#  [2418 6805]]
#
#  Validation - Confusion Matrix:
# [[832 689]
#  [324 747]]
#
# Train Acc :  56.46992325782776
# Train Loss :  0.6050278
# Val Acc :  60.918211936950684
# Val Loss :  0.6053862
# ---------------------------------------------
#
#
#  Epoch: 68/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[6908 5652]
#  [2980 6243]]
#
#  Validation - Confusion Matrix:
# [[705 816]
#  [289 782]]
#
# Train Acc :  59.87860461076101
# Train Loss :  0.60462576
# Val Acc :  57.3688268661499
# Val Loss :  0.6083974
# ---------------------------------------------
#
#
#  Epoch: 69/20000 	LR: [0.001] 	Dur: 8.37 sec
#
#  Training - Confusion Matrix:
# [[5650 6910]
#  [2436 6787]]
#
#  Validation - Confusion Matrix:
# [[834 687]
#  [352 719]]
#
# Train Acc :  57.313488920529686
# Train Loss :  0.6038775
# Val Acc :  59.915125370025635
# Val Loss :  0.60239947
# ---------------------------------------------
#
#
#  Epoch: 70/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[6390 6170]
#  [2751 6472]]
#
#  Validation - Confusion Matrix:
# [[745 776]
#  [289 782]]
#
# Train Acc :  59.042818347613014
# Train Loss :  0.60313475
# Val Acc :  58.912038803100586
# Val Loss :  0.6001687
# ---------------------------------------------
#
#
#  Epoch: 71/20000 	LR: [0.001] 	Dur: 8.35 sec
#
#  Training - Confusion Matrix:
# [[6413 6147]
#  [2654 6569]]
#
#  Validation - Confusion Matrix:
# [[733 788]
#  [295 776]]
#
# Train Acc :  59.74914928277334
# Train Loss :  0.6011017
# Val Acc :  58.21759104728699
# Val Loss :  0.59724534
# ---------------------------------------------
#
#
#  Epoch: 72/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[5868 6692]
#  [2468 6755]]
#
#  Validation - Confusion Matrix:
# [[681 840]
#  [273 798]]
#
# Train Acc :  57.93949464956919
# Train Loss :  0.6020164
# Val Acc :  57.06018805503845
# Val Loss :  0.60366154
# ---------------------------------------------
#
#
#  Epoch: 73/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[6276 6284]
#  [2629 6594]]
#
#  Validation - Confusion Matrix:
# [[766 755]
#  [280 791]]
#
# Train Acc :  58.72649053732554
# Train Loss :  0.6040123
# Val Acc :  60.0694477558136
# Val Loss :  0.6178749
# ---------------------------------------------
#
#
#  Epoch: 74/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[6753 5807]
#  [2795 6428]]
#
#  Validation - Confusion Matrix:
# [[679 842]
#  [263 808]]
#
# Train Acc :  60.14022628466288
# Train Loss :  0.60194063
# Val Acc :  57.3688268661499
# Val Loss :  0.60475886
# ---------------------------------------------
#
#
#  Epoch: 75/20000 	LR: [0.001] 	Dur: 8.36 sec
#
#  Training - Confusion Matrix:
# [[5662 6898]
#  [2386 6837]]
#
#  Validation - Confusion Matrix:
# [[796 725]
#  [324 747]]
#
# Train Acc :  57.574488719304405
# Train Loss :  0.6056892
# Val Acc :  59.529322385787964
# Val Loss :  0.611997
# ---------------------------------------------
#
#
#  Epoch: 76/20000 	LR: [0.001] 	Dur: 8.34 sec
#
#  Training - Confusion Matrix:
# [[6007 6553]
#  [2488 6735]]
#
#  Validation - Confusion Matrix:
# [[715 806]
#  [297 774]]
#
# Train Acc :  58.397541443506874
# Train Loss :  0.60252666
# Val Acc :  57.44599103927612
# Val Loss :  0.59519583
# ---------------------------------------------
#
#
#  Epoch: 77/20000 	LR: [0.001] 	Dur: 8.37 sec
#
#  Training - Confusion Matrix:
# [[6368 6192]
#  [2677 6546]]
#
#  Validation - Confusion Matrix:
# [[771 750]
#  [305 766]]
#
# Train Acc :  59.132298827171326
# Train Loss :  0.6048974
# Val Acc :  59.29784178733826
# Val Loss :  0.6179865
# ---------------------------------------------
#
#
#  Epoch: 78/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[6805 5755]
#  [2946 6277]]
#
#  Validation - Confusion Matrix:
# [[633 888]
#  [243 828]]
#
# Train Acc :  59.8769466082255
# Train Loss :  0.6044202
# Val Acc :  56.36574029922485
# Val Loss :  0.60055405
# ---------------------------------------------
#
#
#  Epoch: 79/20000 	LR: [0.001] 	Dur: 8.43 sec
#
#  Training - Confusion Matrix:
# [[5163 7397]
#  [2139 7084]]
#
#  Validation - Confusion Matrix:
# [[887 634]
#  [392 679]]
#
# Train Acc :  56.40954673290253
# Train Loss :  0.6058764
# Val Acc :  60.41666865348816
# Val Loss :  0.6166525
# ---------------------------------------------
#
#
#  Epoch: 80/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[6853 5707]
#  [2930 6293]]
#
#  Validation - Confusion Matrix:
# [[623 898]
#  [267 804]]
#
# Train Acc :  59.718708197275795
# Train Loss :  0.605282
# Val Acc :  55.054014921188354
# Val Loss :  0.60334754
# ---------------------------------------------
#
#
#  Epoch: 81/20000 	LR: [0.001] 	Dur: 8.43 sec
#
#  Training - Confusion Matrix:
# [[5686 6874]
#  [2377 6846]]
#
#  Validation - Confusion Matrix:
# [[852 669]
#  [365 706]]
#
# Train Acc :  57.87448386351267
# Train Loss :  0.60309833
# Val Acc :  60.10802388191223
# Val Loss :  0.5955705
# ---------------------------------------------
#
#
#  Epoch: 82/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[6300 6260]
#  [2711 6512]]
#
#  Validation - Confusion Matrix:
# [[653 868]
#  [280 791]]
#
# Train Acc :  58.49921007951101
# Train Loss :  0.60699487
# Val Acc :  55.709874629974365
# Val Loss :  0.6193439
# ---------------------------------------------
#
#
#  Epoch: 83/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[5757 6803]
#  [2431 6792]]
#
#  Validation - Confusion Matrix:
# [[897 624]
#  [376 695]]
#
# Train Acc :  57.690719763437905
# Train Loss :  0.60515404
# Val Acc :  61.41975522041321
# Val Loss :  0.6106714
# ---------------------------------------------
#
#
#  Epoch: 84/20000 	LR: [0.001] 	Dur: 8.36 sec
#
#  Training - Confusion Matrix:
# [[6756 5804]
#  [2908 6315]]
#
#  Validation - Confusion Matrix:
# [[678 843]
#  [284 787]]
#
# Train Acc :  59.29142435391744
# Train Loss :  0.6064856
# Val Acc :  56.52006268501282
# Val Loss :  0.6228468
# ---------------------------------------------
#
#
#  Epoch: 85/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[5880 6680]
#  [2475 6748]]
#
#  Validation - Confusion Matrix:
# [[847 674]
#  [335 736]]
#
# Train Acc :  58.02961587905884
# Train Loss :  0.60300213
# Val Acc :  61.07252836227417
# Val Loss :  0.5999319
# ---------------------------------------------
#
#
#  Epoch: 86/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[6083 6477]
#  [2520 6703]]
#
#  Validation - Confusion Matrix:
# [[812 709]
#  [345 726]]
#
# Train Acc :  58.75101685523987
# Train Loss :  0.60176194
# Val Acc :  59.33641791343689
# Val Loss :  0.5934489
# ---------------------------------------------
#
#
#  Epoch: 87/20000 	LR: [0.001] 	Dur: 8.37 sec
#
#  Training - Confusion Matrix:
# [[6162 6398]
#  [2618 6605]]
#
#  Validation - Confusion Matrix:
# [[847 674]
#  [362 709]]
#
# Train Acc :  58.48182241121928
# Train Loss :  0.6038089
# Val Acc :  60.03086566925049
# Val Loss :  0.60501665
# ---------------------------------------------
#
#
#  Epoch: 88/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[5818 6742]
#  [2538 6685]]
#
#  Validation - Confusion Matrix:
# [[862 659]
#  [364 707]]
#
# Train Acc :  57.27677345275879
# Train Loss :  0.60675436
# Val Acc :  60.53240895271301
# Val Loss :  0.614272
# ---------------------------------------------
#
#
#  Epoch: 89/20000 	LR: [0.001] 	Dur: 8.35 sec
#
#  Training - Confusion Matrix:
# [[6545 6015]
#  [2852 6371]]
#
#  Validation - Confusion Matrix:
# [[851 670]
#  [351 720]]
#
# Train Acc :  59.24510061740875
# Train Loss :  0.60699946
# Val Acc :  60.609567165374756
# Val Loss :  0.6122051
# ---------------------------------------------
#
#
#  Epoch: 90/20000 	LR: [0.001] 	Dur: 8.35 sec
#
#  Training - Confusion Matrix:
# [[6108 6452]
#  [2588 6635]]
#
#  Validation - Confusion Matrix:
# [[846 675]
#  [334 737]]
#
# Train Acc :  58.45394233862559
# Train Loss :  0.60559493
# Val Acc :  61.07252836227417
# Val Loss :  0.6052367
# ---------------------------------------------
#
#
#  Epoch: 91/20000 	LR: [0.001] 	Dur: 8.44 sec
#
#  Training - Confusion Matrix:
# [[5209 7351]
#  [2175 7048]]
#
#  Validation - Confusion Matrix:
# [[942 579]
#  [390 681]]
#
# Train Acc :  56.546178460121155
# Train Loss :  0.6036748
# Val Acc :  62.61574029922485
# Val Loss :  0.594847
# ---------------------------------------------
#
#
#  Epoch: 92/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[6553 6007]
#  [2868 6355]]
#
#  Validation - Confusion Matrix:
# [[632 889]
#  [270 801]]
#
# Train Acc :  58.81133675575256
# Train Loss :  0.6050512
# Val Acc :  55.28549551963806
# Val Loss :  0.6044971
# ---------------------------------------------
#
#
#  Epoch: 93/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[5193 7367]
#  [2221 7002]]
#
#  Validation - Confusion Matrix:
# [[1006  515]
#  [ 437  634]]
#
# Train Acc :  56.11073871453603
# Train Loss :  0.60820216
# Val Acc :  63.27160596847534
# Val Loss :  0.6189815
# ---------------------------------------------
#
#
#  Epoch: 94/20000 	LR: [0.001] 	Dur: 8.43 sec
#
#  Training - Confusion Matrix:
# [[6694 5866]
#  [2996 6227]]
#
#  Validation - Confusion Matrix:
# [[583 938]
#  [231 840]]
#
# Train Acc :  58.83806844552358
# Train Loss :  0.6080579
# Val Acc :  54.89969253540039
# Val Loss :  0.60704774
# ---------------------------------------------
#
#
#  Epoch: 95/20000 	LR: [0.001] 	Dur: 8.35 sec
#
#  Training - Confusion Matrix:
# [[5488 7072]
#  [2497 6726]]
#
#  Validation - Confusion Matrix:
# [[850 671]
#  [368 703]]
#
# Train Acc :  56.07466399669647
# Train Loss :  0.6080705
# Val Acc :  59.915125370025635
# Val Loss :  0.6105077
# ---------------------------------------------
#
#
#  Epoch: 96/20000 	LR: [0.001] 	Dur: 8.37 sec
#
#  Training - Confusion Matrix:
# [[5790 6770]
#  [2603 6620]]
#
#  Validation - Confusion Matrix:
# [[788 733]
#  [325 746]]
#
# Train Acc :  56.47970040639242
# Train Loss :  0.6101308
# Val Acc :  59.1821014881134
# Val Loss :  0.6182814
# ---------------------------------------------
#
#
#  Epoch: 97/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[6263 6297]
#  [2851 6372]]
#
#  Validation - Confusion Matrix:
# [[724 797]
#  [317 754]]
#
# Train Acc :  57.8836590051651
# Train Loss :  0.6093119
# Val Acc :  57.02160596847534
# Val Loss :  0.6024119
# ---------------------------------------------
#
#
#  Epoch: 98/20000 	LR: [0.001] 	Dur: 8.41 sec
#
#  Training - Confusion Matrix:
# [[5599 6961]
#  [2551 6672]]
#
#  Validation - Confusion Matrix:
# [[775 746]
#  [361 710]]
#
# Train Acc :  56.62931104501089
# Train Loss :  0.6102526
# Val Acc :  57.29166865348816
# Val Loss :  0.6043305
# ---------------------------------------------
#
#
#  Epoch: 99/20000 	LR: [0.001] 	Dur: 8.36 sec
#
#  Training - Confusion Matrix:
# [[6197 6363]
#  [2830 6393]]
#
#  Validation - Confusion Matrix:
# [[752 769]
#  [304 767]]
#
# Train Acc :  57.430171966552734
# Train Loss :  0.60971045
# Val Acc :  58.60339403152466
# Val Loss :  0.60810435
# ---------------------------------------------
#
#
#  Epoch: 100/20000 	LR: [0.001] 	Dur: 8.43 sec
#
#  Training - Confusion Matrix:
# [[5578 6982]
#  [2571 6652]]
#
#  Validation - Confusion Matrix:
# [[852 669]
#  [383 688]]
#
# Train Acc :  56.36653999487559
# Train Loss :  0.6115804
# Val Acc :  59.41358208656311
# Val Loss :  0.60848176
# ---------------------------------------------
#
#
#  Epoch: 101/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[6238 6322]
#  [2863 6360]]
#
#  Validation - Confusion Matrix:
# [[650 871]
#  [266 805]]
#
# Train Acc :  57.63716399669647
# Train Loss :  0.6102168
# Val Acc :  56.13425970077515
# Val Loss :  0.61140007
# ---------------------------------------------
#
#
#  Epoch: 102/20000 	LR: [0.001] 	Dur: 8.36 sec
#
#  Training - Confusion Matrix:
# [[5716 6844]
#  [2598 6625]]
#
#  Validation - Confusion Matrix:
# [[833 688]
#  [360 711]]
#
# Train Acc :  56.696092089017235
# Train Loss :  0.61240494
# Val Acc :  59.567904472351074
# Val Loss :  0.62093276
# ---------------------------------------------
#
#
#  Epoch: 103/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[5439 7121]
#  [2493 6730]]
#
#  Validation - Confusion Matrix:
# [[675 846]
#  [298 773]]
#
# Train Acc :  55.4729034503301
# Train Loss :  0.6117889
# Val Acc :  55.86419701576233
# Val Loss :  0.62575114
# ---------------------------------------------
#
#
#  Epoch: 104/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[5878 6682]
#  [2735 6488]]
#
#  Validation - Confusion Matrix:
# [[732 789]
#  [322 749]]
#
# Train Acc :  56.998422741889954
# Train Loss :  0.6124796
# Val Acc :  57.137346267700195
# Val Loss :  0.61004883
# ---------------------------------------------
#
#
#  Epoch: 105/20000 	LR: [0.001] 	Dur: 8.37 sec
#
#  Training - Confusion Matrix:
# [[5329 7231]
#  [2462 6761]]
#
#  Validation - Confusion Matrix:
# [[700 821]
#  [304 767]]
#
# Train Acc :  55.59627215067545
# Train Loss :  0.61314005
# Val Acc :  56.59722089767456
# Val Loss :  0.60942036
# ---------------------------------------------
#
#
#  Epoch: 106/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[6124 6436]
#  [2863 6360]]
#
#  Validation - Confusion Matrix:
# [[609 912]
#  [260 811]]
#
# Train Acc :  57.25179413954417
# Train Loss :  0.61268014
# Val Acc :  54.78395223617554
# Val Loss :  0.61073923
# ---------------------------------------------
#
#
#  Epoch: 107/20000 	LR: [0.001] 	Dur: 8.36 sec
#
#  Training - Confusion Matrix:
# [[5209 7351]
#  [2413 6810]]
#
#  Validation - Confusion Matrix:
# [[859 662]
#  [381 690]]
#
# Train Acc :  55.621363719304405
# Train Loss :  0.6119514
# Val Acc :  59.76080298423767
# Val Loss :  0.6097363
# ---------------------------------------------
#
#
#  Epoch: 108/20000 	LR: [0.001] 	Dur: 8.35 sec
#
#  Training - Confusion Matrix:
# [[5617 6943]
#  [2586 6637]]
#
#  Validation - Confusion Matrix:
# [[706 815]
#  [288 783]]
#
# Train Acc :  55.99320828914642
# Train Loss :  0.61198586
# Val Acc :  57.44599103927612
# Val Loss :  0.61844766
# ---------------------------------------------
#
#
#  Epoch: 109/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[6356 6204]
#  [2886 6337]]
#
#  Validation - Confusion Matrix:
# [[581 940]
#  [241 830]]
#
# Train Acc :  57.962665955225624
# Train Loss :  0.6105605
# Val Acc :  54.43673133850098
# Val Loss :  0.61963296
# ---------------------------------------------
#
#
#  Epoch: 110/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[4082 8478]
#  [1842 7381]]
#
#  Validation - Confusion Matrix:
# [[872 649]
#  [367 704]]
#
# Train Acc :  53.17583282788595
# Train Loss :  0.6104979
# Val Acc :  60.80247163772583
# Val Loss :  0.6106036
# ---------------------------------------------
#
#
#  Epoch: 111/20000 	LR: [0.001] 	Dur: 8.37 sec
#
#  Training - Confusion Matrix:
# [[6192 6368]
#  [2741 6482]]
#
#  Validation - Confusion Matrix:
# [[614 907]
#  [258 813]]
#
# Train Acc :  57.684749364852905
# Train Loss :  0.6089408
# Val Acc :  55.054014921188354
# Val Loss :  0.60795146
# ---------------------------------------------
#
#
#  Epoch: 112/20000 	LR: [0.001] 	Dur: 8.43 sec
#
#  Training - Confusion Matrix:
# [[5188 7372]
#  [2256 6967]]
#
#  Validation - Confusion Matrix:
# [[932 589]
#  [398 673]]
#
# Train Acc :  56.253247459729515
# Train Loss :  0.6061929
# Val Acc :  61.92129850387573
# Val Loss :  0.5924079
# ---------------------------------------------
#
#
#  Epoch: 113/20000 	LR: [0.001] 	Dur: 8.35 sec
#
#  Training - Confusion Matrix:
# [[5921 6639]
#  [2650 6573]]
#
#  Validation - Confusion Matrix:
# [[674 847]
#  [266 805]]
#
# Train Acc :  57.231430212656655
# Train Loss :  0.607552
# Val Acc :  57.06018805503845
# Val Loss :  0.610024
# ---------------------------------------------
#
#
#  Epoch: 114/20000 	LR: [0.001] 	Dur: 8.37 sec
#
#  Training - Confusion Matrix:
# [[5960 6600]
#  [2699 6524]]
#
#  Validation - Confusion Matrix:
# [[790 731]
#  [338 733]]
#
# Train Acc :  57.38262434800466
# Train Loss :  0.608608
# Val Acc :  58.75771641731262
# Val Loss :  0.61812186
# ---------------------------------------------
#
#
#  Epoch: 115/20000 	LR: [0.001] 	Dur: 8.41 sec
#
#  Training - Confusion Matrix:
# [[5154 7406]
#  [2266 6957]]
#
#  Validation - Confusion Matrix:
# [[920 601]
#  [398 673]]
#
# Train Acc :  55.96954723199209
# Train Loss :  0.609459
# Val Acc :  61.45833134651184
# Val Loss :  0.6088489
# ---------------------------------------------
#
#
#  Epoch: 116/20000 	LR: [0.001] 	Dur: 8.41 sec
#
#  Training - Confusion Matrix:
# [[7052 5508]
#  [3295 5928]]
#
#  Validation - Confusion Matrix:
# [[604 917]
#  [231 840]]
#
# Train Acc :  59.331077337265015
# Train Loss :  0.6089253
# Val Acc :  55.709874629974365
# Val Loss :  0.6010512
# ---------------------------------------------
#
#
#  Epoch: 117/20000 	LR: [0.001] 	Dur: 8.44 sec
#
#  Training - Confusion Matrix:
# [[5423 7137]
#  [2459 6764]]
#
#  Validation - Confusion Matrix:
# [[954 567]
#  [416 655]]
#
# Train Acc :  56.505563855171204
# Train Loss :  0.60937846
# Val Acc :  62.07561492919922
# Val Loss :  0.602567
# ---------------------------------------------
#
#
#  Epoch: 118/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[6541 6019]
#  [2996 6227]]
#
#  Validation - Confusion Matrix:
# [[577 944]
#  [235 836]]
#
# Train Acc :  57.84918665885925
# Train Loss :  0.6075042
# Val Acc :  54.51388955116272
# Val Loss :  0.59387934
# ---------------------------------------------
#
#
#  Epoch: 119/20000 	LR: [0.001] 	Dur: 8.36 sec
#
#  Training - Confusion Matrix:
# [[5884 6676]
#  [2646 6577]]
#
#  Validation - Confusion Matrix:
# [[789 732]
#  [310 761]]
#
# Train Acc :  57.55069653193156
# Train Loss :  0.60512704
# Val Acc :  59.79938507080078
# Val Loss :  0.5849873
# ---------------------------------------------
#
#
#  Epoch: 120/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[4510 8050]
#  [1971 7252]]
#
#  Validation - Confusion Matrix:
# [[926 595]
#  [393 678]]
#
# Train Acc :  54.20930484930674
# Train Loss :  0.6064186
# Val Acc :  61.88271641731262
# Val Loss :  0.59148604
# ---------------------------------------------
#
#
#  Epoch: 121/20000 	LR: [0.001] 	Dur: 8.41 sec
#
#  Training - Confusion Matrix:
# [[6881 5679]
#  [2959 6264]]
#
#  Validation - Confusion Matrix:
# [[709 812]
#  [277 794]]
#
# Train Acc :  59.793136517206825
# Train Loss :  0.606051
# Val Acc :  57.98611044883728
# Val Loss :  0.609419
# ---------------------------------------------
#
#
#  Epoch: 122/20000 	LR: [0.001] 	Dur: 8.33 sec
#
#  Training - Confusion Matrix:
# [[5048 7512]
#  [2145 7078]]
#
#  Validation - Confusion Matrix:
# [[943 578]
#  [404 667]]
#
# Train Acc :  55.812532703081764
# Train Loss :  0.60500604
# Val Acc :  62.11419701576233
# Val Loss :  0.6011584
# ---------------------------------------------
#
#
#  Epoch: 123/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[5618 6942]
#  [2396 6827]]
#
#  Validation - Confusion Matrix:
# [[931 590]
#  [398 673]]
#
# Train Acc :  57.40709404150645
# Train Loss :  0.60265654
# Val Acc :  61.88271641731262
# Val Loss :  0.59615433
# ---------------------------------------------
#
#
#  Epoch: 124/20000 	LR: [0.001] 	Dur: 8.40 sec
#  --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : 60.83%
#
#  Training - Confusion Matrix:
# [[6154 6406]
#  [2658 6565]]
#
#  Validation - Confusion Matrix:
# [[947 574]
#  [384 687]]
#
# Train Acc :  58.62666666507721
# Train Loss :  0.60386443
# Val Acc :  63.040125370025635
# Val Loss :  0.6013844
# ---------------------------------------------
#
#
#  Epoch: 125/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[5835 6725]
#  [2547 6676]]
#
#  Validation - Confusion Matrix:
# [[879 642]
#  [372 699]]
#
# Train Acc :  57.3703795671463
# Train Loss :  0.6054236
# Val Acc :  60.87962985038757
# Val Loss :  0.604937
# ---------------------------------------------
#
#
#  Epoch: 126/20000 	LR: [0.001] 	Dur: 8.35 sec
#
#  Training - Confusion Matrix:
# [[5811 6749]
#  [2538 6685]]
#
#  Validation - Confusion Matrix:
# [[1010  511]
#  [ 427  644]]
#
# Train Acc :  57.78033137321472
# Train Loss :  0.60226375
# Val Acc :  63.81173133850098
# Val Loss :  0.588989
# ---------------------------------------------
#
#
#  Epoch: 127/20000 	LR: [0.001] 	Dur: 8.37 sec
#  --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : 61.09%
#
#  Training - Confusion Matrix:
# [[6299 6261]
#  [2775 6448]]
#
#  Validation - Confusion Matrix:
# [[964 557]
#  [376 695]]
#
# Train Acc :  58.182392517725624
# Train Loss :  0.6049666
# Val Acc :  64.00462985038757
# Val Loss :  0.59995466
# ---------------------------------------------
#
#
#  Epoch: 128/20000 	LR: [0.001] 	Dur: 8.41 sec
#  --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : 61.17%
#
#  Training - Confusion Matrix:
# [[6463 6097]
#  [2846 6377]]
#
#  Validation - Confusion Matrix:
# [[959 562]
#  [390 681]]
#
# Train Acc :  59.06668504079183
# Train Loss :  0.60428363
# Val Acc :  63.27160596847534
# Val Loss :  0.59621805
# ---------------------------------------------
#
#
#  Epoch: 129/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[5804 6756]
#  [2491 6732]]
#
#  Validation - Confusion Matrix:
# [[1023  498]
#  [ 438  633]]
#
# Train Acc :  57.77737398942312
# Train Loss :  0.60242933
# Val Acc :  63.88888955116272
# Val Loss :  0.5919784
# ---------------------------------------------
#
#
#  Epoch: 130/20000 	LR: [0.001] 	Dur: 8.43 sec
#
#  Training - Confusion Matrix:
# [[6830 5730]
#  [2992 6231]]
#
#  Validation - Confusion Matrix:
# [[777 744]
#  [307 764]]
#
# Train Acc :  59.451339642206825
# Train Loss :  0.6057095
# Val Acc :  59.45215821266174
# Val Loss :  0.61313784
# ---------------------------------------------
#
#
#  Epoch: 131/20000 	LR: [0.001] 	Dur: 8.40 sec
#
#  Training - Confusion Matrix:
# [[5361 7199]
#  [2314 6909]]
#
#  Validation - Confusion Matrix:
# [[1002  519]
#  [ 420  651]]
#
# Train Acc :  56.886901458104454
# Train Loss :  0.60413617
# Val Acc :  63.773149251937866
# Val Loss :  0.59889823
# ---------------------------------------------
#
#
#  Epoch: 132/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[6220 6340]
#  [2752 6471]]
#
#  Validation - Confusion Matrix:
# [[874 647]
#  [347 724]]
#
# Train Acc :  58.111523588498436
# Train Loss :  0.60446376
# Val Acc :  61.651235818862915
# Val Loss :  0.5986975
# ---------------------------------------------
#
#
#  Epoch: 133/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[6110 6450]
#  [2738 6485]]
#
#  Validation - Confusion Matrix:
# [[920 601]
#  [379 692]]
#
# Train Acc :  57.82556235790253
# Train Loss :  0.6065363
# Val Acc :  62.19136118888855
# Val Loss :  0.61409473
# ---------------------------------------------
#
#
#  Epoch: 134/20000 	LR: [0.001] 	Dur: 8.43 sec
#
#  Training - Confusion Matrix:
# [[6269 6291]
#  [2767 6456]]
#
#  Validation - Confusion Matrix:
# [[877 644]
#  [345 726]]
#
# Train Acc :  58.2760363817215
# Train Loss :  0.60481066
# Val Acc :  61.84413433074951
# Val Loss :  0.6097592
# ---------------------------------------------
#
#
#  Epoch: 135/20000 	LR: [0.001] 	Dur: 8.38 sec
#
#  Training - Confusion Matrix:
# [[6004 6556]
#  [2695 6528]]
#
#  Validation - Confusion Matrix:
# [[961 560]
#  [383 688]]
#
# Train Acc :  57.71748820940653
# Train Loss :  0.6039553
# Val Acc :  63.6188268661499
# Val Loss :  0.5915582
# ---------------------------------------------
#
#
#  Epoch: 136/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[6529 6031]
#  [2907 6316]]
#
#  Validation - Confusion Matrix:
# [[839 682]
#  [360 711]]
#
# Train Acc :  58.816649516423546
# Train Loss :  0.6065183
# Val Acc :  59.79938507080078
# Val Loss :  0.6118065
# ---------------------------------------------
#
#
#  Epoch: 137/20000 	LR: [0.001] 	Dur: 8.39 sec
#
#  Training - Confusion Matrix:
# [[5722 6838]
#  [2503 6720]]
#
#  Validation - Confusion Matrix:
# [[912 609]
#  [355 716]]
#
# Train Acc :  57.39488701025645
# Train Loss :  0.6063964
# Val Acc :  62.80864477157593
# Val Loss :  0.6151155
# ---------------------------------------------
#
#
#  Epoch: 138/20000 	LR: [0.001] 	Dur: 8.55 sec
#
#  Training - Confusion Matrix:
# [[6032 6528]
#  [2664 6559]]
#
#  Validation - Confusion Matrix:
# [[813 708]
#  [333 738]]
#
# Train Acc :  57.55634903907776
# Train Loss :  0.605541
# Val Acc :  59.837961196899414
# Val Loss :  0.61060035
# ---------------------------------------------
#
#
#  Epoch: 139/20000 	LR: [0.001] 	Dur: 8.41 sec
#
#  Training - Confusion Matrix:
# [[5399 7161]
#  [2463 6760]]
#
#  Validation - Confusion Matrix:
# [[1063  458]
#  [ 470  601]]
#
# Train Acc :  56.30441109339396
# Train Loss :  0.6064125
# Val Acc :  64.19752836227417
# Val Loss :  0.61110914
# ---------------------------------------------
#
#
#  Epoch: 140/20000 	LR: [0.001] 	Dur: 8.53 sec
#
#  Training - Confusion Matrix:
# [[6276 6284]
#  [2932 6291]]
#
#  Validation - Confusion Matrix:
# [[799 722]
#  [329 742]]
#
# Train Acc :  57.24936525026957
# Train Loss :  0.6063162
# Val Acc :  59.45215821266174
# Val Loss :  0.603483
# ---------------------------------------------
#
#
#  Epoch: 141/20000 	LR: [0.001] 	Dur: 8.51 sec
#
#  Training - Confusion Matrix:
# [[6191 6369]
#  [2777 6446]]
#
#  Validation - Confusion Matrix:
# [[976 545]
#  [423 648]]
#
# Train Acc :  58.11856885751089
# Train Loss :  0.6022055
# Val Acc :  62.654322385787964
# Val Loss :  0.5876671
# ---------------------------------------------
#
#
#  Epoch: 142/20000 	LR: [0.001] 	Dur: 8.47 sec
#
#  Training - Confusion Matrix:
# [[6114 6446]
#  [2740 6483]]
#
#  Validation - Confusion Matrix:
# [[833 688]
#  [344 727]]
#
# Train Acc :  57.51970907052358
# Train Loss :  0.6048556
# Val Acc :  60.18518805503845
# Val Loss :  0.60995513
# ---------------------------------------------
#
#
#  Epoch: 143/20000 	LR: [0.001] 	Dur: 8.51 sec
#
#  Training - Confusion Matrix:
# [[6297 6263]
#  [2869 6354]]
#
#  Validation - Confusion Matrix:
# [[791 730]
#  [351 720]]
#
# Train Acc :  58.1319252649943
# Train Loss :  0.60432297
# Val Acc :  58.29475522041321
# Val Loss :  0.60515034
# ---------------------------------------------
#
#
#  Epoch: 144/20000 	LR: [0.001] 	Dur: 8.53 sec
#
#  Training - Confusion Matrix:
# [[4569 7991]
#  [1923 7300]]
#
#  Validation - Confusion Matrix:
# [[1110  411]
#  [ 492  579]]
#
# Train Acc :  55.168007810910545
# Train Loss :  0.6015926
# Val Acc :  65.16203880310059
# Val Loss :  0.5889064
# ---------------------------------------------
#
#
#  Epoch: 145/20000 	LR: [0.001] 	Dur: 8.49 sec
#
#  Training - Confusion Matrix:
# [[6120 6440]
#  [2760 6463]]
#
#  Validation - Confusion Matrix:
# [[878 643]
#  [361 710]]
#
# Train Acc :  57.706958055496216
# Train Loss :  0.6011166
# Val Acc :  61.265432834625244
# Val Loss :  0.58305067
# ---------------------------------------------
#
#
#  Epoch: 146/20000 	LR: [0.001] 	Dur: 8.52 sec
#
#  Training - Confusion Matrix:
# [[6754 5806]
#  [2998 6225]]
#
#  Validation - Confusion Matrix:
# [[902 619]
#  [365 706]]
#
# Train Acc :  59.66716607411703
# Train Loss :  0.60080236
# Val Acc :  62.037038803100586
# Val Loss :  0.5907062
# ---------------------------------------------
#
#
#  Epoch: 147/20000 	LR: [0.001] 	Dur: 8.46 sec
#
#  Training - Confusion Matrix:
# [[5726 6834]
#  [2431 6792]]
#
#  Validation - Confusion Matrix:
# [[993 528]
#  [433 638]]
#
# Train Acc :  57.381418347358704
# Train Loss :  0.602305
# Val Acc :  62.92438507080078
# Val Loss :  0.61016345
# ---------------------------------------------
#
#
# ...
#
#  Training - Confusion Matrix:
# [[11011  1549]
#  [  568  8655]]
#
#  Validation - Confusion Matrix:
# [[891 630]
#  [ 72 999]]
#
# Train Acc :  90.06888469060263
# Train Loss :  0.22020279
# Val Acc :  72.91666865348816
# Val Loss :  0.24842307
# ---------------------------------------------
#
#
#  Epoch: 904/20000 	LR: [0.0002] 	Dur: 9.94 sec
#
#  Training - Confusion Matrix:
# [[10963  1597]
#  [  575  8648]]
#
#  Validation - Confusion Matrix:
# [[910 611]
#  [ 73 998]]
#
# Train Acc :  90.01952906449637
# Train Loss :  0.22156483
# Val Acc :  73.61111044883728
# Val Loss :  0.2190392
# ---------------------------------------------
#
#
#  Epoch: 905/20000 	LR: [0.0002] 	Dur: 9.94 sec
#
#  Training - Confusion Matrix:
# [[10907  1653]
#  [  545  8678]]
#
#  Validation - Confusion Matrix:
# [[931 590]
#  [ 72 999]]
#
# Train Acc :  89.93990023930868
# Train Loss :  0.21206163
# Val Acc :  74.45987462997437
# Val Loss :  0.19367278
# ---------------------------------------------
#
#
#  Epoch: 906/20000 	LR: [0.0002] 	Dur: 10.04 sec
#
#  Training - Confusion Matrix:
# [[11016  1544]
#  [  592  8631]]
#
#  Validation - Confusion Matrix:
# [[ 884  637]
#  [  63 1008]]
#
# Train Acc :  90.02646108468375
# Train Loss :  0.2183178
# Val Acc :  72.9938268661499
# Val Loss :  0.22756778
# ---------------------------------------------
#
#
#  Epoch: 907/20000 	LR: [0.0002] 	Dur: 9.69 sec
#
#  Training - Confusion Matrix:
# [[10968  1592]
#  [  567  8656]]
#
#  Validation - Confusion Matrix:
# [[918 603]
#  [ 81 990]]
#
# Train Acc :  90.15092353026071
# Train Loss :  0.21564789
# Val Acc :  73.61111044883728
# Val Loss :  0.20117334
# ---------------------------------------------
#
#
#  Epoch: 908/20000 	LR: [0.0002] 	Dur: 9.61 sec
#
#  Training - Confusion Matrix:
# [[11011  1549]
#  [  556  8667]]
#
#  Validation - Confusion Matrix:
# [[901 620]
#  [ 75 996]]
#
# Train Acc :  90.40553867816925
# Train Loss :  0.21362527
# Val Acc :  73.18673133850098
# Val Loss :  0.2115028
# ---------------------------------------------
#
#
#  Epoch: 909/20000 	LR: [0.0002] 	Dur: 9.62 sec
#
#  Training - Confusion Matrix:
# [[10906  1654]
#  [  540  8683]]
#
#  Validation - Confusion Matrix:
# [[917 604]
#  [ 73 998]]
#
# Train Acc :  89.96489842732748
# Train Loss :  0.22023974
# Val Acc :  73.8811731338501
# Val Loss :  0.24226646
# ---------------------------------------------
#
#
#  Epoch: 910/20000 	LR: [0.0002] 	Dur: 9.74 sec
#
#  Training - Confusion Matrix:
# [[10939  1621]
#  [  558  8665]]
#
#  Validation - Confusion Matrix:
# [[916 605]
#  [ 72 999]]
#
# Train Acc :  89.90382552146912
# Train Loss :  0.21952163
# Val Acc :  73.8811731338501
# Val Loss :  0.23125045
# ---------------------------------------------
#
#
#  Epoch: 911/20000 	LR: [0.0002] 	Dur: 9.56 sec
#
#  Training - Confusion Matrix:
# [[11016  1544]
#  [  591  8632]]
#
#  Validation - Confusion Matrix:
# [[918 603]
#  [ 75 996]]
#
# Train Acc :  90.09158412615457
# Train Loss :  0.21723296
# Val Acc :  73.84259104728699
# Val Loss :  0.23362467
# ---------------------------------------------
#
#
#  Epoch: 912/20000 	LR: [0.0002] 	Dur: 9.84 sec
#
#  Training - Confusion Matrix:
# [[10980  1580]
#  [  547  8676]]
#
#  Validation - Confusion Matrix:
# [[934 587]
#  [ 89 982]]
#
# Train Acc :  90.2898540099462
# Train Loss :  0.21023758
# Val Acc :  73.91975522041321
# Val Loss :  0.19409102
# ---------------------------------------------
#
#
#  Epoch: 913/20000 	LR: [0.0002] 	Dur: 9.82 sec
#
#  Training - Confusion Matrix:
# [[11021  1539]
#  [  537  8686]]
#
#  Validation - Confusion Matrix:
# [[907 614]
#  [ 82 989]]
#
# Train Acc :  90.41015406449637
# Train Loss :  0.20960869
# Val Acc :  73.14814925193787
# Val Loss :  0.21219741
# ---------------------------------------------
#
#
#  Epoch: 914/20000 	LR: [0.0002] 	Dur: 9.56 sec
#
#  Training - Confusion Matrix:
# [[10940  1620]
#  [  565  8658]]
#
#  Validation - Confusion Matrix:
# [[905 616]
#  [ 84 987]]
#
# Train Acc :  89.89685575167337
# Train Loss :  0.21836436
# Val Acc :  72.9938268661499
# Val Loss :  0.22587435
# ---------------------------------------------
#
#
#  Epoch: 915/20000 	LR: [0.0002] 	Dur: 9.52 sec
#
#  Training - Confusion Matrix:
# [[10918  1642]
#  [  538  8685]]
#
#  Validation - Confusion Matrix:
# [[938 583]
#  [ 89 982]]
#
# Train Acc :  90.10908504327139
# Train Loss :  0.2137484
# Val Acc :  74.07407760620117
# Val Loss :  0.18947728
# ---------------------------------------------
#
#
#  Epoch: 916/20000 	LR: [0.0002] 	Dur: 9.59 sec
#
#  Training - Confusion Matrix:
# [[11047  1513]
#  [  566  8657]]
#
#  Validation - Confusion Matrix:
# [[928 593]
#  [ 82 989]]
#
# Train Acc :  90.40666917959848
# Train Loss :  0.21300717
# Val Acc :  73.95833134651184
# Val Loss :  0.21899895
# ---------------------------------------------
#
#
#  Epoch: 917/20000 	LR: [0.0002] 	Dur: 9.59 sec
#
#  Training - Confusion Matrix:
# [[11046  1514]
#  [  596  8627]]
#
#  Validation - Confusion Matrix:
# [[910 611]
#  [ 81 990]]
#
# Train Acc :  90.33286174138388
# Train Loss :  0.21234924
# Val Acc :  73.30247163772583
# Val Loss :  0.20423897
# ---------------------------------------------
#
#
#  Epoch: 918/20000 	LR: [0.0002] 	Dur: 9.57 sec
#
#  Training - Confusion Matrix:
# [[10944  1616]
#  [  557  8666]]
#
#  Validation - Confusion Matrix:
# [[928 593]
#  [ 81 990]]
#
# Train Acc :  89.9107962846756
# Train Loss :  0.2191801
# Val Acc :  73.99691343307495
# Val Loss :  0.2377597
# ---------------------------------------------
#
#
#  Epoch: 919/20000 	LR: [0.0002] 	Dur: 9.38 sec
#
#  Training - Confusion Matrix:
# [[10945  1615]
#  [  543  8680]]
#
#  Validation - Confusion Matrix:
# [[939 582]
#  [ 81 990]]
#
# Train Acc :  90.26837845643362
# Train Loss :  0.2150942
# Val Acc :  74.42129850387573
# Val Loss :  0.21706429
# ---------------------------------------------
#
#
#  Epoch: 920/20000 	LR: [0.0002] 	Dur: 9.49 sec
#
#  Training - Confusion Matrix:
# [[10985  1575]
#  [  580  8643]]
#
#  Validation - Confusion Matrix:
# [[946 575]
#  [ 82 989]]
#
# Train Acc :  90.158478418986
# Train Loss :  0.21036942
# Val Acc :  74.65277910232544
# Val Loss :  0.19517605
# ---------------------------------------------
#
#
#  Epoch: 921/20000 	LR: [0.0002] 	Dur: 9.48 sec
#
#  Training - Confusion Matrix:
# [[11006  1554]
#  [  559  8664]]
#
#  Validation - Confusion Matrix:
# [[911 610]
#  [ 73 998]]
#
# Train Acc :  90.22471308708191
# Train Loss :  0.21412088
# Val Acc :  73.64969253540039
# Val Loss :  0.20690243
# ---------------------------------------------
#
#
#  Epoch: 922/20000 	LR: [0.0002] 	Dur: 9.62 sec
#
#  Training - Confusion Matrix:
# [[11019  1541]
#  [  549  8674]]
#
#  Validation - Confusion Matrix:
# [[924 597]
#  [ 74 997]]
#
# Train Acc :  90.45785168806711
# Train Loss :  0.21407147
# Val Acc :  74.1126537322998
# Val Loss :  0.21117502
# ---------------------------------------------
#
#
#  Epoch: 923/20000 	LR: [0.0002] 	Dur: 9.73 sec
#
#  Training - Confusion Matrix:
# [[10891  1669]
#  [  509  8714]]
#
#  Validation - Confusion Matrix:
# [[960 561]
#  [ 90 981]]
#
# Train Acc :  90.09977877140045
# Train Loss :  0.21664178
# Val Acc :  74.88425970077515
# Val Loss :  0.22448188
# ---------------------------------------------
#
#
#  Epoch: 924/20000 	LR: [0.0002] 	Dur: 9.69 sec
#
#  Training - Confusion Matrix:
# [[10963  1597]
#  [  521  8702]]
#
#  Validation - Confusion Matrix:
# [[973 548]
#  [103 968]]
#
# Train Acc :  90.37008484204611
# Train Loss :  0.21048386
# Val Acc :  74.88425970077515
# Val Loss :  0.20496452
# ---------------------------------------------
#
#
#  Epoch: 925/20000 	LR: [0.0002] 	Dur: 9.86 sec
#
#  Training - Confusion Matrix:
# [[11080  1480]
#  [  588  8635]]
#
#  Validation - Confusion Matrix:
# [[912 609]
#  [ 76 995]]
#
# Train Acc :  90.40781855583191
# Train Loss :  0.21572636
# Val Acc :  73.57253432273865
# Val Loss :  0.22761472
# ---------------------------------------------
#
#
#  Epoch: 926/20000 	LR: [0.0002] 	Dur: 9.78 sec
#
#  Training - Confusion Matrix:
# [[11041  1519]
#  [  587  8636]]
#
#  Validation - Confusion Matrix:
# [[ 893  628]
#  [  71 1000]]
#
# Train Acc :  90.28808375199637
# Train Loss :  0.21253641
# Val Acc :  73.03240895271301
# Val Loss :  0.21282737
# ---------------------------------------------
#
#
#  Epoch: 927/20000 	LR: [0.0002] 	Dur: 9.36 sec
#
#  Training - Confusion Matrix:
# [[10902  1658]
#  [  553  8670]]
#
#  Validation - Confusion Matrix:
# [[904 617]
#  [ 77 994]]
#
# Train Acc :  89.7648960351944
# Train Loss :  0.2178831
# Val Acc :  73.22530746459961
# Val Loss :  0.20905657
# ---------------------------------------------
#
#
#  Epoch: 928/20000 	LR: [0.0002] 	Dur: 9.37 sec
#
#  Training - Confusion Matrix:
# [[10949  1611]
#  [  517  8706]]
#
#  Validation - Confusion Matrix:
# [[931 590]
#  [ 73 998]]
#
# Train Acc :  90.3032292922338
# Train Loss :  0.212305
# Val Acc :  74.42129850387573
# Val Loss :  0.2094305
# ---------------------------------------------
#
#
#  Epoch: 929/20000 	LR: [0.0002] 	Dur: 9.27 sec
#
#  Training - Confusion Matrix:
# [[10949  1611]
#  [  508  8715]]
#
#  Validation - Confusion Matrix:
# [[931 590]
#  [ 79 992]]
#
# Train Acc :  90.12180070082346
# Train Loss :  0.21260996
# Val Acc :  74.18981790542603
# Val Loss :  0.2337065
# ---------------------------------------------
#
#
#  Epoch: 930/20000 	LR: [0.0002] 	Dur: 9.31 sec
#
#  Training - Confusion Matrix:
# [[10934  1626]
#  [  516  8707]]
#
#  Validation - Confusion Matrix:
# [[948 573]
#  [ 85 986]]
#
# Train Acc :  90.08926749229431
# Train Loss :  0.2158309
# Val Acc :  74.61419701576233
# Val Loss :  0.22352554
# ---------------------------------------------
#
#
#  Epoch: 931/20000 	LR: [0.0002] 	Dur: 9.35 sec
#
#  Training - Confusion Matrix:
# [[11041  1519]
#  [  545  8678]]
#
#  Validation - Confusion Matrix:
# [[906 615]
#  [ 78 993]]
#
# Train Acc :  90.53747951984406
# Train Loss :  0.20981567
# Val Acc :  73.26388955116272
# Val Loss :  0.21610409
# ---------------------------------------------
#
#
#  Epoch: 932/20000 	LR: [0.0002] 	Dur: 9.37 sec
#
#  Training - Confusion Matrix:
# [[10964  1596]
#  [  549  8674]]
#
#  Validation - Confusion Matrix:
# [[929 592]
#  [ 82 989]]
#
# Train Acc :  90.32999773820242
# Train Loss :  0.21027066
# Val Acc :  73.99691343307495
# Val Loss :  0.18790464
# ---------------------------------------------
#
#
#  Epoch: 933/20000 	LR: [0.0002] 	Dur: 9.33 sec
#
#  Training - Confusion Matrix:
# [[11028  1532]
#  [  551  8672]]
#
#  Validation - Confusion Matrix:
# [[948 573]
#  [ 84 987]]
#
# Train Acc :  90.39911528428397
# Train Loss :  0.2116034
# Val Acc :  74.65277910232544
# Val Loss :  0.2055459
# ---------------------------------------------
#
#
#  Epoch: 934/20000 	LR: [0.0002] 	Dur: 9.34 sec
#
#  Training - Confusion Matrix:
# [[10993  1567]
#  [  562  8661]]
#
#  Validation - Confusion Matrix:
# [[931 590]
#  [ 84 987]]
#
# Train Acc :  90.15088677406311
# Train Loss :  0.2157238
# Val Acc :  73.99691343307495
# Val Loss :  0.23051448
# ---------------------------------------------
#
#
#  Epoch: 935/20000 	LR: [0.0002] 	Dur: 9.32 sec
#
#  Training - Confusion Matrix:
# [[10959  1601]
#  [  544  8679]]
#
#  Validation - Confusion Matrix:
# [[918 603]
#  [ 90 981]]
#
# Train Acc :  90.09450475374857
# Train Loss :  0.21466494
# Val Acc :  73.26388955116272
# Val Loss :  0.22434452
# ---------------------------------------------
#
#
#  Epoch: 936/20000 	LR: [0.0002] 	Dur: 9.38 sec
#
#  Training - Confusion Matrix:
# [[11063  1497]
#  [  547  8676]]
#
#  Validation - Confusion Matrix:
# [[943 578]
#  [ 87 984]]
#
# Train Acc :  90.51419595877329
# Train Loss :  0.2105732
# Val Acc :  74.34413433074951
# Val Loss :  0.22591935
# ---------------------------------------------
#
#
#  Epoch: 937/20000 	LR: [0.0002] 	Dur: 9.32 sec
#
#  Training - Confusion Matrix:
# [[11034  1526]
#  [  570  8653]]
#
#  Validation - Confusion Matrix:
# [[937 584]
#  [ 86 985]]
#
# Train Acc :  90.35493930180868
# Train Loss :  0.21197313
# Val Acc :  74.15123581886292
# Val Loss :  0.20830503
# ---------------------------------------------
#
#
#  Epoch: 938/20000 	LR: [0.0002] 	Dur: 9.30 sec
#
#  Training - Confusion Matrix:
# [[11014  1546]
#  [  582  8641]]
#
#  Validation - Confusion Matrix:
# [[916 605]
#  [ 76 995]]
#
# Train Acc :  90.29450714588165
# Train Loss :  0.21600956
# Val Acc :  73.72685074806213
# Val Loss :  0.22158174
# ---------------------------------------------
#
#
#  Epoch: 939/20000 	LR: [0.0002] 	Dur: 9.71 sec
#  --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : 82.97%
#
#  Training - Confusion Matrix:
# [[10865  1695]
#  [  508  8715]]
#
#  Validation - Confusion Matrix:
# [[1004  517]
#  [ 105  966]]
#
# Train Acc :  89.94572162628174
# Train Loss :  0.21813925
# Val Acc :  76.00308656692505
# Val Loss :  0.22906561
# ---------------------------------------------
#
#
#  Epoch: 940/20000 	LR: [0.0002] 	Dur: 9.37 sec
#
#  Training - Confusion Matrix:
# [[10958  1602]
#  [  513  8710]]
#
#  Validation - Confusion Matrix:
# [[955 566]
#  [ 85 986]]
#
# Train Acc :  90.3735707203547
# Train Loss :  0.21074362
# Val Acc :  74.88425970077515
# Val Loss :  0.19715646
# ---------------------------------------------
#
#
#  Epoch: 941/20000 	LR: [0.0002] 	Dur: 9.41 sec
#
#  Training - Confusion Matrix:
# [[11208  1352]
#  [  622  8601]]
#
#  Validation - Confusion Matrix:
# [[ 851  670]
#  [  59 1012]]
#
# Train Acc :  90.79902668793997
# Train Loss :  0.21285073
# Val Acc :  71.875
# Val Loss :  0.21977375
# ---------------------------------------------
#
#
#  Epoch: 942/20000 	LR: [0.0002] 	Dur: 9.62 sec
#
#  Training - Confusion Matrix:
# [[10959  1601]
#  [  548  8675]]
#
#  Validation - Confusion Matrix:
# [[946 575]
#  [ 80 991]]
#
# Train Acc :  90.20033578077951
# Train Loss :  0.2133296
# Val Acc :  74.72993731498718
# Val Loss :  0.20416
# ---------------------------------------------
#
#
#  Epoch: 943/20000 	LR: [0.0002] 	Dur: 9.85 sec
#
#  Training - Confusion Matrix:
# [[10996  1564]
#  [  512  8711]]
#
#  Validation - Confusion Matrix:
# [[949 572]
#  [ 94 977]]
#
# Train Acc :  90.37526647249857
# Train Loss :  0.21090531
# Val Acc :  74.30555820465088
# Val Loss :  0.22600551
# ---------------------------------------------
#
#
#  Epoch: 944/20000 	LR: [0.0002] 	Dur: 9.74 sec
#
#  Training - Confusion Matrix:
# [[10914  1646]
#  [  482  8741]]
#
#  Validation - Confusion Matrix:
# [[972 549]
#  [ 89 982]]
#
# Train Acc :  90.18984337647757
# Train Loss :  0.2127197
# Val Acc :  75.38580298423767
# Val Loss :  0.22679503
# ---------------------------------------------
#
#
#  Epoch: 945/20000 	LR: [0.0002] 	Dur: 9.70 sec
#
#  Training - Confusion Matrix:
# [[11073  1487]
#  [  589  8634]]
#
#  Validation - Confusion Matrix:
# [[ 890  631]
#  [  64 1007]]
#
# Train Acc :  90.288046002388
# Train Loss :  0.21627943
# Val Acc :  73.18673133850098
# Val Loss :  0.2274755
# ---------------------------------------------
#
#
#  Epoch: 946/20000 	LR: [0.0002] 	Dur: 9.62 sec
#  --------------------------------------------------------->  Model Checkpoints Saved with Mean Accuracy : 83.21%
#
#  Training - Confusion Matrix:
# [[10889  1671]
#  [  530  8693]]
#
#  Validation - Confusion Matrix:
# [[1002  519]
#  [  95  976]]
#
# Train Acc :  90.10213315486908
# Train Loss :  0.20904298
# Val Acc :  76.31173133850098
# Val Loss :  0.19139694
# ---------------------------------------------
#
#
#  Epoch: 947/20000 	LR: [0.0002] 	Dur: 9.68 sec
#
#  Training - Confusion Matrix:
# [[10956  1604]
#  [  509  8714]]
#
#  Validation - Confusion Matrix:
# [[948 573]
#  [ 88 983]]
#
# Train Acc :  90.22471308708191
# Train Loss :  0.20951569
# Val Acc :  74.49845671653748
# Val Loss :  0.21022065
# ---------------------------------------------
#
#
#  Epoch: 948/20000 	LR: [0.0002] 	Dur: 9.63 sec
#
#  Training - Confusion Matrix:
# [[11163  1397]
#  [  571  8652]]
#
#  Validation - Confusion Matrix:
# [[880 641]
#  [ 76 995]]
#
# Train Acc :  91.14615420500436
# Train Loss :  0.20496069
# Val Acc :  72.33796119689941
# Val Loss :  0.19241263
# ---------------------------------------------
#
#
#  Epoch: 949/20000 	LR: [0.0002] 	Dur: 9.76 sec
#
#  Training - Confusion Matrix:
# [[10935  1625]
#  [  506  8717]]
#
#  Validation - Confusion Matrix:
# [[960 561]
#  [ 91 980]]
#
# Train Acc :  90.32590985298157
# Train Loss :  0.21325009
# Val Acc :  74.84567761421204
# Val Loss :  0.22069247
# ---------------------------------------------
#
#
#  Epoch: 950/20000 	LR: [0.0002] 	Dur: 10.45 sec
#
#  Training - Confusion Matrix:
# [[10884  1676]
#  [  498  8725]]
#
#  Validation - Confusion Matrix:
# [[997 524]
#  [ 97 974]]
#
# Train Acc :  90.15094240506491
# Train Loss :  0.21161757
# Val Acc :  76.04166865348816
# Val Loss :  0.19616601
# ---------------------------------------------
#
#
#  Epoch: 951/20000 	LR: [0.0002] 	Dur: 9.53 sec
#
#  Training - Confusion Matrix:
# [[10969  1591]
#  [  570  8653]]
#
#  Validation - Confusion Matrix:
# [[970 551]
#  [ 96 975]]
#
# Train Acc :  89.87240393956503
# Train Loss :  0.21979868
# Val Acc :  75.03858208656311
# Val Loss :  0.2371642
